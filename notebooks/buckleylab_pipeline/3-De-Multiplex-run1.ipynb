# %% [markdown]
# # Description
#     Demultiplex ERA Rhizosphere samples: run1

# %% [markdown]
# # Setting variables

# %%
workDir = '/home/bryan/ERA/'
seqDir = '/home/bryan/ERA/data/MiSeq/20170417_run1/'

metadataFile = 'ERA_MappingFile.txt'
read1_file = 'read1.fq'
read2_file = 'read2.fq'
index_read1_file = 'index1.fq'
index_read2_file = 'index2.fq'
read12_screed_file = 'pear_merged-2017-04-18.assembled.fastq_screed'

# %% [markdown]
# # Init

# %%
import os
import screed
import pandas as pd
from glob import glob
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
#from ggplot import *
import re
import scipy.stats as stats

# %%
if not os.path.isdir(workDir):
    os.mkdir(workDir)

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# library(gdata)
# Out:
# Error in library(gdata) : there is no package called ‘gdata’
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in library(gdata) : there is no package called ‘gdata’
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Uncompressing with four files output

# %%
uncompFiles = glob(os.path.join(seqDir, 'index?.fq'))

if len(uncompFiles) != 2:
    # !cd $seqDir; \
        pigz -k -d -p 24 index?.fq.gz

# %%
# Generate screed database from index files

# %%
#long processessing time
os.chdir(seqDir)
screed.read_fastq_sequences(index_read1_file)
screed.read_fastq_sequences(index_read2_file)
# Out:
# <ScreedDB, 'index2.fq_screed'>

# %% [markdown]
# ## Checkpoint: define index screed files to skip above step

# %%
index_read1_screed = index_read1_file + '_screed'
index_read2_screed = index_read2_file + '_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta = pd.read_table(os.path.join(workDir,metadataFile), delimiter="\t")
df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]
#df_meta['Barcode_FR'] = [y.lower() + x.lower() for x,y \
#                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
df_meta
# Out:
#                Sample            TubeID ExtractionPlate PooledDNAPlate  \
# 0     ERA-T1_1-2b_170               125            ERA1              A
# 1     ERA-T1_1-3c_170               137            ERA1              A
# 2       ERA-T3_1-2b_0               530            ERA1              A
# 3      ERA-T2_1-2b_85               361            ERA1              A
# 4     ERA-T3_1-2d_170               602            ERA1              A
# 5      ERA-T1_1-4b_85               143            ERA1              A
# 6     ERA-T1_1-4b_170               142            ERA1              A
# 7       ERA-T1_1-2c_0               128            ERA1              A
# 8      ERA-T1_1-4a_85               139            ERA1              A
# 9       ERA-T3_1-4b_0               578            ERA1              A
# 10    ERA-T1_1-4a_170               141            ERA1              A
# 11     ERA-T2_1-2c_85               364            ERA1              A
# 12    ERA-T3_1-2c_170               554            ERA1              A
# 13     ERA-T2_1-4a_85               374            ERA1              A
# 14     ERA-T2_1-5b_85               385            ERA1              A
# 15     ERA-T2_1-1d_85               358            ERA1              A
# 16     ERA-T2_1-4b_85               378            ERA1              A
# 17     ERA-T1_1-2b_85               126            ERA1              A
# 18      ERA-T1_1-3c_0               135            ERA1              A
# 19      ERA-T1_1-4a_0               140            ERA1              A
# 20      ERA-T1_1-2d_0               132            ERA1              A
# 21    ERA-T3_1-4a_170               542            ERA1              A
# 22     ERA-T3_1-4b_85               577            ERA1              A
# 23     ERA-T2_1-1a_85               356            ERA1              A
# 24     ERA-T1_1-2c_85               129            ERA1              A
# 25     ERA-T2_1-3a_85               369            ERA1              A
# 26      ERA-T1_1-4b_0               144            ERA1              A
# 27    ERA-T3_1-3c_170               566            ERA1              A
# 28     ERA-T2_1-4d_85               381            ERA1              A
# 29     ERA-T2_1-5c_85               386            ERA1              A
# ..                ...               ...             ...            ...
# 224    ERA-T2_3-2c_85               431            ERA3              C
# 225     ERA-T3_3-2c_0               594            ERA3              C
# 226    ERA-T3_3-2c_85               595            ERA3              C
# 227   ERA-T3_3-2c_170               596            ERA3              C
# 228     ERA-T0_4-1a_0           BD - 14            ERA3              C
# 229    ERA-T1_4-3d_85               231            ERA3              C
# 230     ERA-T1_4-3d_0               232            ERA3              C
# 231   ERA-T1_4-3d_170               233            ERA3              C
# 232    ERA-T2_4-3d_85               466            ERA3              C
# 233    ERA-T3_4-3d_85               597            ERA3              C
# 234     ERA-T3_4-3d_0               598            ERA3              C
# 235   ERA-T3_4-3d_170               599            ERA3              C
# 236     ERA-T0_3-2c_0           BD - 12            ERA3              C
# 237     ERA-T0_3-4c_0            BD - 7            ERA3              C
# 238     ERA-T0_4-3d_0           BD - 16            ERA3              C
# 239     ERA-T0_1-2d_0           BD - 11            ERA3              C
# 240    ERA-T1_3-5c_85               212            ERA3              C
# 241     ERA-T1_3-4c_0               206            ERA3              C
# 242   ERA-T1_3-1d_170               192            ERA3              C
# 243    ERA-T1_3-4c_85               207            ERA3              C
# 244    ERA-T2_3-4c_85               442            ERA3              C
# 245    ERA-T2_3-5b_85               445            ERA3              C
# 246   ERA-T1_3-1c_170               189            ERA3              C
# 247    ERA-T3_3-4c_85               607            ERA3              C
# 248      NegControl_C      NegControl_C            ERA3              C
# 249  NegControl_Plate  NegControl_Plate            ERA3              C
# 250          MockComm          MockComm            ERA3              C
# 251  PostiveControl_C  PostiveControl_C            ERA3              C
# 252       IndexQC_Rev       IndexQC_Rev              IC             IC
# 253        IndexQC_Fw        IndexQC_Fw              IC             IC
#
#     Sample Well ID  PrimerPlate Primer Number Primer Well ID  Unnamed: 8  \
# 0               A1            1             1             A1         NaN
# 1               B1            1             2             B1         NaN
# 2               C1            1             3             C1         NaN
# 3               D1            1             4             D1         NaN
# 4               E1            1             5             E1         NaN
# 5               F1            1             6             F1         NaN
# 6               G1            1             7             G1         NaN
# 7               H1            1             8             H1         NaN
# 8               A2            1             9             A2         NaN
# 9               B2            1            10             B2         NaN
# 10              C2            1            11             C2         NaN
# 11              D2            1            12             D2         NaN
# 12              E2            1            13             E2         NaN
# 13              F2            1            14             F2         NaN
# 14              G2            1            15             G2         NaN
# 15              H2            1            16             H2         NaN
# 16              A3            1            17             A3         NaN
# 17              B3            1            18             B3         NaN
# 18              C3            1            19             C3         NaN
# 19              D3            1            20             D3         NaN
# 20              E3            1            21             E3         NaN
# 21              F3            1            22             F3         NaN
# 22              G3            1            23             G3         NaN
# 23              H3            1            24             H3         NaN
# 24              A4            1            25             A4         NaN
# 25              B4            1            26             B4         NaN
# 26              C4            1            27             C4         NaN
# 27              D4            1            28             D4         NaN
# 28              E4            1            29             E4         NaN
# 29              F4            1            30             F4         NaN
# ..             ...          ...           ...            ...         ...
# 224             F7            3            33             A5         NaN
# 225             G7            3            34             B5         NaN
# 226             H7            3            35             C5         NaN
# 227             A8            3            36             D5         NaN
# 228             B8            3            37             E5         NaN
# 229             C8            3            38             F5         NaN
# 230             D8            3            39             G5         NaN
# 231             E8            3            40             H5         NaN
# 232             F8            3            41             A6         NaN
# 233             G8            3            42             B6         NaN
# 234             H8            3            43             C6         NaN
# 235             A9            3            44             D6         NaN
# 236             B9            3            45             E6         NaN
# 237             C9            3            46             F6         NaN
# 238             D9            3            47             G6         NaN
# 239             E9            3            48             H6         NaN
# 240            A11            3            49             A7         NaN
# 241            B11            3            50             B7         NaN
# 242            C11            3            51             C7         NaN
# 243            D11            3            52             D7         NaN
# 244            E11            3            53             E7         NaN
# 245            F11            3            54             F7         NaN
# 246            G11            3            55             G7         NaN
# 247            H11            3            56             H7         NaN
# 248            A12            3            57             A8         NaN
# 249            B12            3            58             B8         NaN
# 250            G12            3            59             C8         NaN
# 251            H12            3            60             D8         NaN
# 252             IC            3            60             D9         NaN
# 253             IC            3            IC             IC         NaN
#
#     primerFwdLoc primerRevLoc fwd_barcode rev_barcode    PlotID TimePoint  \
# 0            1-A          1-1    ATCGTACG    AACTCTCG  1-2b_170        T1
# 1            1-B          1-1    ACTATCTG    AACTCTCG  1-3c_170        T1
# 2            1-C          1-1    TAGCGAGT    AACTCTCG    1-2b_0        T3
# 3            1-D          1-1    CTGCGTGT    AACTCTCG   1-2b_85        T2
# 4            1-E          1-1    TCATCGAG    AACTCTCG  1-2d_170        T3
# 5            1-F          1-1    CGTGAGTG    AACTCTCG   1-4b_85        T1
# 6            1-G          1-1    GGATATCT    AACTCTCG  1-4b_170        T1
# 7            1-H          1-1    GACACCGT    AACTCTCG    1-2c_0        T1
# 8            1-A          1-2    ATCGTACG    ACTATGTC   1-4a_85        T1
# 9            1-B          1-2    ACTATCTG    ACTATGTC    1-4b_0        T3
# 10           1-C          1-2    TAGCGAGT    ACTATGTC  1-4a_170        T1
# 11           1-D          1-2    CTGCGTGT    ACTATGTC   1-2c_85        T2
# 12           1-E          1-2    TCATCGAG    ACTATGTC  1-2c_170        T3
# 13           1-F          1-2    CGTGAGTG    ACTATGTC   1-4a_85        T2
# 14           1-G          1-2    GGATATCT    ACTATGTC   1-5b_85        T2
# 15           1-H          1-2    GACACCGT    ACTATGTC   1-1d_85        T2
# 16           1-A          1-3    ATCGTACG    AGTAGCGT   1-4b_85        T2
# 17           1-B          1-3    ACTATCTG    AGTAGCGT   1-2b_85        T1
# 251          3-D          3-8    CTGCGTGT    GGTACTAT       NaN       NaN
# 252          3-D          3-9    CTGCGTGT    GTATACGC       NaN       NaN
# 253          3-I          3-C   ACGACGTG     GGTACTAT       NaN       NaN
#
#             Barcode_FR
# 0     cgagagttatcgtacg
# 1     cgagagttactatctg
# 2     cgagagtttagcgagt
# 3     cgagagttctgcgtgt
# 4     cgagagtttcatcgag
# 5     cgagagttcgtgagtg
# 6     cgagagttggatatct
# 7     cgagagttgacaccgt
# 8     gacatagtatcgtacg
# 9     gacatagtactatctg
# 10    gacatagttagcgagt
# 11    gacatagtctgcgtgt
# 12    gacatagttcatcgag
# 13    gacatagtcgtgagtg
# 14    gacatagtggatatct
# 15    gacatagtgacaccgt
# 16    acgctactatcgtacg
# 17    acgctactactatctg
# 18    acgctacttagcgagt
# 19    acgctactctgcgtgt
# 20    acgctacttcatcgag
# 21    acgctactcgtgagtg
# 22    acgctactggatatct
# 23    acgctactgacaccgt
# 24    actcactgatcgtacg
# 25    actcactgactatctg
# 26    actcactgtagcgagt
# 27    actcactgctgcgtgt
# 28    actcactgtcatcgag
# 29    actcactgcgtgagtg
# ..                 ...
# 224   gatctacgatcgtacg
# 225   gatctacgactatctg
# 226   gatctacgtagcgagt
# 227   gatctacgctgcgtgt
# 228   gatctacgtcatcgag
# 229   gatctacgcgtgagtg
# 230   gatctacgggatatct
# 231   gatctacggacaccgt
# 232   gtaacgagatcgtacg
# 233   gtaacgagactatctg
# 234   gtaacgagtagcgagt
# 235   gtaacgagctgcgtgt
# 236   gtaacgagtcatcgag
# 237   gtaacgagcgtgagtg
# 238   gtaacgagggatatct
# 239   gtaacgaggacaccgt
# 240   acgtgcgcatcgtacg
# 241   acgtgcgcactatctg
# 242   acgtgcgctagcgagt
# 243   acgtgcgcctgcgtgt
# 244   acgtgcgctcatcgag
# 245   acgtgcgccgtgagtg
# 246   acgtgcgcggatatct
# 247   acgtgcgcgacaccgt
# 248   atagtaccatcgtacg
# 249   atagtaccactatctg
# 250   atagtacctagcgagt
# 251   atagtaccctgcgtgt
# 252   gcgtatacctgcgtgt
# 253  atagtaccacgacgtg
#
# [254 rows x 16 columns]

# %%
# resulting dict of sample => barcode_FR 
n_print = 5
[(map_d.keys()[i], map_d[map_d.keys()[i]]) for i in xrange(n_print)]
# Out:
# [('tgagtacgactatctg', 'ERA-T1_1-2d_85'),
#  ('gatctacgcgtgagtg', 'ERA-T1_4-3d_85'),
#  ('tatagcgagacaccgt', 'NegControl_A'),
#  ('gtaacgagcgtgagtg', 'ERA-T0_3-4c_0'),
#  ('tatagcgatacgagac', 'ERA-T2_4-5a_85')]

# %%
# loading screed databases 
os.chdir(seqDir)

ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed_file)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed_file)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workDir, outFile)
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        # debug
        #c += 1
        #if c > 10000:
        #    break
            
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print "Unable to assign %s reads to samples"%unassigned
# Out:
# Unable to assign 3140123 reads to samples

# %% [markdown]
# ## Checkpoint: define outfile for next command without running above.

# %%
outFile = '/home/bryan/ERA/data/MiSeq/20170417_run1/pear_merged-2017-04-18.assembled.dmult.fastq'

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print 'Number of sequences: {}'.format(n_lines/4)
# Out:
# Number of sequences: 14036217

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame(seq_cnt.items(), columns=['Sample', 'seq_count'])
df_seq_cnt
# Out:
#                Sample  seq_count
# 0     ERA-T1_3-3a_170      34912
# 1       ERA-T3_2-5c_0      50256
# 2       ERA-T3_3-5c_0      50903
# 3     ERA-T3_4-3d_170      99796
# 4       ERA-T3_2-3d_0      44601
# 5       ERA-T1_3-4c_0      29330
# 6      ERA-T2_2-1c_85      68659
# 7       ERA-T3_1-4b_0      48070
# 8    PostiveControl_C         45
# 9       ERA-T3_1-3c_0      51283
# 10     ERA-T1_1-3c_85      53610
# 11      ERA-T3_2-5a_0      95057
# 12    ERA-T1_1-2d_170      59288
# 13     ERA-T3_4-4a_85      77801
# 14     ERA-T2_2-4b_85      71930
# 15     ERA-T2_3-5c_85      44491
# 16     ERA-T2_1-2a_85      48409
# 17    ERA-T3_1-5a_170      46357
# 18     ERA-T3_2-5a_85      74556
# 19      ERA-T1_2-2d_0      63740
# 20      ERA-T1_1-4a_0      67009
# 21     ERA-T2_2-2d_85     108210
# 22     ERA-T1_3-2c_85     116369
# 23      ERA-T1_4-1b_0      40542
# 24      ERA-T3_3-2c_0      32319
# 25    ERA-T1_4-3d_170      91410
# 26    ERA-T1_2-2c_170      44697
# 27    ERA-T3_2-3b_170      66273
# 28      ERA-T1_3-1c_0      43455
# 29      ERA-T1_4-2c_0      70202
# ..                ...        ...
# 222    ERA-T2_2-3b_85      31460
# 223    ERA-T2_1-4a_85      45574
# 224    ERA-T2_1-2c_85      53010
# 225   ERA-T3_2-2b_170      62224
# 226     ERA-T3_4-5b_0      53212
# 227    ERA-T2_3-4d_85      33495
# 228    ERA-T2_3-1b_85      57475
# 229    ERA-T2_1-4b_85      76605
# 230     ERA-T0_2-2c_0      98619
# 231   ERA-T3_1-3c_170      51222
# 232    ERA-T2_2-3d_85      31081
# 233      NegControl_A        283
# 234   ERA-T3_4-5b_170      74826
# 235    ERA-T1_1-2c_85      57703
# 236    ERA-T2_3-5b_85      43469
# 237    ERA-T2_1-4c_85      36004
# 238    ERA-T2_4-3b_85      25945
