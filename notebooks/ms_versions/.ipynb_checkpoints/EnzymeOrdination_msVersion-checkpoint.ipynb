# %% [markdown]
# ## Description:
#
#     Ordinate enzyme data
#     Regress axes against OTU abundance in DESeq

# %% [markdown]
# # Setting variables

# %%
workDir = '/home/bryan/ERA/data/MiSeq/20170417_run1/DESeq2/'
#using physeq file with sparsity of greater than 3 in 3 samples
physeqFile = '/home/bryan/ERA/data/MiSeq/20170417_run1/phyloseq/ERA_thresh.rds'

# %% [markdown]
# # Init

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# # The required package list:
# reqpkg = c("plyr","BiocParallel","doParallel", "DESeq2", "foreach", "ggplot2",
#    "gridExtra","scales", "phyloseq", "dplyr", "tidyr", "lmerTest",
#            "reshape2", "vegan", "RColorBrewer", "lsmeans")
# # Load all required packages and show version
# for (i in reqpkg) {
#     print(i)
#     print(packageVersion(i))
#     suppressMessages(library(i, quietly = TRUE, verbose = FALSE,
#                              warn.conflicts = FALSE, character.only = TRUE))
# }
# Out:
# [1] "plyr"
# [1] ‘1.8.4’
# [1] "BiocParallel"
# [1] ‘1.8.2’
# [1] "doParallel"
# [1] ‘1.0.10’
# [1] "DESeq2"
# [1] ‘1.14.1’
# [1] "foreach"
# [1] ‘1.4.3’
# [1] "ggplot2"
# [1] ‘2.2.1’
# [1] "gridExtra"
# [1] ‘2.2.1’
# [1] "scales"
# [1] ‘0.4.1’
# [1] "phyloseq"
# [1] ‘1.19.1’
# [1] "dplyr"
# [1] ‘0.5.0’
# [1] "tidyr"
# [1] ‘0.6.0’
# [1] "lmerTest"
# [1] ‘2.0.33’
# [1] "reshape2"
# [1] ‘1.4.2’
# [1] "vegan"
# [1] ‘2.4.3’
# [1] "RColorBrewer"
# [1] ‘1.1.2’
# [1] "lsmeans"
# [1] ‘2.25.5’

# %%
# %%R
# # set theme for ggplot
#
# theme_pub = function (base_size = 11, base_family = "Helvetica")
# {
#     theme_grey(base_size = base_size, base_family = base_family) %+replace%
#         theme(
#             axis.line.x = element_line(size = .5),
#             axis.line.y = element_line(size = .5),
#             panel.background = element_rect(fill = "white", colour = NA),
#             panel.border = element_rect(fill = NA, color = "black", size = .5),
#             panel.grid.major = element_blank(),
#             panel.grid.minor = element_blank(),
#             strip.background = element_rect(fill = "grey85",
#                 colour = "grey20"),
#             legend.key = element_rect(fill = "white",
#                 colour = NA), complete = TRUE)
#     }

# %%
# %%R
# #set color scales
# library(RColorBrewer)
# FertColors = brewer.pal(3, 'Set2')
#
#
# GenotypeColors = colorRampPalette(brewer.pal(4,'RdYlBu'))(12)
# GenotypeColors %>% print
#
# GenotypeColors_sub6 = GenotypeColors[c(2,4,6,8,10,12)]
# GenotypeColors_sub6
#
# # function for gathering and plotting legend separately
# g_legend<-function(a.gplot){
#     tmp <- ggplot_gtable(ggplot_build(a.gplot))
#     leg <- which(sapply(tmp$grobs, function(x) x$name) == "guide-box")
#     legend <- tmp$grobs[[leg]]
#     legend
# }
# Out:
#  [1] "#D7191C" "#E1412E" "#EB6A41" "#F69254" "#F5B16D" "#DFBD92" "#C8C9B7"
#  [8] "#B2D5DC" "#93C7DF" "#71AED1" "#4E94C3" "#2C7BB6"

# %%
# %%R
# register(MulticoreParam(20))

# %% [markdown]
# # Loading phyloseq object

# %%
# %%R -i physeqFile
#
# physeq.Full = readRDS(physeqFile)
# physeq.Full
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 243 samples ]
# sample_data() Sample Data:       [ 243 samples by 46 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %%
# %%R
# colnames(sample_data(physeq.Full))
# Out:
#  [1] "X.sampleID"      "TubeID"          "ExtractionPlate" "PooledDNAPlate"
#  [5] "Sample.Well.ID"  "PrimerPlate"     "Primer.Number"   "Primer.Well.ID"
#  [9] "X"               "primerFwdLoc"    "primerRevLoc"    "fwd_barcode"
# [13] "rev_barcode"     "PlotID"          "TimePoint"       "Rep"
# [17] "Row"             "Pos"             "Fert"            "PlotIndex"
# [21] "Plant"           "Genotype"        "SeedTreatment"   "R_Year"
# [25] "ERA"             "BG_activity.g"   "BX_activity.g"   "CB_activity.g"
# [29] "LAP_activity.g"  "NAG_activity.g"  "Stage"           "kgdw_ha"
# [33] "FracN.leco"      "FracC.leco"      "kgN_ha"          "RGR"
# [37] "AGR"             "Nprod"           "NupR"            "d15N"
# [41] "X15N_AtPercent"  "FracN"           "FracN_fromSoil"  "FracN_fromFert"
# [45] "kgFertN_ha"      "kgSoilN_ha"

# %%
# %%R
#
# #remove BARE soil controls and untreated seeds
# physeq.plant = subset_samples(physeq.Full, Genotype != "Bare" & SeedTreatment == "Treated")
#
#
# # Remove ordination outliers, see Ordination notebook
# #physeq.plant = subset_samples(physeq.plant, !X.sampleID %in% c("ERA-T2_1-4c_85", "ERA-T2_4-4d_85"))
#
#
# # Set rep as a factor
# sample_data(physeq.plant)$Rep = factor(sample_data(physeq.plant)$Rep)
# sample_data(physeq.plant)$ERA = factor(sample_data(physeq.plant)$ERA)
# sample_data(physeq.plant)$Fert = factor(sample_data(physeq.plant)$Fert)
#
# sample_data(physeq.plant)$R_Year.c = sample_data(physeq.plant)$R_Year - 1935
# physeq.plant
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 195 samples ]
# sample_data() Sample Data:       [ 195 samples by 47 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %% [markdown]
# # Ordinate all time points of core data

# %%
# %%R
#
# sample_data(physeq.Full)$Rep = factor(sample_data(physeq.Full)$Rep)
# sample_data(physeq.Full)$ERA = factor(sample_data(physeq.Full)$ERA)
# sample_data(physeq.Full)$Fert = factor(sample_data(physeq.Full)$Fert)
#
#
# sample_data(physeq.Full)$R_Year.c = sample_data(physeq.Full)$R_Year - 1935
#
# # subset to samples in plots sampled on each harvest
# physeq.core = subset_samples(physeq.Full, Plant == "Bare" & Fert == "85" & !is.na(BG_activity.g)| R_Year %in% c(1939,
#                                                 1953, 1971, 1984, 2001, 2011) &
#                              Fert == "85" & !is.na(BG_activity.g))
#
# # # PCA of enzymes
# sd = as(sample_data(physeq.core), "data.frame")
# rownames(sd) = sd$X.sample
#
# #tmp = filter(sd, X.sampleID != "ERA-T1_4-5b_85")
#
# sd %>% select(BG_activity.g, BX_activity.g,CB_activity.g, LAP_activity.g, NAG_activity.g) %>%
#     as.matrix %>%
# Hmisc::rcorr()
# Out:
#                BG_activity.g BX_activity.g CB_activity.g LAP_activity.g
# BG_activity.g           1.00          0.57          0.61           0.22
# BX_activity.g           0.57          1.00          0.87           0.47
# CB_activity.g           0.61          0.87          1.00           0.42
# LAP_activity.g          0.22          0.47          0.42           1.00
# NAG_activity.g          0.65          0.69          0.70           0.47
#                NAG_activity.g
# BG_activity.g            0.65
# BX_activity.g            0.69
# CB_activity.g            0.70
# LAP_activity.g           0.47
# NAG_activity.g           1.00
#
# n= 92
#
#
# P
#                BG_activity.g BX_activity.g CB_activity.g LAP_activity.g
# BG_activity.g                0.0000        0.0000        0.0318
# BX_activity.g  0.0000                      0.0000        0.0000
# CB_activity.g  0.0000        0.0000                      0.0000
# LAP_activity.g 0.0318        0.0000        0.0000
# NAG_activity.g 0.0000        0.0000        0.0000        0.0000
#                NAG_activity.g
# BG_activity.g  0.0000
# BX_activity.g  0.0000
# CB_activity.g  0.0000
# LAP_activity.g 0.0000
# NAG_activity.g

# %%
# %%R
# # # PCA of enzymes
# sd = as(sample_data(physeq.core), "data.frame")
# rownames(sd) = sd$X.sample
#
# # removing extreme outliler fr
# tmp = filter(sd, X.sampleID != "ERA-T1_4-5b_85")
# fit = prcomp(~BG_activity.g +  CB_activity.g + LAP_activity.g + NAG_activity.g, data = tmp,
#                  na.action = na.exclude, center = TRUE, scale = TRUE)
#
# summary(fit) %>% print
# fit$rotation %>% print
# biplot(fit)
#
# S = predict(fit)[,1:3]
# TM_Fit = cbind(tmp, S)
# rownames(TM_Fit) = TM_Fit$X.sample
# #sample_data(physeq.plant) = TM_Fit
#
#
#
# p = ggplot(TM_Fit, aes(PC1, PC2, color = TimePoint,
#                        size = 12), pch = 21)
# p = p + geom_point()
# p = p + scale_colour_brewer(palette="Paired")
# p = p + ggtitle("PCA of enzyme activity")
# p
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4
# Standard deviation     1.6618 0.8564 0.55220 0.44731
# Proportion of Variance 0.6904 0.1834 0.07623 0.05002
# Cumulative Proportion  0.6904 0.8738 0.94998 1.00000
#                       PC1         PC2         PC3        PC4
# BG_activity.g  -0.5355747  0.34403482 -0.14021737  0.7583791
# CB_activity.g  -0.5297438  0.19703077  0.75902645 -0.3231552
# LAP_activity.g -0.3722394 -0.91316602  0.04525756  0.1597418
# NAG_activity.g -0.5421892  0.09458722 -0.63416851 -0.5430603

# %%
# %%R
# TM_Fit = TM_Fit %>% mutate(Planted = ifelse(Genotype == "Bare", "Bare", "Rhizosphere"))
# p = ggplot(TM_Fit, aes(PC1, PC2, color = Planted, shape = Fert,
#                        size = 12), pch = 21)
# p = p + geom_point()
# p = p + scale_colour_brewer(palette="Paired")
# p = p + ggtitle("PCA of enzyme activity")
# p = p + facet_wrap(~TimePoint, scales = "free")
# p

# %%
# %%R
# # Now plot loading arrows
# arrowmat <- vegan::scores(fit, display = "species")
#
# rownames(arrowmat) = c("BG", "CG", "LAP", "NAG")
# #rownames(arrowmat) = c("BX", "CB", "LAP", "NAG")
#
# # Add labels, make a data.frame
# arrowdf <- data.frame(labels = rownames(arrowmat), arrowmat)
#
# # Define the arrow aesthetic mapping
# arrow_map <- aes(xend = PC1,
#     yend = PC2,
#     x = 0,
#     y = 0,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# label_map <- aes(x = 1.1 * PC1,
#     y = 1.1 * PC2,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# arrowhead = arrow(length = unit(0.02, "npc"))
#
# pA.c = ggplot() +
#     geom_segment(arrow_map,
#     #size = .5,
#     data = arrowdf,
#     color = "black",
#     arrow = arrowhead
#     ) +
# geom_text(label_map,
#     data = arrowdf,
#     show_guide = FALSE, size = 5) +
#     theme_pub()
#     #theme(axis.text = element_blank())
# pA.c
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Warning:
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Ignoring unknown aesthetics: shape, label
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Ignoring unknown aesthetics: shape
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ### Join enzyme ordination scores with phyloseq object

# %%
# %%R
# PCscore = TM_Fit %>%
#     select(X.sampleID, PC1, PC2, PC3)
# colnames(PCscore)[2:4] = c("EnzPC1", "EnzPC2", "EnzPC3")

# %%
# %%R
# sd = left_join(sd, PCscore, by = "X.sampleID")
# rownames(sd) = sd$X.sampleID
# physeq.plantenz = physeq.plant
# sample_data(physeq.plantenz) = sd

# %% [markdown]
# # Core sample enzyme analysis

# %% [markdown]
# * Two tests: bare vs rhizosphere over time and rhizosphere genotypes over time

# %%
# %%R
# ### Quick seed treatment check
# sd$R_Year %>% unique
# Out:
# [1] 2001   NA 1971 2011 1939 1953 1984

# %%
# %%R
# m1 = lmer(PC1~Planted*TimePoint + (1|Rep) + (1|Rep:Genotype),  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~Planted*TimePoint + (1|Rep) + (1|Rep:Genotype),  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                    Sum Sq Mean Sq NumDF  DenDF F.value    Pr(>F)
# Planted           31.4189 31.4189     1 24.646 31.2496 8.578e-06 ***
# TimePoint         31.3677 15.6839     2 59.311 15.5994 3.601e-06 ***
# Planted:TimePoint  0.4158  0.2079     2 59.311  0.2068    0.8138
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                    Sum Sq Mean Sq NumDF DenDF F.value    Pr(>F)
# Planted            4.3202  4.3202     1 25.67  27.068 2.044e-05 ***
# TimePoint         23.5222 11.7611     2 59.54  73.690 < 2.2e-16 ***
# Planted:TimePoint  0.0874  0.0437     2 59.54   0.274    0.7614
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~Planted) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(Planted,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~Planted) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(Planted,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Core.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "Planted") #%>%
#    # mutate(TimePoint = "Core")
# Core.lsm.df
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: NOTE: Results may be misleading due to involvement in interactions
#
#   warnings.warn(x, RRuntimeWarning)
#       Planted Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1        Bare    2.0102521 0.4473626       1.066098      2.9544063   -0.5768600
# 2 Rhizosphere   -0.3195459 0.2732674      -1.146538      0.5074459    0.1426401
#     Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1 0.15277500     -0.9015175     -0.2522025
# 2 0.09716391     -0.1526622      0.4379424

# %%
# %%R -w 400 -h 200
# pP= ggplot(Core.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, color = Planted)) +
#     geom_point()+
#     theme_pub()+
#     xlim(c(-2,3))+
#     ylim(c(-1,1.5))+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = Planted),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE, color = Planted),
#                 height = .002) +
#     theme(legend.position = "bottom")+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")#
#
# STLeg = g_legend(pP)
# pP = pP + theme(legend.position = "none")
# pP

# %%
# %%R
# sub = TM_Fit %>% filter(Planted == "Rhizosphere") %>%
#     mutate(R_Year.f = factor(R_Year))
# m1 = lmer(PC1~R_Year.f*TimePoint + (1|Rep) + (1|Rep:Genotype),  data = sub, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.f*TimePoint + (1|Rep) + (1|Rep:Genotype),  data = sub, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                    Sum Sq Mean Sq NumDF  DenDF F.value    Pr(>F)
# R_Year.f           16.371  3.2742     5 16.006  2.8088   0.05246 .
# TimePoint          62.525 31.2625     2 43.712 26.8184 2.512e-08 ***
# R_Year.f:TimePoint  8.558  0.8558    10 43.633  0.7342   0.68850
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                    Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.f            0.412  0.0823     5 15.980   0.450 0.8069
# TimePoint          36.377 18.1885     2 43.716  99.526 <2e-16 ***
# R_Year.f:TimePoint  1.145  0.1145    10 43.637   0.626 0.7830
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Core.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "R_Year.f") #%>%
#    # mutate(TimePoint = "Core")
# Core.lsm.df
# Out:
#   R_Year.f Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1     1939   -0.4022284 0.4237067     -1.3335555      0.5290988   0.10371608
# 2     1953   -0.3967198 0.4041497     -1.3079651      0.5145254   0.12790314
# 3     1971   -1.2219163 0.4237067     -2.1532434     -0.2905891   0.29905778
# 4     1984    0.4025347 0.4041497     -0.5087105      1.3137799   0.02703805
# 5     2001    0.1106109 0.4373870     -0.8387068      1.0599285   0.12232679
# 6     2011   -0.3678534 0.4237067     -1.2991805      0.5634738   0.12820403
#    Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1 0.1507136    -0.21394998      0.4213821
# 2 0.1420436    -0.17752380      0.4333301
# 3 0.1507136    -0.01860827      0.6167238
# 4 0.1420436    -0.27838889      0.3324650
# 5 0.1567205    -0.20524304      0.4498966
# 6 0.1507136    -0.18946203      0.4458701

# %%
# %%R -w 400 -h 200
# pF = ggplot(Core.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean )) +
#
#     scale_color_manual(values = GenotypeColors_sub6) +
#     scale_fill_manual(values = GenotypeColors_sub6) +
#     theme_pub()+
#        xlim(c(-2,3))+
#     ylim(c(-1,1.5))+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = R_Year.f),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE, color = R_Year.f),
#                 height = .002) +
#          geom_point(aes(fill = R_Year.f), color = "black", shape = 21, size = 2)+
#     theme(legend.position = "none", legend.title = NULL)+
#     guides(fill = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     guides(color = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")#
# pF %>% print
# #pF = pF + theme(legend.position = "none")

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~TimePoint) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(TimePoint,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~TimePoint) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(TimePoint,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Core.time.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "TimePoint")
# Core.time.lsm.df
# Out:
#   TimePoint Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1        T1    0.8106853 0.3461111    -0.03168814      1.6530588    1.1453874
# 2        T2   -0.2457955 0.3297767    -1.08927261      0.5976817   -0.2696344
# 3        T3   -1.5026760 0.3418302    -2.34429922     -0.6610529   -0.4716300
#    Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1 0.1134276      0.8904013     1.40037347
# 2 0.1055227     -0.5178019    -0.02146691
# 3 0.1113739     -0.7244968    -0.21876319

# %%
# %%R -w 400 -h 200
# pT = ggplot(Core.time.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, color = TimePoint)) +
#     geom_point()+
#     theme_pub()+
#        xlim(c(-2,3))+
#     ylim(c(-1,1.5))+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = TimePoint),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE, color = TimePoint),
#                 height = .002) +
#     theme(legend.position = "bottom")+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")
# TimeLeg = g_legend(pT)
# pT = pT + theme(legend.position = "none")
# pT

# %%
# %%R -w 700 -h 250
# GCore = grid.arrange(pP, pT, pF, pA.c, ncol = 4, widths = c(1, 1, 2, 1))

# %%
# %%R
# m1 = lmer(PC1~R_Year.c*TimePoint + (1|Rep) + (1|Genotype) + (1|Rep:Genotype),  data = sub, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.c*TimePoint + (1|Rep) + (1|Genotype) + (1|Rep:Genotype),  data = sub, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                     Sum Sq Mean Sq NumDF  DenDF F.value   Pr(>F)
# R_Year.c            0.5254  0.5254     1  4.119  0.4613 0.533264
# TimePoint          13.6480  6.8240     2 51.618  5.9913 0.004573 **
# R_Year.c:TimePoint  0.6675  0.3338     2 51.840  0.2930 0.747230
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                     Sum Sq Mean Sq NumDF  DenDF F.value    Pr(>F)
# R_Year.c            0.0001  0.0001     1  4.384   0.001    0.9820
# TimePoint          12.0130  6.0065     2 52.457  34.334 2.937e-10 ***
# R_Year.c:TimePoint  0.0913  0.0456     2 52.537   0.261    0.7714
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# * Within core plants there is no effect of year of release, but there is a genotype effect
# * No year of release effect within core plots over time or with polynomial

# %% [markdown]
# # Ordinate enzyme data - timepoints seperately

# %% [markdown]
# ## T1

# %%
# %%R
# physeq.plant.t1 = subset_samples(physeq.plant, TimePoint == "T1" & !X.sampleID %in%
#                                  c("ERA-T1_3-5c_0","ERA-T1_4-5b_85")) # removing two multivariate outliers,
#                                                                     #run with samples to visualize
# physeq.plant.t1
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 70 samples ]
# sample_data() Sample Data:       [ 70 samples by 47 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %%
# %%R
# # # PCA of enzymes
# sd = as(sample_data(physeq.plant.t1), "data.frame")
# rownames(sd) = sd$X.sample
#
#
# fit = prcomp(~BG_activity.g + CB_activity.g + LAP_activity.g + NAG_activity.g, data = sd,
#                  na.action = na.exclude, center = TRUE, scale = TRUE)
#
# summary(fit) %>% print
#
# #fittmp = fit
# #flip axis 1 to ease visual interpretation.
# fit$rotation[,"PC1"] = fit$rotation[,"PC1"] * -1
# fit$x[,"PC1"] = fit$x[,"PC1"] * -1
# fit$rotation %>% print
#
#
# biplot(fit)
# # biplot(fittmp)
#
# S = predict(fit)[,1:3]
#
# #Stmp = predict(fittmp)[,1:3]
#
# #head(S) %>% print
# #head(Stmp) %>% print
# TM_Fit = cbind(sd, S)
# rownames(TM_Fit) = TM_Fit$X.sample
# sample_data(physeq.plant.t1) = TM_Fit
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4
# Standard deviation     1.8415 0.6458 0.40380 0.16960
# Proportion of Variance 0.8478 0.1043 0.04076 0.00719
# Cumulative Proportion  0.8478 0.9520 0.99281 1.00000
#                       PC1        PC2         PC3         PC4
# BG_activity.g  -0.4953908  0.4392308 -0.72795055  0.17819175
# CB_activity.g  -0.4837800  0.5663562  0.66703969 -0.01598999
# LAP_activity.g -0.4993322 -0.5788197  0.14436642  0.62832592
# NAG_activity.g -0.5207805 -0.3889534 -0.06560779 -0.75709878

# %%
# %%R
# # Now add the environmental variables as arrows
# arrowmat <- vegan::scores(fit, display = "species")
#
# rownames(arrowmat) = c("BG", "CB", "LAP", "NAG")
# #rownames(arrowmat) = c("BX", "CB", "LAP", "NAG")
#
# # Add labels, make a data.frame
# arrowdf <- data.frame(labels = rownames(arrowmat), arrowmat)
#
# # Define the arrow aesthetic mapping
# arrow_map <- aes(xend = PC1,
#     yend = PC2,
#     x = 0,
#     y = 0,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# label_map <- aes(x = 1.1 * PC1,
#     y = 1.1 * PC2,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# arrowhead = arrow(length = unit(0.02, "npc"))
#
# pA.1 = ggplot() +
#     geom_segment(arrow_map,
#     #size = .5,
#     data = arrowdf,
#     color = "black",
#     arrow = arrowhead
#     ) +
# geom_text(label_map,
#     data = arrowdf,
#     show_guide = FALSE, size = 5) +
#     theme_pub()
#     #theme(axis.text = element_blank())
# pA.1

# %%
# %%R
# p = ggplot(TM_Fit, aes(PC1, PC2, color = Genotype,
#                        size = 12), pch = 21)
# p = p + geom_point()
# p = p + scale_colour_brewer(palette="Paired")
# p = p + ggtitle("PCA of enzyme activity at T1")
# p

# %% [markdown]
# ## Year of release effects at T1

# %%
# %%R
#
# m1 = lmer(PC1~R_Year.c*Fert + (1|Rep) +(1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos),  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.c*Fert + (1|Rep) + +(1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos),  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#               Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.c      2.4985 2.49848     1  3.792 1.07687 0.3610
# Fert          2.1368 1.06839     2 28.772 0.46048 0.6355
# R_Year.c:Fert 1.3478 0.67391     2 40.755 0.29046 0.7495
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.c      1.63040 1.63040     1  3.793  4.5585 0.1034
# Fert          0.06872 0.03436     2 27.386  0.0961 0.9087
# R_Year.c:Fert 0.30824 0.15412     2 40.847  0.4309 0.6528

# %%
# %%R
#
# m1 = lmer(PC1~poly(R_Year.c,2)*Fert + (1|Rep) +(1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos),  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~poly(R_Year.c,2)*Fert + (1|Rep) + +(1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos),  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                        Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# poly(R_Year.c, 2)      1.7969 0.89845     2  2.905 0.41651 0.6934
# Fert                   2.4626 1.23130     2  4.927 0.57082 0.5985
# poly(R_Year.c, 2):Fert 9.0417 2.26042     4 39.314 1.04791 0.3950
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                         Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# poly(R_Year.c, 2)      1.61362 0.80681     2  2.815 2.24565 0.2612
# Fert                   0.24557 0.12279     2  4.699 0.34176 0.7268
# poly(R_Year.c, 2):Fert 1.63868 0.40967     4 39.913 1.14026 0.3516

# %% [markdown]
# ## Treatment effects at T1

# %%
# %%R
# head(TM_Fit)
# Out:
#                      X.sampleID TubeID ExtractionPlate PooledDNAPlate
# ERA-T1_3-5c_170 ERA-T1_3-5c_170    213            ERA4              B
# ERA-T1_1-2b_170 ERA-T1_1-2b_170    125            ERA1              A
# ERA-T1_1-4b_0     ERA-T1_1-4b_0    144            ERA1              A
# ERA-T1_1-4a_170 ERA-T1_1-4a_170    141            ERA1              A
# ERA-T1_4-4a_170 ERA-T1_4-4a_170    236            ERA5              B
# ERA-T1_2-2b_85   ERA-T1_2-2b_85    157            ERA2              A
#                 Sample.Well.ID PrimerPlate Primer.Number Primer.Well.ID  X
# ERA-T1_3-5c_170             D3           2            20             D3 NA
# ERA-T1_1-2b_170             A1           1             1             A1 NA
# ERA-T1_1-4b_0               C4           1            27             C4 NA
# ERA-T1_1-4a_170             C2           1            11             C2 NA
# ERA-T1_4-4a_170             F7           2            54             F7 NA
# ERA-T1_2-2b_85              G8           1            63             G8 NA
#                 primerFwdLoc primerRevLoc fwd_barcode rev_barcode   PlotID
# ERA-T1_3-5c_170          2-D          2-3    TACGAGAC    AGTAGCGT 3-5c_170
# ERA-T1_1-2b_170          1-A          1-1    ATCGTACG    AACTCTCG 1-2b_170
# ERA-T1_1-4b_0            1-C          1-4    TAGCGAGT    CAGTGAGT   1-4b_0
# ERA-T1_1-4a_170          1-C          1-2    TAGCGAGT    ACTATGTC 1-4a_170
# ERA-T1_4-4a_170          2-F          2-7    TCGACGAG    GGAGACTA 4-4a_170
# ERA-T1_2-2b_85           1-G          1-8    GGATATCT    GTCGCTCG  2-2b_85
#                 TimePoint Rep Row Pos Fert PlotIndex Plant Genotype
# ERA-T1_3-5c_170        T1   3   5   c  170       177  1939     1939
# ERA-T1_1-2b_170        T1   1   2   b  170        16  1939     1939
# ERA-T1_1-4b_0          T1   1   4   b    0        42  2001     2001
# ERA-T1_1-4a_170        T1   1   4   a  170        39  1953     1953
# ERA-T1_4-4a_170        T1   4   4   a  170       219  1984     1984
# ERA-T1_2-2b_85         T1   2   2   b   85        77  1971     1971
#                 SeedTreatment R_Year ERA BG_activity.g BX_activity.g
# ERA-T1_3-5c_170       Treated   1939   1      74.45039      21.77484
# ERA-T1_1-2b_170       Treated   1939   1      96.79331      21.01421
# ERA-T1_1-4b_0         Treated   2001   3      63.29524      17.04118
# ERA-T1_1-4a_170       Treated   1953   1      80.84751      12.69426
# ERA-T1_4-4a_170       Treated   1984   2     122.02821      28.35926
# ERA-T1_2-2b_85        Treated   1971   2     107.80246      23.16892
#                 CB_activity.g LAP_activity.g NAG_activity.g Stage kgdw_ha
# ERA-T1_3-5c_170      22.76533       51.22149       20.16614    V6   301.5
# ERA-T1_1-2b_170      21.70019       46.58059       20.24606    V6   269.4
# ERA-T1_1-4b_0        13.62927       35.16869       16.51682    V6   291.6
# ERA-T1_1-4a_170      15.13109       35.43456       17.35626    V6   454.8
# ERA-T1_4-4a_170      30.38742       49.07651       23.80746    V6  1324.2
# ERA-T1_2-2b_85       27.69335       51.80574       25.78346    V6   310.5
#                 FracN.leco FracC.leco    kgN_ha        RGR       AGR     Nprod
# ERA-T1_3-5c_170   0.025878    0.41664  7.802217 0.06068723  7.891667 1.0114646
# ERA-T1_1-2b_170   0.032903    0.40984  8.864068 0.05829206  7.000000 0.7897051
# ERA-T1_1-4b_0     0.018950    0.41287  5.525820 0.05997687  7.616667 1.3783776
# ERA-T1_1-4a_170   0.023853    0.42165 10.848344 0.06943378 12.150000 1.1199866
# ERA-T1_4-4a_170   0.028757    0.42469 38.080019 0.09217220 36.300000 0.9532558
# ERA-T1_2-2b_85    0.020809    0.41495  6.461195 0.06131306  8.141667 1.2600869
#                      NupR d15N X15N_AtPercent FracN FracN_fromSoil
# ERA-T1_3-5c_170 0.1598961   NA             NA    NA             NA
# ERA-T1_1-2b_170 0.1824887   NA             NA    NA             NA
# ERA-T1_1-4b_0   0.1114621   NA             NA    NA             NA
# ERA-T1_1-4a_170 0.2247073   NA             NA    NA             NA
# ERA-T1_4-4a_170 0.8041047   NA             NA    NA             NA
# ERA-T1_2-2b_85  0.1313637   NA             NA    NA             NA
#                 FracN_fromFert kgFertN_ha kgSoilN_ha R_Year.c        PC1
# ERA-T1_3-5c_170             NA         NA         NA        4 -0.5656300
# ERA-T1_1-2b_170             NA         NA         NA        4 -0.7641802
# ERA-T1_1-4b_0               NA         NA         NA       66  1.5180471
# ERA-T1_1-4a_170             NA         NA         NA       18  0.9178837
# ERA-T1_4-4a_170             NA         NA         NA       49 -2.4564372
# ERA-T1_2-2b_85              NA         NA         NA       36 -2.2770759
#                        PC2          PC3
# ERA-T1_3-5c_170 -0.3764814  0.654006934
# ERA-T1_1-2b_170  0.2270041 -0.250054804
# ERA-T1_1-4b_0   -0.2014132 -0.096060497
# ERA-T1_1-4a_170  0.1949304 -0.521914251
# ERA-T1_4-4a_170  1.0635800 -0.195162596
# ERA-T1_2-2b_85   0.2436603  0.006063973

# %%
# %%R
# TM_Fit = TM_Fit %>% mutate(R_Year.f = factor(R_Year))
# m1 = lmer(PC1~R_Year.f*Fert + (1|Rep) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos),  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.f*Fert + (1|Rep) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos),  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.f      12.2999 2.45999     5 13.172 1.09986 0.4058
# Fert           1.7075 0.85377     2  4.091 0.38172 0.7047
# R_Year.f:Fert 17.2148 1.72148    10 29.413 0.76968 0.6561
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#               Sum Sq Mean Sq NumDF   DenDF F.value Pr(>F)
# R_Year.f      1.6519 0.33037     5 13.2048 0.91867 0.4987
# Fert          0.1883 0.09417     2  3.6588 0.26187 0.7829
# R_Year.f:Fert 3.6695 0.36695    10 28.7249 1.02039 0.4511

# %% [markdown]
# # plot treatment effects on enzymes at T1

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Genotype.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "R_Year.f")
# Genotype.lsm.df
# Out:
#   R_Year.f Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1     1939   -0.1136241 0.7501762     -1.7230133       1.495765  -0.21803778
# 2     1953   -0.6820073 0.7305284     -2.2642506       0.900236  -0.23437141
# 3     1971   -0.5319048 0.7503326     -2.1414492       1.077640  -0.05418978
# 4     1984    1.0037435 0.7473006     -0.6298681       2.637355   0.15290757
# 5     2001    0.5272584 0.7654807     -1.1317685       2.186285  -0.08539866
# 6     2011   -0.1309980 0.7285985     -1.7059184       1.443922   0.31258654
#    Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1 0.2254893     -0.7188322      0.2827567
# 2 0.2164312     -0.7230826      0.2543398
# 3 0.2254363     -0.5548775      0.4464979
# 4 0.2216645     -0.3697194      0.6755345
# 5 0.2299003     -0.6153784      0.4445811
# 6 0.2157921     -0.1703558      0.7955289

# %%
# %%R -w 400 -h 200
#
# pG.1 = ggplot(Genotype.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, color = R_Year.f)) +
#     scale_color_manual(values = GenotypeColors_sub6) +
#     scale_fill_manual(values = GenotypeColors_sub6) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = R_Year.f),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE, color = R_Year.f),
#                 height = .002) +
#     geom_point(aes(fill = R_Year.f), color = "black", shape = 21, size = 2)+#pch = 21, color = "black")+
#     theme(legend.position = "bottom")+
#     guides(fill = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     guides(color = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")#
# pG.1  %>% print
# pG.1 = pG.1 + theme(legend.position = "none")

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~Fert) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(Fert,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~Fert) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(Fert,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Fert.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "Fert")
# Fert.lsm.df
# Out:
#   Fert Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1    0   -0.1316833 0.5792658      -1.532129       1.268762   0.01438211
# 2   85   -0.1313460 0.5736456      -1.529538       1.266846   0.01854114
# 3  170    0.2992631 0.5688673      -1.100163       1.698689  -0.09617502
#    Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1 0.1566350     -0.4389971      0.4677614
# 2 0.1537348     -0.4421631      0.4792454
# 3 0.1509315     -0.5688383      0.3764883

# %%
# %%R -w 400 -h 200
# pF.1 = ggplot(Fert.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, color = Fert)) +
#     scale_color_manual(values = FertColors)+
#     scale_fill_manual(values = FertColors)+
#     theme_pub()+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = Fert),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE, color = Fert),
#                 height = .002) +
#      geom_point(aes(fill = Fert), color = "black", shape = 21, size = 2)+#pch = 21, color = "black")+
#     theme(legend.position = "bottom")+
#     guides(fill = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     guides(color = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")#
# pF.1 %>% print
# pF.1 = pF.1 +     theme(legend.position = "none")

# %%
# %%R
# pA.1 = ggplot() +
#     geom_segment(arrow_map,
#     #size = .5,
#     data = arrowdf,
#     color = "black",
#     arrow = arrowhead
#     ) +
# geom_text(label_map,
#     data = arrowdf,
#     show_guide = FALSE, size = 5) +
#     theme_pub()
#     #theme(axis.text = element_blank())
# pA.1

# %%
# %%R -w 700 -h 250
# grid.arrange(pG.1, pF.1, pA.1, ncol = 3, widths = c(2,1,1))

# %%
# %%R
# TM_Fit = TM_Fit %>%
#     mutate(R_Year.c = R_Year - 1935)
# m1 = lmer(PC1~R_Year.c *Fert + (1|Rep) + (1|Genotype) + (1|Rep:Row:Pos) + (1|Pos:Fert),  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.c * Fert + (1|Rep) + (1|Genotype) + (1|Rep:Row:Pos) + (1|Pos:Fert),  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#               Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.c      2.9665 2.96649     1  3.921 1.29385 0.3200
# Fert          2.0774 1.03869     2 28.875 0.45303 0.6401
# R_Year.c:Fert 1.4069 0.70345     2 40.443 0.30681 0.7375
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.c      1.40646 1.40646     1  3.844  4.0025 0.1189
# Fert          0.05422 0.02711     2 29.179  0.0772 0.9259
# R_Year.c:Fert 0.26546 0.13273     2 40.342  0.3777 0.6878

# %% [markdown]
# ## DESeq of T1 enzymes

# %%
# %%R
# sample_data(physeq.plant.t1)$Rep = as.factor(sample_data(physeq.plant.t1)$Rep)
# sample_data(physeq.plant.t1)$Fert = as.factor(sample_data(physeq.plant.t1)$Fert)
# sample_data(physeq.plant.t1)$ERA = as.factor(sample_data(physeq.plant.t1)$ERA)
# sample_data(physeq.plant.t1)$R_Year.c = sample_data(physeq.plant.t1)$R_Year - 1935

# %%
# %%R
# t.df = tax_table(physeq.plant.t1) %>% as.data.frame()
# t.df = t.df %>% mutate(OTU = row.names(t.df))

# %%
# %%R
# tmp.1 = subset_samples(physeq.plant.t1, !is.na(PC1))
# dds = phyloseq_to_deseq2(tmp.1, ~Rep + PC1 + PC2)
# d_dds = DESeq(dds, parallel = TRUE)
# resultsNames(d_dds) %>% print
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: converting counts to integer mode
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: estimating size factors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: estimating dispersions
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: gene-wise dispersion estimates: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: mean-dispersion relationship
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: final dispersion estimates, MLE betas: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: fitting model and testing: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# [1] "Intercept" "Rep1"      "Rep2"      "Rep3"      "Rep4"      "PC1"
# [7] "PC2"

# %%
# %%R
# EnzRes = results(d_dds, name="PC1", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(EnzRes) %>% print
# plotMA(EnzRes)
#
# EnzRes$OTU = rownames(EnzRes)
# df_pc1 = EnzRes %>% as.data.frame()
# df_pc1 = left_join(df_pc1, t.df, by = "OTU")
# Out:
# out of 4582 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 2, 0.044%
# LFC < 0 (down)   : 12, 0.26%
# outliers [1]     : 0, 0%
# low counts [2]   : 3197, 70%
# (mean count < 3)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# NULL

# %%
# %%R
# #Normalized counts per sample:
# df_pc1 %>%
#     #group_by(Plant) %>%
#     summarize(Ndepth = sum(baseMean)) %>%
#     .$Ndepth %>%
#     unique() %>%
# paste(.,"normalized reads at T1") %>% print
# Out:
# [1] "30051.7181892838 normalized reads at T1"

# %%
# %%R

# dds = phyloseq_to_deseq2(tmp.1, ~Rep + PC2)
# d_dds = DESeq(dds, parallel = TRUE)
# resultsNames(d_dds) %>% print

# %%
# %%R
# EnzRes = results(d_dds, name="PC2", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(EnzRes) %>% print
# plotMA(EnzRes)
#
# EnzRes$OTU = rownames(EnzRes)
# df_pc2 = EnzRes %>% as.data.frame()
# df_pc2 = left_join(df_pc2, t.df, by = "OTU")
# Out:
# out of 4582 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 0, 0%
# LFC < 0 (down)   : 0, 0%
# outliers [1]     : 0, 0%
# low counts [2]   : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# NULL

# %%
# %%R
# df_pc1$test = "EnzPCA1"
# df_pc2$test = "EnzPCA2"
# df_enz = bind_rows(df_pc1, df_pc2)

# %%
# %%R
# sigtab = df_enz %>% filter(padj < 0.05)
# x = tapply(sigtab$log2FoldChange, sigtab$Rank4, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank4 = factor(as.character(sigtab$Rank4), levels=names(x))
# # x = tapply(sigtab$log2FoldChange, sigtab$Rank3, function(x) max(x))
# # x = sort(x, TRUE)
# # sigtab$Rank3 = factor(as.character(sigtab$Rank3), levels=names(x))
#
# p2 = ggplot(sigtab, aes(x=Rank4, y=log2FoldChange, size = baseMean)) +
#     geom_point(aes(color = Rank2))+
#  # theme_pub() +
#   theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5)) +
#     ggtitle("OTUs correlated with the primary axis of Enzyme ordination")  +
#    theme(legend.position="right") +
#     facet_wrap(~test, ncol = 1, scales = 'free_y')
# #x = tapply(sigtab$log2FoldChange, sigtab$Rank2, function(x) max(x))
# #x = sort(x, TRUE)
# #x
#
#     p2

# %%
# %%R
# write.csv(sigtab, file = '/home/bryan/ERA/data/MiSeq/20170417_run1/DESeq2/l2f_enzyme_t1_sig.csv', row.names = FALSE)

# %% [markdown]
# ## T2

# %%
# %%R
# physeq.plant.t2 = subset_samples(physeq.Full, TimePoint == "T2" & Genotype != "Bare")
# physeq.plant.t2
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 64 samples ]
# sample_data() Sample Data:       [ 64 samples by 47 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %%
# %%R
# # # PCA of enzymes
# sd = as(sample_data(physeq.plant.t2), "data.frame")
# rownames(sd) = sd$X.sample
#
#
# fit = prcomp(~BG_activity.g  + CB_activity.g + LAP_activity.g + NAG_activity.g, data = sd,
#                  na.action = na.exclude, center = TRUE, scale = TRUE)
#
# summary(fit) %>% print
# fit$rotation %>% print
# biplot(fit)
#
# S = predict(fit)[,1:3]
# TM_Fit = cbind(sd, S)
# rownames(TM_Fit) = TM_Fit$X.sample
# sample_data(physeq.plant.t2) = TM_Fit
# Out:
# Importance of components:
#                           PC1    PC2    PC3     PC4
# Standard deviation     1.6354 0.8607 0.6522 0.39912
# Proportion of Variance 0.6686 0.1852 0.1063 0.03982
# Cumulative Proportion  0.6686 0.8538 0.9602 1.00000
#                       PC1         PC2        PC3        PC4
# BG_activity.g  -0.5043251  0.48760405 -0.4854776 -0.5217374
# CB_activity.g  -0.5737849  0.04915661 -0.2050679  0.7913922
# LAP_activity.g -0.4008918 -0.86036348 -0.1507576 -0.2762835
# NAG_activity.g -0.5056806  0.14000213  0.8363796 -0.1586057

# %%
# %%R
#
#
# # Now add the environmental variables as arrows
# arrowmat <- vegan::scores(fit, display = "species")
#
# rownames(arrowmat) = c("BG", "CB", "LAP", "NAG")
# #rownames(arrowmat) = c("BX", "CB", "LAP", "NAG")
#
# # Add labels, make a data.frame
# arrowdf <- data.frame(labels = rownames(arrowmat), arrowmat)
#
# # Define the arrow aesthetic mapping
# arrow_map <- aes(xend = PC1,
#     yend = PC2,
#     x = 0,
#     y = 0,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# label_map <- aes(x = 1.1 * PC1,
#     y = 1.1 * PC2,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# arrowhead = arrow(length = unit(0.02, "npc"))

# %%
# %%R
# p = ggplot(TM_Fit, aes(PC1, PC2, color = Genotype,
#                        size = 12), pch = 21)
# p = p + geom_point()
# p = p + scale_colour_brewer(palette="Paired")
# p = p + ggtitle("PCA of enzyme activity")
#
#
#
# p

# %% [markdown]
# ## Treatment effects at T2

# %%
# %%R
# sub  = TM_Fit %>% filter(SeedTreatment != "Untreated") %>%
# mutate(R_Year.f = factor(R_Year))
# m1 = lmer(PC1~R_Year.f  + (1|Rep),  data = sub, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.f  + (1|Rep),  data = sub, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#          Sum Sq Mean Sq NumDF DenDF F.value  Pr(>F)
# R_Year.f 36.876  3.3523    11    33  2.2795 0.03334 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#          Sum Sq Mean Sq NumDF DenDF F.value Pr(>F)
# R_Year.f  3.486 0.31691    11    33 0.28752  0.984

# %% [markdown]
# ### Plot treatments at T2

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Genotype.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "R_Year.f")
# Genotype.lsm.df
# Out:
#    R_Year.f Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1      1936  -0.10529878 0.7481174     -1.6938107      1.4832131   0.26822699
# 2      1939   0.59785381 0.7481174     -0.9906581      2.1863657   0.04774559
# 3      1942   0.58307682 0.7481174     -1.0054351      2.1715887   0.37985136
# 4      1953  -0.51524792 0.7481174     -2.1037598      1.0732640  -0.31484662
# 5      1961   0.33460341 0.7481174     -1.2539085      1.9231153  -0.20548694
# 6      1971  -2.09555529 0.7481174     -3.6840672     -0.5070434  -0.25318442
# 7      1975  -1.04868772 0.7481174     -2.6371996      0.5398242  -0.26879142
# 8      1984   1.29600207 0.7481174     -0.2925098      2.8845140   0.41371343
# 9      1991  -0.01915973 0.7481174     -1.6076716      1.5693522  -0.30806755
# 10     2001   0.75855539 0.7481174     -0.8299565      2.3470673   0.16815747
# 11     2003   0.63427872 0.7481174     -0.9542332      2.2227906  -0.26710759
# 12     2011   0.02101181 0.7481174     -1.5675001      1.6095237  -0.17893712
#     Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1  0.5249282     -0.7963768      1.3328307
# 2  0.5249282     -1.0168582      1.1123493
# 3  0.5249282     -0.6847524      1.4444551
# 4  0.5249282     -1.3794504      0.7497571
# 5  0.5249282     -1.2700907      0.8591168
# 6  0.5249282     -1.3177882      0.8114193
# 7  0.5249282     -1.3333952      0.7958123
# 8  0.5249282     -0.6508903      1.4783172
# 9  0.5249282     -1.3726713      0.7565362
# 10 0.5249282     -0.8964463      1.2327612
# 11 0.5249282     -1.3317113      0.7974962
# 12 0.5249282     -1.2435409      0.8856666

# %%
# %%R -w 400 -h 200
# pG.2 = ggplot(Genotype.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, color = R_Year.f)) +
#     scale_color_manual(values = GenotypeColors)+
#     scale_fill_manual(values = GenotypeColors)+
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = R_Year.f),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE,
#                        color = R_Year.f),
#                 height = .002) +
#     geom_point(aes(fill = R_Year.f), color = "black", shape = 21, size = 2)+#pch = 21, color = "black")+
#     theme(legend.position = "bottom")+
#     guides(fill = guide_legend(title = NULL, title.position = NULL, ncol = 6))+
#     guides(color = guide_legend(title = NULL, title.position = NULL, ncol = 6))+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2") #
#
# GenLeg = g_legend(pG.2)
# pG.2 = pG.2 + theme(legend.position = "none")
# pG.2

# %%
# %%R
# pA = ggplot() +
#     geom_segment(arrow_map,
#     #size = .5,
#     data = arrowdf,
#     color = "black",
#     arrow = arrowhead
#     ) +
# geom_text(label_map,
#     data = arrowdf,
#     show_guide = FALSE, size = 5) +
#     theme_pub()
#     #theme(axis.text = element_blank())
# pA
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Warning:
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Ignoring unknown aesthetics: shape, label
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Ignoring unknown aesthetics: shape
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R -w 700 -h 300
# require(cowplot)
# TopRow = plot_grid(pG.2, pA, ncol = 2, rel_widths = c(4,2))
# grid.arrange(TopRow, GenLeg, ncol = 1, heights = c(5,.5))

# %%
# %%R
# svg(filename = '/home/bryan/ERA/data/figures/ms_versions/Figure7_diss.svg', width = 6.5, height = 3.2)
# grid.arrange(TopRow, GenLeg, ncol = 1, heights = c(5,1))
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# svg(filename = '/home/bryan/ERA/data/figures/ms_versions/Figure7_ms.svg', width = 7.086, height = 3.2)
# grid.arrange(TopRow, GenLeg, ncol = 1, heights = c(5,1))
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# * Test year of release

# %%
# %%R
# #TM_Fit = TM_Fit %>%
#  #   mutate(R_Year.c = R_Year - 1935)
# sub  = TM_Fit %>% filter(SeedTreatment != "Untreated")
# m1 = lmer(PC1~R_Year.c + (1|Rep) + (1|Genotype),  data = sub, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.c  + (1|Rep) + (1|Genotype),  data = sub, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#           Sum Sq Mean Sq NumDF DenDF F.value Pr(>F)
# R_Year.c 0.18089 0.18089     1    10   0.123 0.7331
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#           Sum Sq Mean Sq NumDF DenDF F.value Pr(>F)
# R_Year.c 0.35777 0.35777     1    10 0.38445 0.5491

# %%
# %%R
# #TM_Fit = TM_Fit %>%
#  #   mutate(R_Year.c = R_Year - 1935)
# sub  = TM_Fit %>% filter(SeedTreatment != "Untreated")
# m1 = lmer(PC1~poly(R_Year.c,2) + (1|Rep) + (1|Genotype),  data = sub, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~poly(R_Year.c,2)  + (1|Rep) + (1|Genotype),  data = sub, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                   Sum Sq Mean Sq NumDF DenDF F.value Pr(>F)
# poly(R_Year.c, 2) 2.5166  1.2583     2     9 0.85562 0.4569
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                    Sum Sq Mean Sq NumDF DenDF F.value Pr(>F)
# poly(R_Year.c, 2) 0.67861 0.33931     2     9 0.35938 0.7077

# %% [markdown]
# * Genotype effect, but no relationship to year of releaese.
# * Also checked polynomial with year of release, but no  dice

# %% [markdown]
# ### check seed treatment

# %%
# %%R
# TM_Fit$Plant %>% levels
# Out:
#  [1] "1936"  "1936U" "1939"  "1942"  "1953"  "1953U" "1961"  "1971"  "1975"
# [10] "1984"  "1984U" "1991"  "2001"  "2003"  "2003U" "2011"

# %%
# %%R
#
# sub  = TM_Fit %>% filter(Genotype %in%  c("1936", "1953", "1984", "2003")) %>%
# mutate(R_Year.f = factor(R_Year))
# mT1 = lmer(PC1~R_Year.f*SeedTreatment  + (1|Rep),  data = sub, na.action = na.exclude)
#   print("Enz1")
#   anova(mT1, ddf = "Kenward-Roger") %>% print
#
# mT2 = lmer(PC2~R_Year.f*SeedTreatment  + (1|Rep),  data = sub, na.action = na.exclude)
#   print("Enz2")
#   anova(mT2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                        Sum Sq Mean Sq NumDF DenDF F.value Pr(>F)
# R_Year.f               1.6992 0.56641     3    21 0.16840 0.9165
# SeedTreatment          1.5333 1.53329     1    21 0.45585 0.5069
# R_Year.f:SeedTreatment 7.8971 2.63237     3    21 0.78261 0.5169
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                         Sum Sq Mean Sq NumDF DenDF F.value Pr(>F)
# R_Year.f               2.58792 0.86264     3    21 1.16880 0.3452
# SeedTreatment          0.08767 0.08767     1    21 0.11879 0.7338
# R_Year.f:SeedTreatment 0.35612 0.11871     3    21 0.16084 0.9215

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(mT1, pairwise~R_Year.f|SeedTreatment) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#
# select(R_Year.f,SeedTreatment,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[3:6] = paste("Axis1", colnames(Axis1.lsm.df)[3:6], sep = ".")
#
# Axis2.lsm.df = lsmeans(mT2, pairwise~R_Year.f|SeedTreatment) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f, SeedTreatment,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[3:6] = paste("Axis2", colnames(Axis2.lsm.df)[3:6], sep = ".")
#
# Genotype.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = c("R_Year.f", "SeedTreatment"))
# Genotype.lsm.df
# Out:
#   R_Year.f SeedTreatment Axis1.lsmean Axis1.SE Axis1.lower.CL Axis1.upper.CL
# 1     1936       Treated   -0.1052988  0.93531     -2.0367591       1.826162
# 2     1953       Treated   -0.5152479  0.93531     -2.4467082       1.416212
# 3     1984       Treated    1.2960021  0.93531     -0.6354582       3.227462
# 4     2003       Treated    0.6342787  0.93531     -1.2971816       2.565739
# 5     1936     Untreated    0.3566231  0.93531     -1.5748372       2.288083
# 6     1953     Untreated    0.0789864  0.93531     -1.8524739       2.010447
# 7     1984     Untreated   -0.4302928  0.93531     -2.3617531       1.501168
# 8     2003     Untreated   -0.4467493  0.93531     -2.3782096       1.484711
#   Axis2.lsmean  Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1  0.268226988 0.4295516     -0.6183239      1.1547778
# 2 -0.314846624 0.4295516     -1.2013975      0.5717042
# 3  0.413713429 0.4295516     -0.4728374      1.3002643
# 4 -0.267107587 0.4295516     -1.1536584      0.6194433
# 5  0.020098288 0.4295516     -0.8664526      0.9066491
# 6 -0.006776401 0.4295516     -0.8933273      0.8797745
# 7  0.616042028 0.4295516     -0.2705088      1.5025929
# 8 -0.110637086 0.4295516     -0.9971879      0.7759138

# %%
# %%R -w 300 -h 250
# # Flip axis 1 for consistency with T1
# library(RColorBrewer)
# TreatmentColors = brewer.pal(3, 'Dark2')
# pG.ST = ggplot(Genotype.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, label = R_Year.f, color = SeedTreatment)) +
# #     scale_color_manual(values = GenotypeColors)+
# #     scale_fill_manual(values = GenotypeColors)+
#     theme_pub()+
#     scale_color_manual(values = TreatmentColors) +
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE), color = "black",
#                  width = .002) +
#      geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE),color = "black",
#                height = .002) +
#     geom_label(aes(color = SeedTreatment)) +
#    #geom_point(aes(fill = SeedTreatment), color = "black", shape = 21, size = 2)+#pch = 21, color = "black")+
#     theme(legend.position = "bottom")+
#     guides(fill = guide_legend(title = NULL, title.position = NULL, ncol = 4))+
#     guides(color = guide_legend(title = NULL, title.position = NULL, ncol = 4))+
#
#     geom_point()+
#     #scale_color_manual(values = TreatmentColors)+
# #     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
# #                 color = "black",
# #                 width = .002) +
# #     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
# #                 height = .002)+
#     geom_label(aes(color = SeedTreatment)) +
#     theme(legend.position = "bottom") +
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")
#
# TreatedLegend = g_legend(pG.ST)
# pG.ST = pG.ST + theme(legend.position = "none")
#
# pG.ST %>% print

# %%
# %%R -w 325 -h 325
# grid.arrange(pG.ST, TreatedLegend, ncol = 1, heights = c(2.8, .45))

# %%
# %%R
# svg(filename = '/home/bryan/ERA/data/figures/ms_versions/SeedTreatment_Enzymes.svg', width = 3.14, height = 3.14)
# print(pG.ST)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## DESeq of T2 enzymes

# %%
# %%R
# sample_data(physeq.plant.t2)$Rep = as.factor(sample_data(physeq.plant.t2)$Rep)
# sample_data(physeq.plant.t2)$Fert = as.factor(sample_data(physeq.plant.t2)$Fert)
# sample_data(physeq.plant.t2)$ERA = as.factor(sample_data(physeq.plant.t2)$ERA)
# sample_data(physeq.plant.t2)$R_Year.c = sample_data(physeq.plant.t2)$R_Year - 1935

# %%
# %%R
# t.df = tax_table(physeq.plant.t2) %>% as.data.frame()
# t.df = t.df %>% mutate(OTU = row.names(t.df))

# %%
# %%R
# phy.tmp = physeq.plant.t2 %>% subset_samples(SeedTreatment != "Untreated")
# dds = phyloseq_to_deseq2(phy.tmp, ~Rep + PC1 + PC2)
# d_dds = DESeq(dds, parallel = TRUE)
# resultsNames(d_dds) %>% print
# phy.tmp = NULL
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: converting counts to integer mode
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: estimating size factors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: estimating dispersions
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: gene-wise dispersion estimates: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: mean-dispersion relationship
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: final dispersion estimates, MLE betas: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: fitting model and testing: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# [1] "Intercept" "Rep1"      "Rep2"      "Rep3"      "Rep4"      "PC1"
# [7] "PC2"

# %%
# %%R
# EnzRes = results(d_dds, name="PC1", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(EnzRes) %>% print
# plotMA(EnzRes)
#
# EnzRes$OTU = rownames(EnzRes)
# df_pc1 = EnzRes %>% as.data.frame()
# df_pc1 = left_join(df_pc1, t.df, by = "OTU")
# Out:
# out of 4589 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 0, 0%
# LFC < 0 (down)   : 1, 0.022%
# outliers [1]     : 0, 0%
# low counts [2]   : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# NULL

# %%
# %%R
# #Normalized counts per sample:
# df_pc1 %>%
#     #group_by(Plant) %>%
#     summarize(Ndepth = sum(baseMean)) %>%
#     .$Ndepth %>%
#     unique() %>%
# paste(.,"normalized reads at T2") %>% print
# Out:
# [1] "31964.6608886275 normalized reads at T2"

# %%
#%%R

# dds = phyloseq_to_deseq2(physeq.plant.t2, ~PC2)
# d_dds = DESeq(dds, parallel = TRUE)
# resultsNames(d_dds) %>% print

# %%
# %%R
# EnzRes = results(d_dds, name="PC2", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(EnzRes) %>% print
# plotMA(EnzRes)
#
# EnzRes$OTU = rownames(EnzRes)
# df_pc2 = EnzRes %>% as.data.frame()
# df_pc2 = left_join(df_pc2, t.df, by = "OTU")
# Out:
# out of 4589 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 1, 0.022%
# LFC < 0 (down)   : 0, 0%
# outliers [1]     : 0, 0%
# low counts [2]   : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# NULL

# %%
# %%R
# df_pc1$test = "EnzPCA1"
# df_pc2$test = "EnzPCA2"
# df_enz = bind_rows(df_pc1, df_pc2)

# %%
# %%R
# sigtab = df_enz %>% filter(padj < 0.05)
# x = tapply(sigtab$log2FoldChange, sigtab$Rank4, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank4 = factor(as.character(sigtab$Rank4), levels=names(x))
# # x = tapply(sigtab$log2FoldChange, sigtab$Rank3, function(x) max(x))
# # x = sort(x, TRUE)
# # sigtab$Rank3 = factor(as.character(sigtab$Rank3), levels=names(x))
#
# p2 = ggplot(sigtab, aes(x=Rank4, y=log2FoldChange, size = baseMean)) +
#     geom_point(aes(color = Rank2))+
#  # theme_pub() +
#   theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5)) +
#     ggtitle("OTUs correlated with the primary axis of Enzyme ordination")  +
#    theme(legend.position="right") +
#     facet_wrap(~test, ncol = 1, scales = 'free_y')
# #x = tapply(sigtab$log2FoldChange, sigtab$Rank2, function(x) max(x))
# #x = sort(x, TRUE)
# #x
#
#     p2

# %%
# %%R
# write.csv(sigtab, file = '/home/bryan/ERA/data/MiSeq/20170417_run1/DESeq2/l2f_enzyme_t2_sig.csv', row.names = FALSE)

# %% [markdown]
# ## Enzyme ordination at T3

# %%
# %%R
# physeq.plant.t3 = subset_samples(physeq.plant, TimePoint == "T3")
# physeq.plant.t3
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 72 samples ]
# sample_data() Sample Data:       [ 72 samples by 47 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %%
# %%R
# # # PCA of enzymes
# sd = as(sample_data(physeq.plant.t3), "data.frame")
# rownames(sd) = sd$X.sample
#
#
# fit = prcomp(~BG_activity.g + CB_activity.g + LAP_activity.g + NAG_activity.g, data = sd,
#                  na.action = na.exclude, center = TRUE, scale = TRUE)
#
#
# # Flip second axis for ease of interpretation
# fit$rotation[,"PC2"] = fit$rotation[,"PC2"] * -1
# fit$x[,"PC2"] = fit$x[,"PC2"] * -1
# fit$rotation %>% print
#
# summary(fit) %>% print
#
#
# biplot(fit)
#
# S = predict(fit)[,1:3]
# TM_Fit = cbind(sd, S)
# rownames(TM_Fit) = TM_Fit$X.sample
# sample_data(physeq.plant.t3) = TM_Fit
# Out:
#                       PC1         PC2         PC3        PC4
# BG_activity.g  -0.5730204 -0.06398277 -0.68969419  0.4380362
# CB_activity.g  -0.5918057  0.04136671 -0.02321411 -0.8046838
# LAP_activity.g -0.2266984 -0.90510393  0.34238040  0.1103194
# NAG_activity.g -0.5196359  0.41830836  0.63761955  0.3852765
# Importance of components:
#                           PC1    PC2     PC3     PC4
# Standard deviation     1.6225 1.0105 0.47848 0.34303
# Proportion of Variance 0.6581 0.2553 0.05724 0.02942
# Cumulative Proportion  0.6581 0.9133 0.97058 1.00000

# %%
# %%R
# # Now add the environmental variables as arrows
# arrowmat <- vegan::scores(fit, display = "species")
#
# rownames(arrowmat) = c("BG", "CB", "LAP", "NAG")
# #rownames(arrowmat) = c("BX", "CB", "LAP", "NAG")
#
# # Add labels, make a data.frame
# arrowdf <- data.frame(labels = rownames(arrowmat), arrowmat)
#
# # Define the arrow aesthetic mapping
# arrow_map <- aes(xend = PC1,
#     yend = PC2,
#     x = 0,
#     y = 0,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# label_map <- aes(x = 1.1 * PC1,
#     y = 1.1 * PC2,
#     shape = NULL,
#     color = NULL,
#     label = labels)
#
# arrowhead = arrow(length = unit(0.02, "npc"))
#
# pA.3 = ggplot() +
#     geom_segment(arrow_map,
#     #size = .5,
#     data = arrowdf,
#     color = "black",
#     arrow = arrowhead
#     ) +
# geom_text(label_map,
#     data = arrowdf,
#     show_guide = FALSE, size = 5) +
#     theme_pub()
#     #theme(axis.text = element_blank())
# pA.3
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Warning:
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Ignoring unknown aesthetics: shape, label
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Ignoring unknown aesthetics: shape
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R
# p = ggplot(TM_Fit, aes(PC1, PC2, color = Fert,
#                        size = 12), pch = 21)
# p = p + geom_point()
# p = p + scale_colour_brewer(palette="Paired")
# p = p + ggtitle("PCA of enzyme activity at T3")
# p

# %% [markdown]
# ## Treatment effects at T3

# %%
# %%R
# TM_Fit = mutate(TM_Fit, R_Year.f = factor(R_Year))
# m1 = lmer(PC1~R_Year.f*Fert + (1|Rep) + (1|Pos) + (1|Rep:Row:Pos) + (1|Pos:Fert),  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.f*Fert + (1|Rep) + (1|Pos) + (1|Rep:Row:Pos) + (1|Pos:Fert),  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                Sum Sq Mean Sq NumDF   DenDF F.value Pr(>F)
# R_Year.f       6.8442  1.3688     5 12.8672 0.58906 0.7087
# Fert          14.2664  7.1332     2  3.6463 3.06968 0.1653
# R_Year.f:Fert  8.8241  0.8824    10 31.5180 0.37973 0.9463
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#               Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.f      2.7253 0.54506     5 13.056 1.22474 0.3518
# Fert          1.5792 0.78959     2  4.529 1.77418 0.2698
# R_Year.f:Fert 4.1215 0.41215    10 32.471 0.92609 0.5224

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~R_Year.f) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(R_Year.f,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Genotype.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "R_Year.f")
# Genotype.lsm.df
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: NOTE: Results may be misleading due to involvement in interactions
#
#   warnings.warn(x, RRuntimeWarning)
#   R_Year.f Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1     1939  -0.46803394 0.5620614     -1.6709566      0.7348887    0.1250817
# 2     1953   0.10362021 0.5620648     -1.0994283      1.3066687   -0.2451854
# 3     1971  -0.14047972 0.5620608     -1.3433800      1.0624206   -0.6196165
# 4     1984   0.78234746 0.5627121     -0.4366232      2.0013182    0.2069887
# 5     2001  -0.02330861 0.5627121     -1.2422793      1.1956621    0.4435681
# 6     2011  -0.24359374 0.5620590     -1.4464293      0.9592418    0.1300770
#    Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1 0.4224879     -0.8104603      1.0606236
# 2 0.4226686     -1.1809539      0.6905830
# 3 0.4224564     -1.5550970      0.3158641
# 4 0.4262563     -0.7339240      1.1479015
# 5 0.4262563     -0.4973447      1.3844808
# 6 0.4223917     -0.8053694      1.0655233

# %%
# %%R -w 400 -h 200
# #reverse both axes to match T1
# pG.3 = ggplot(Genotype.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, color = R_Year.f)) +
#  scale_color_manual(values = GenotypeColors_sub6) +
#     scale_fill_manual(values = GenotypeColors_sub6) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = R_Year.f),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE, color = R_Year.f),
#                 height = .002) +
#     geom_point(aes(fill = R_Year.f), color = "black", shape = 21, size = 2)+#pch = 21, color = "black")+
#     theme(legend.position = "none")+
#     guides(fill = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     guides(color = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")#
# pG.3

# %%
# %%R
# #Generate lsmeans for Axes1
#
# Axis1.lsm.df = lsmeans(m1, pairwise~Fert) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(Fert,lsmean,SE, lower.CL, upper.CL)
#
# colnames(Axis1.lsm.df)[2:5] = paste("Axis1", colnames(Axis1.lsm.df)[2:5], sep = ".")
#
# Axis2.lsm.df = lsmeans(m2, pairwise~Fert) %>%
#         summary %>%
#         .$lsmeans %>%
#         as.data.frame() %>%
#         select(Fert,lsmean, SE, lower.CL, upper.CL)
#
# colnames(Axis2.lsm.df)[2:5] = paste("Axis2", colnames(Axis2.lsm.df)[2:5], sep = ".")
#
# Fert.lsm.df = full_join(Axis1.lsm.df, Axis2.lsm.df, by = "Fert")
# Fert.lsm.df
# Out:
#   Fert Axis1.lsmean  Axis1.SE Axis1.lower.CL Axis1.upper.CL Axis2.lsmean
# 1    0    0.4841017 0.4036072     -0.5094378      1.4776412   0.23878029
# 2   85    0.1296070 0.4036072     -0.8639325      1.1231465  -0.28970361
# 3  170   -0.6084329 0.4036072     -1.6019724      0.3851066   0.07138009
#    Axis2.SE Axis2.lower.CL Axis2.upper.CL
# 1 0.3475786     -0.6374187      1.1149793
# 2 0.3475786     -1.1659026      0.5864954
# 3 0.3475786     -0.8048189      0.9475791

# %%
# %%R -w 400 -h 200
# pF.3 = ggplot(Fert.lsm.df, aes(x = Axis1.lsmean, y = Axis2.lsmean, color = Fert)) +
#   scale_color_manual(values = FertColors)+
#     scale_fill_manual(values = FertColors)+
#     theme_pub()+
#     geom_errorbar(aes(ymin = Axis2.lsmean - Axis2.SE, ymax = Axis2.lsmean + Axis2.SE, color = Fert),
#                 width = .002) +
#     geom_errorbarh(aes(xmin = Axis1.lsmean - Axis1.SE, xmax = Axis1.lsmean + Axis1.SE, color = Fert),
#                 height = .002) +
#      geom_point(aes(fill = Fert), color = "black", shape = 21, size = 2)+#pch = 21, color = "black")+
#     theme(legend.position = "none")+
#     guides(fill = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     guides(color = guide_legend(title = NULL, title.position = NULL, ncol = 3))+
#     xlab("Enzyme Axis 1")+
#     ylab("Enzyme Axis 2")#
# pF.3

# %%
# %%R
# TM_Fit = TM_Fit %>%
#     mutate(R_Year.c = R_Year - 1935)
# m1 = lmer(PC1~R_Year.c*Fert + (1|Rep) + (1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos) ,  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~R_Year.c*Fert + (1|Rep) + (1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos) ,  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.c      0.31755 0.31755     1  3.828 0.15123 0.7180
# Fert          2.04782 1.02391     2 31.539 0.48763 0.6186
# R_Year.c:Fert 0.49497 0.24749     2 42.013 0.11786 0.8891
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# R_Year.c      0.38419 0.38419     1  3.896 0.80991 0.4203
# Fert          1.52447 0.76223     2 25.834 1.60689 0.2199
# R_Year.c:Fert 0.23704 0.11852     2 40.993 0.24986 0.7801

# %%
# %%R
# TM_Fit = TM_Fit %>%
#     mutate(R_Year.c = R_Year - 1935)
# m1 = lmer(PC1~poly(R_Year.c,2)*Fert + (1|Rep) + (1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos) ,  data = TM_Fit, na.action = na.exclude)
#   print("Enz1")
#   anova(m1, ddf = "Kenward-Roger") %>% print
#
# m2 = lmer(PC2~poly(R_Year.c,2)*Fert + (1|Rep) + (1|Genotype) + (1|Pos) + (1|Pos:Fert) + (1|Rep:Row:Pos) ,  data = TM_Fit, na.action = na.exclude)
#   print("Enz2")
#   anova(m2, ddf = "Kenward-Roger") %>% print
# Out:
# [1] "Enz1"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                         Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# poly(R_Year.c, 2)       3.6550  1.8275     2  2.934  0.8569 0.5092
# Fert                   14.3103  7.1551     2  4.870  3.3548 0.1214
# poly(R_Year.c, 2):Fert  3.1064  0.7766     4 41.130  0.3641 0.8327
# [1] "Enz2"
# Analysis of Variance Table of type III  with  Kenward-Roger
# approximation for degrees of freedom
#                         Sum Sq Mean Sq NumDF  DenDF F.value Pr(>F)
# poly(R_Year.c, 2)      0.78861 0.39430     2  2.943 0.80815 0.5251
# Fert                   2.00112 1.00056     2  5.318 2.05071 0.2187
# poly(R_Year.c, 2):Fert 0.49231 0.12308     4 40.049 0.25226 0.9066

# %% [markdown]
# ## DESeq of T3 enzymes

# %%
# %%R
# sample_data(physeq.plant.t3)$Rep = as.factor(sample_data(physeq.plant.t3)$Rep)
# sample_data(physeq.plant.t3)$Fert = as.factor(sample_data(physeq.plant.t3)$Fert)
# sample_data(physeq.plant.t3)$ERA = as.factor(sample_data(physeq.plant.t3)$ERA)
# sample_data(physeq.plant.t3)$R_Year.c = sample_data(physeq.plant.t3)$R_Year - 1935

# %%
# %%R
# t.df = tax_table(physeq.plant.t3) %>% as.data.frame()
# t.df = t.df %>% mutate(OTU = row.names(t.df))

# %%
# %%R
#
# dds = phyloseq_to_deseq2(physeq.plant.t3, ~Rep + PC1 + PC2)
# d_dds = DESeq(dds, parallel = TRUE)
# resultsNames(d_dds) %>% print
# Out:
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: converting counts to integer mode
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: estimating size factors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: estimating dispersions
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: gene-wise dispersion estimates: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: mean-dispersion relationship
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: final dispersion estimates, MLE betas: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# /home/bryan/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: fitting model and testing: 20 workers
#
#   warnings.warn(x, RRuntimeWarning)
# [1] "Intercept" "Rep1"      "Rep2"      "Rep3"      "Rep4"      "PC1"
# [7] "PC2"

# %%
# %%R
# EnzRes = results(d_dds, name="PC1", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(EnzRes) %>% print
# plotMA(EnzRes)
#
# EnzRes$OTU = rownames(EnzRes)
# df_pc1 = EnzRes %>% as.data.frame()
# df_pc1 = left_join(df_pc1, t.df, by = "OTU")
# Out:
# out of 4590 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 9, 0.2%
# LFC < 0 (down)   : 9, 0.2%
# outliers [1]     : 0, 0%
# low counts [2]   : 4004, 87%
# (mean count < 10)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# NULL

# %%
# %%R
# #Normalized counts per sample:
# df_pc1 %>%
#     #group_by(Plant) %>%
#     summarize(Ndepth = sum(baseMean)) %>%
#     .$Ndepth %>%
#     unique() %>%
# paste(.,"normalized reads at T3") %>% print
# Out:
# [1] "33535.0243078956 normalized reads at T3"

# %%
# %%R
# EnzRes = results(d_dds, name="PC2", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(EnzRes) %>% print
# plotMA(EnzRes)
#
# EnzRes$OTU = rownames(EnzRes)
# df_pc2 = EnzRes %>% as.data.frame()
# df_pc2 = left_join(df_pc2, t.df, by = "OTU")
# Out:
# out of 4590 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 0, 0%
# LFC < 0 (down)   : 0, 0%
# outliers [1]     : 0, 0%
# low counts [2]   : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# NULL

# %%
# %%R
# df_pc1$test = "EnzPCA1"
# df_pc2$test = "EnzPCA2"
# df_enz = bind_rows(df_pc1, df_pc2)

# %%
# %%R
# sigtab = df_enz %>% filter(padj < 0.05)
# x = tapply(sigtab$log2FoldChange, sigtab$Rank4, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank4 = factor(as.character(sigtab$Rank4), levels=names(x))
# # x = tapply(sigtab$log2FoldChange, sigtab$Rank3, function(x) max(x))
# # x = sort(x, TRUE)
# # sigtab$Rank3 = factor(as.character(sigtab$Rank3), levels=names(x))
#
# p2 = ggplot(sigtab, aes(x=Rank4, y=log2FoldChange, size = baseMean)) +
#     geom_point(aes(color = Rank2))+
#  # theme_pub() +
#   theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5)) +
#     ggtitle("OTUs correlated with the primary axis of Enzyme ordination")  +
#    theme(legend.position="right") +
#     facet_wrap(~test, ncol = 1, scales = 'free_y')
# #x = tapply(sigtab$log2FoldChange, sigtab$Rank2, function(x) max(x))
# #x = sort(x, TRUE)
# #x
#
#     p2

# %%
# %%R
# write.csv(sigtab, file = '/home/bryan/ERA/data/MiSeq/20170417_run1/DESeq2/l2f_enzyme_t3_sig.csv', row.names = FALSE)

# %% [markdown]
# ## Arrange figure
# * Note that axis 1 is flipped in T2 and axis 1 and 2 are flipped in T3 so that loadings all point in the same direction

# %%
# %%R
# #Fert
# tmp1 = pF.1 + theme(legend.position = "bottom")
# FertLegend = g_legend(tmp1)

# %%
# %%R -w 700 -h 500
# GridT1_3 =grid.arrange(pG.1, pF.1, pA.1, pG.3,pF.3, pA.3, ncol = 3, widths = c(2,1,1))
# ## Use code below for figure that includes R2
# #LM = rbind(c(1,1,2), c(3,3,NA), c(4,4,5))
# #grid.arrange(pG.1, pF.1, pG.2, pG.3,pF.3, ncol = 2, layout_matrix = LM , heights = c(1.5,2, 1.5))

# %%
# %%R -w 700 -h 600
# MLeg = plot_grid(STLeg, TimeLeg, GenLeg, FertLegend, ncol = 2)
# grid.arrange(GCore, GridT1_3,MLeg, ncol = 1, heights = c(1,2,.6))
# #plot_grid(TopRow, MLeg) # ncols = 1, heights = c(6,.5)

# %%
# %%R
# svg(filename = '/home/bryan/ ', width = 6.5, height = 7)
# grid.arrange(GCore, GridT1_3,MLeg, ncol = 1, heights = c(1,2,.6))
# dev.off()
# Out:
# png
#   2
