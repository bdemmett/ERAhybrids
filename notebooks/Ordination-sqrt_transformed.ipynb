# %% [markdown]
# ## Description:
#
#     A quick and dirty ordination of all OTUs

# %% [markdown]
# # Init

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# library(foreach)
# library(doParallel)
# library(gridExtra)
# library(dplyr)
# library(tidyr)
# library(vegan)
# library(DESeq2)
# library(phyloseq)
# library(lme4)
# library(lmerTest)
# library(MuMIn)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: foreach: simple, scalable parallel programming from Revolution Analytics
# Use Revolution R for scalability, fault tolerance and more.
# http://www.revolutionanalytics.com
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: iterators
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: parallel
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: permute
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: lattice
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: This is vegan 2.4-3
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: S4Vectors
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: stats4
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: BiocGenerics
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘BiocGenerics’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, xtabs
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colnames, do.call,
#     duplicated, eval, evalq, Filter, Find, get, grep, grepl, intersect,
#     is.unsorted, lapply, lengths, Map, mapply, match, mget, order,
#     paste, pmax, pmax.int, pmin, pmin.int, Position, rank, rbind,
#     Reduce, rownames, sapply, setdiff, sort, table, tapply, union,
#     unique, unsplit, which, which.max, which.min
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘S4Vectors’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     colMeans, colSums, expand.grid, rowMeans, rowSums
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: IRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘IRanges’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, regroup, slice
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomicRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomeInfoDb
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: SummarizedExperiment
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: Biobase
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘phyloseq’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:SummarizedExperiment’:
#
#     distance
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:Biobase’:
#
#     sampleNames
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:GenomicRanges’:
#
#     distance
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:IRanges’:
#
#     distance
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: Matrix
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘Matrix’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘lmerTest’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:stats’:
#
#     step
#
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R
# # set theme for ggplot
#
# theme_pub = function (base_size = 11, base_family = "Helvetica")
# {
#     theme_grey(base_size = base_size, base_family = base_family) %+replace%
#         theme(
#             axis.line.x = element_line(size = .5),
#             axis.line.y = element_line(size = .5),
#             panel.background = element_rect(fill = "white", colour = NA),
#             panel.border = element_rect(fill = NA, color = "black", size = .5),
#             panel.grid.major = element_blank(),
#             panel.grid.minor = element_blank(),
#             strip.background = element_rect(fill = "grey85",
#                 colour = "grey20"),
#             legend.key = element_rect(fill = "white",
#                 colour = NA), complete = TRUE)
#     }

# %% [markdown]
# # Loading phyloseq object

# %%
# %%R
# setwd('/home/bryan/ERA/data/MiSeq/20170417_run1/phyloseq/')

# %%
# %%R
# # loading
#
# physeq = readRDS('ERA_snorm.rds')
#
# #remove T0, not necessary
# physeq = subset_samples(physeq, !is.na(Genotype), TRUE)
# physeq = subset_samples(physeq, TimePoint != "T0")
# physeq = transform_sample_counts(physeq, sqrt)
# physeq = subset_samples(physeq, SeedTreatment == "Treated"| Genotype == "Bare") # see seed treatment notebook for comparison
# sample_data(physeq)$Planted = ifelse(sample_data(physeq)$Genotype == "Bare", "Bare", "Rhizosphere")
# physeq
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 220 samples ]
# sample_data() Sample Data:       [ 220 samples by 47 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %%
# %%R
# sample_data(physeq)$Rep = as.factor(sample_data(physeq)$Rep)
# sample_data(physeq)$Row = as.factor(sample_data(physeq)$Row)
# sample_data(physeq)$Fert = as.factor(sample_data(physeq)$Fert)

# %% [markdown]
# ## Calculate pairwise weighted Unifrac distances between samples

# %%
# %%R
# registerDoParallel(cores=28)
# wunif.dist = phyloseq::distance(physeq,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# registerDoParallel(cores=28)
# bray.dist = distance(physeq,
#                       method = "bray",
#                       weighted = FALSE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# physeq %>%
#     sample_data() %>%
#     .$Plant %>%
#     levels()
# Out:
#  [1] "322"     "330"     "339"     "3394"    "3475"    "34M95"   "34N42"
#  [8] "3517"    "354"     "3541"    "3618"    "Bare"    "P1151HR"

# %% [markdown]
# ## NMDS of w-Unifrac

# %%
# %%R
# set.seed(41)
# dist.bray.nmds = metaMDS(bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.1357791
# Run 1 stress 0.1368189
# Run 2 stress 0.135805
# ... Procrustes: rmse 0.002945528  max resid 0.04043395
# Run 3 stress 0.1360395
# ... Procrustes: rmse 0.007283981  max resid 0.1044412
# Run 4 stress 0.1366247
# Run 5 stress 0.1419988
# Run 6 stress 0.1415511
# Run 7 stress 0.1360933
# ... Procrustes: rmse 0.00529585  max resid 0.06476081
# Run 8 stress 0.1362747
# ... Procrustes: rmse 0.007602146  max resid 0.08875678
# Run 9 stress 0.1358089
# ... Procrustes: rmse 0.002991967  max resid 0.04072908
# Run 10 stress 0.1368772
# Run 11 stress 0.1365472
# Run 12 stress 0.1366379
# Run 13 stress 0.1368951
# Run 14 stress 0.1362915
# Run 15 stress 0.1367868
# Run 16 stress 0.1364924
# Run 17 stress 0.1367489
# Run 18 stress 0.1357676
# ... New best solution
# ... Procrustes: rmse 0.0009454351  max resid 0.01046201
# Run 19 stress 0.1364966
# Run 20 stress 0.1366641
# Run 21 stress 0.1370262
# Run 22 stress 0.1362844
# Run 23 stress 0.1366201
# Run 24 stress 0.1367591
# Run 25 stress 0.1366364
# Run 26 stress 0.1360228
# ... Procrustes: rmse 0.007272384  max resid 0.1046012
# Run 27 stress 0.1357856
# ... Procrustes: rmse 0.001156545  max resid 0.01059487
# Run 28 stress 0.136807
# Run 29 stress 0.1370896
# Run 30 stress 0.1371149
# Run 31 stress 0.1358069
# ... Procrustes: rmse 0.002976238  max resid 0.04283341
# Run 32 stress 0.1360273
# ... Procrustes: rmse 0.007241244  max resid 0.1044524
# Run 33 stress 0.1367171
# Run 34 stress 0.1366818
# Run 35 stress 0.1357814
# ... Procrustes: rmse 0.001005989  max resid 0.01112988
# Run 36 stress 0.1366776
# Run 37 stress 0.135823
# ... Procrustes: rmse 0.003072042  max resid 0.0416162
# Run 38 stress 0.1359432
# ... Procrustes: rmse 0.005335409  max resid 0.07675622
# Run 39 stress 0.1359937
# ... Procrustes: rmse 0.004507482  max resid 0.06490396
# Run 40 stress 0.1367011
# Run 41 stress 0.1429892
# Run 42 stress 0.1357671
# ... New best solution
# ... Procrustes: rmse 0.000373198  max resid 0.00430689
# ... Similar to previous best
# *** Solution reached

# %%
# %%R
# head(dist.bray.nmds, n = 10)
# Out:
# $nobj
# [1] 220
#
# $nfix
# [1] 0
#
# $ndim
# [1] 3
#
# $ndis
# [1] 24090
#
# $ngrp
# [1] 1
#
# $diss
#     [1] 0.1675001 0.1705677 0.1712091 0.1745578 0.1756362 0.1756893 0.1776891
#     [8] 0.1778153 0.1784939 0.1787284 0.1798999 0.1799099 0.1801357 0.1806975
#    [15] 0.1807334 0.1817490 0.1820185 0.1823428 0.1830354 0.1835411 0.1837616
#    [22] 0.1845023 0.1846621 0.1849383 0.1860044 0.1862527 0.1870007 0.1870461
#    [29] 0.1873997 0.1877391 0.1886340 0.1895103 0.1895895 0.1899286 0.1904630
#    [36] 0.1905006 0.1905582 0.1915869 0.1919204 0.1919511 0.1925804 0.1932570
#    [43] 0.1933324 0.1934134 0.1940579 0.1940632 0.1945779 0.1947653 0.1952268
#    [50] 0.1953669 0.1955098 0.1956463 0.1958191 0.1958460 0.1958608 0.1959458
#    [57] 0.1960106 0.1961266 0.1961405 0.1964457 0.1968101 0.1969404 0.1969786
#    [64] 0.1972658 0.1973388 0.1975658 0.1979251 0.1979641 0.1980789 0.1981226
#    [71] 0.1987610 0.1987759 0.1989579 0.1991843 0.1993175 0.1995903 0.2008742
#    [78] 0.2010887 0.2014627 0.2015639 0.2020083 0.2021239 0.2022642 0.2022814
#    [85] 0.2026313 0.2027082 0.2027370 0.2027640 0.2033351 0.2033808 0.2035408
#    [92] 0.2036381 0.2038037 0.2039015 0.2041563 0.2041718 0.2043657 0.2044846
#    [99] 0.2048315 0.2049846 0.2050531 0.2051285 0.2052046 0.2054785 0.2056411
#   [106] 0.2056553 0.2057495 0.2058790 0.2060922 0.2061137 0.2063333 0.2071100
#   [113] 0.2071689 0.2072515 0.2076761 0.2080579 0.2084440 0.2086687 0.2087202
#   [120] 0.2087351 0.2088300 0.2092515 0.2092608 0.2092729 0.2093065 0.2093214
#   [127] 0.2095239 0.2098431 0.2102678 0.2104060 0.2105209 0.2105555 0.2106855
#   [134] 0.2107045 0.2108976 0.2109646 0.2112035 0.2113022 0.2115882 0.2116241
#   [141] 0.2118549 0.2119390 0.2119797 0.2120167 0.2121272 0.2121388 0.2126356
#   [148] 0.2127835 0.2130101 0.2132377 0.2133179 0.2133693 0.2133832 0.2133881
#   [155] 0.2134365 0.2137588 0.2137937 0.2138867 0.2139092 0.2139814 0.2141074
#   [162] 0.2141223 0.2142584 0.2143254 0.2144022 0.2144257 0.2144695 0.2145725
#   [169] 0.2146654 0.2146902 0.2147861 0.2151758 0.2151988 0.2152497 0.2154739
#   [176] 0.2155690 0.2156658 0.2157586 0.2157649 0.2160523 0.2160932 0.2161444
#   [183] 0.2163030 0.2163691 0.2164257 0.2164746 0.2164932 0.2165978 0.2166698
#   [190] 0.2166813 0.2167445 0.2169042 0.2169118 0.2171762 0.2172577 0.2173539
#   [197] 0.2173632 0.2173999 0.2175927 0.2178859 0.2179234 0.2180643 0.2181311
#   [204] 0.2183032 0.2183220 0.2183563 0.2184892 0.2185304 0.2185562 0.2185584
#   [211] 0.2186097 0.2188334 0.2188447 0.2188502 0.2189705 0.2190314 0.2191292
#   [218] 0.2192034 0.2192104 0.2193792 0.2193888 0.2194255 0.2197108 0.2199034
#   [225] 0.2199692 0.2201329 0.2201346 0.2202601 0.2203008 0.2205035 0.2205852
#   [232] 0.2207375 0.2207558 0.2208430 0.2208957 0.2209587 0.2210614 0.2212883
#   [239] 0.2213225 0.2213457 0.2213613 0.2214659 0.2214976 0.2215165 0.2216557
#   [246] 0.2216940 0.2217431 0.2217528 0.2218140 0.2219112 0.2220576 0.2221129
#   [253] 0.2221221 0.2221234 0.2221580 0.2222801 0.2223093 0.2223363 0.2223564
#   [260] 0.2223607 0.2223983 0.2224177 0.2225074 0.2227645 0.2227653 0.2229449
#   [267] 0.2230042 0.2230335 0.2231029 0.2231524 0.2233178 0.2233195 0.2235399
#   [274] 0.2236356 0.2236753 0.2237604 0.2238047 0.2239228 0.2240709 0.2242442
#   [281] 0.2242544 0.2242914 0.2242984 0.2243129 0.2243273 0.2244006 0.2245223
#   [288] 0.2245562 0.2246774 0.2249459 0.2249527 0.2250450 0.2250495 0.2250538
#   [295] 0.2253252 0.2253280 0.2253929 0.2254070 0.2254678 0.2255399 0.2255869
#   [302] 0.2258656 0.2259396 0.2259877 0.2260980 0.2261039 0.2261046 0.2262122
#   [309] 0.2262374 0.2263533 0.2263895 0.2264043 0.2264061 0.2264737 0.2264903
#   [316] 0.2264909 0.2265787 0.2268544 0.2269009 0.2269055 0.2269425 0.2270272
#   [323] 0.2270404 0.2270519 0.2271013 0.2271578 0.2272922 0.2274796 0.2274888
#   [330] 0.2276184 0.2276367 0.2277021 0.2277165 0.2277468 0.2277506 0.2277508
#   [337] 0.2278039 0.2278079 0.2278548 0.2278612 0.2278915 0.2280925 0.2281010
#   [344] 0.2281145 0.2283557 0.2283730 0.2283802 0.2283911 0.2284337 0.2285072
#   [351] 0.2285082 0.2285487 0.2286668 0.2286888 0.2287025 0.2287444 0.2288212
#   [358] 0.2289342 0.2289716 0.2290127 0.2290674 0.2291428 0.2291587 0.2293059
#   [365] 0.2293221 0.2293551 0.2293598 0.2293946 0.2294127 0.2294542 0.2294652
#   [372] 0.2295689 0.2295791 0.2295806 0.2296095 0.2296176 0.2296246 0.2296567
#   [379] 0.2296763 0.2296951 0.2297133 0.2297343 0.2297743 0.2297897 0.2298048
#   [386] 0.2298224 0.2298457 0.2298680 0.2298812 0.2299308 0.2299586 0.2299768
#   [393] 0.2300030 0.2300030 0.2300328 0.2300479 0.2301507 0.2301619 0.2301736
#   [400] 0.2303407 0.2303470 0.2303585 0.2303672 0.2304474 0.2305673 0.2306114
#   [407] 0.2306336 0.2307162 0.2307163 0.2308471 0.2308642 0.2308969 0.2309805
#   [414] 0.2310209 0.2310785 0.2310830 0.2311415 0.2311473 0.2311577 0.2312132
#   [421] 0.2312304 0.2312967 0.2313437 0.2314235 0.2314364 0.2314425 0.2314621
#   [428] 0.2314801 0.2314873 0.2315478 0.2315570 0.2315617 0.2316733 0.2316965
#   [435] 0.2317004 0.2318047 0.2318259 0.2319429 0.2319657 0.2319806 0.2319994
#   [442] 0.2321472 0.2321750 0.2322351 0.2322974 0.2323576 0.2324495 0.2325307
#   [449] 0.2325876 0.2325956 0.2326593 0.2328188 0.2328283 0.2328397 0.2329460
#   [456] 0.2329498 0.2329701 0.2329929 0.2330124 0.2330159 0.2330261 0.2330299
#   [463] 0.2330894 0.2331254 0.2331363 0.2331465 0.2331717 0.2331826 0.2331840
#   [470] 0.2332177 0.2332423 0.2332533 0.2332600 0.2333255 0.2333641 0.2333769
#   [477] 0.2333787 0.2333961 0.2334459 0.2334472 0.2334549 0.2334983 0.2336596
#   [484] 0.2337364 0.2337703 0.2338461 0.2338527 0.2339052 0.2339178 0.2339593
#   [491] 0.2339904 0.2340045 0.2340156 0.2340241 0.2340423 0.2340666 0.2340773
#   [498] 0.2340999 0.2341070 0.2341321 0.2341387 0.2341677 0.2342050 0.2342750
#   [505] 0.2343191 0.2343872 0.2344532 0.2345156 0.2345787 0.2345830 0.2345830
#   [512] 0.2345920 0.2346083 0.2346419 0.2346529 0.2346864 0.2347212 0.2347390
#   [519] 0.2347394 0.2347442 0.2347749 0.2347864 0.2348548 0.2348593 0.2348686
#   [526] 0.2348706 0.2349006 0.2349053 0.2349181 0.2349194 0.2349354 0.2349814
#   [533] 0.2349962 0.2350440 0.2350826 0.2351075 0.2351332 0.2351664 0.2352060
#   [540] 0.2352165 0.2352426 0.2352986 0.2353142 0.2353242 0.2353824 0.2355305
#   [547] 0.2355504 0.2355592 0.2355940 0.2355976 0.2356567 0.2356603 0.2356656
#   [554] 0.2356901 0.2357151 0.2357236 0.2357407 0.2357766 0.2357849 0.2358032
#   [561] 0.2358047 0.2358261 0.2358596 0.2359273 0.2359925 0.2360003 0.2360086
#   [568] 0.2360345 0.2360752 0.2360826 0.2361298 0.2361317 0.2361385 0.2361559
#   [575] 0.2361993 0.2362115 0.2362189 0.2362264 0.2362396 0.2363170 0.2363352
#   [582] 0.2363865 0.2363889 0.2364398 0.2365129 0.2365294 0.2365574 0.2365682
#   [589] 0.2366041 0.2366082 0.2366380 0.2367479 0.2368009 0.2368117 0.2368163
#   [596] 0.2368511 0.2368563 0.2369207 0.2369210 0.2369731 0.2369891 0.2370215
#   [603] 0.2370217 0.2370452 0.2370584 0.2371020 0.2371153 0.2371208 0.2372204
#   [610] 0.2372359 0.2372809 0.2373082 0.2373467 0.2373477 0.2373576 0.2373688
#   [617] 0.2374378 0.2374763 0.2375240 0.2375319 0.2375323 0.2375402 0.2375512
#   [624] 0.2375582 0.2375623 0.2375689 0.2375832 0.2375933 0.2376007 0.2376064
#   [631] 0.2376283 0.2376919 0.2377301 0.2377471 0.2377529 0.2377600 0.2377833
#   [638] 0.2378166 0.2378391 0.2378671 0.2378725 0.2378864 0.2378874 0.2378895
#   [645] 0.2379509 0.2379669 0.2379926 0.2380028 0.2380440 0.2380798 0.2380909
#   [652] 0.2381262 0.2381742 0.2381758 0.2382017 0.2382134 0.2382240 0.2382721
#   [659] 0.2383524 0.2383571 0.2383978 0.2384413 0.2384627 0.2384826 0.2384888
#   [666] 0.2385177 0.2385379 0.2385889 0.2386097 0.2386354 0.2386843 0.2387094
#   [673] 0.2387430 0.2387600 0.2387963 0.2388032 0.2388293 0.2389878 0.2389901
#   [680] 0.2389982 0.2390078 0.2390382 0.2390389 0.2390595 0.2390719 0.2391001
#   [687] 0.2391135 0.2391147 0.2391432 0.2392475 0.2392528 0.2393085 0.2393362
#   [694] 0.2393514 0.2393664 0.2393769 0.2394156 0.2394229 0.2394509 0.2394538
#   [701] 0.2394708 0.2394990 0.2395562 0.2395822 0.2395888 0.2396485 0.2396823
#   [708] 0.2396843 0.2396968 0.2397082 0.2397187 0.2397292 0.2397305 0.2397392
#   [715] 0.2397677 0.2397758 0.2397820 0.2397890 0.2397920 0.2398199 0.2398504
#   [722] 0.2398563 0.2399043 0.2399133 0.2399169 0.2399202 0.2399617 0.2399632
#   [729] 0.2399978 0.2400233 0.2400365 0.2400373 0.2400857 0.2400922 0.2401017
#   [736] 0.2401044 0.2401067 0.2401436 0.2401436 0.2401641 0.2401700 0.2401770
#   [743] 0.2401814 0.2401837 0.2402334 0.2402662 0.2402928 0.2402970 0.2403106
#   [750] 0.2403121 0.2403218 0.2403508 0.2403531 0.2403666 0.2404002 0.2404098
#   [757] 0.2404287 0.2404301 0.2404407 0.2404873 0.2405318 0.2405465 0.2405788
#   [764] 0.2406081 0.2406584 0.2406817 0.2406869 0.2406906 0.2406916 0.2407064
#   [771] 0.2407631 0.2407663 0.2407891 0.2408271 0.2408285 0.2408299 0.2408440
#   [778] 0.2408506 0.2408542 0.2408876 0.2408947 0.2409036 0.2409112 0.2409486
#   [785] 0.2409488 0.2409637 0.2410251 0.2410262 0.2410738 0.2410983 0.2411154
#   [792] 0.2411453 0.2411624 0.2411724 0.2411745 0.2411962 0.2412521 0.2412531
#   [799] 0.2412572 0.2412613 0.2412671 0.2413059 0.2413312 0.2413321 0.2413359
#   [806] 0.2413420 0.2413495 0.2413754 0.2413787 0.2413848 0.2413930 0.2414866
#   [813] 0.2414924 0.2415152 0.2415243 0.2415341 0.2415723 0.2415812 0.2415843
#   [820] 0.2415858 0.2415944 0.2416072 0.2416129 0.2416311 0.2416462 0.2416652
#   [827] 0.2416793 0.2416828 0.2416911 0.2416916 0.2416939 0.2417153 0.2417236
#   [834] 0.2417495 0.2417520 0.2417527 0.2417536 0.2418052 0.2418134 0.2418190
#   [841] 0.2418293 0.2418327 0.2418450 0.2418505 0.2418526 0.2418651 0.2418657
#   [848] 0.2418781 0.2418972 0.2419230 0.2419449 0.2419802 0.2419877 0.2419878
#   [855] 0.2420045 0.2420282 0.2420433 0.2420496 0.2420844 0.2420868 0.2421300
#   [862] 0.2421333 0.2421995 0.2422399 0.2422455 0.2422820 0.2422895 0.2422905
#   [869] 0.2422959 0.2422978 0.2423254 0.2423273 0.2423502 0.2423510 0.2423819
#   [876] 0.2423881 0.2423975 0.2424030 0.2424691 0.2424769 0.2425689 0.2425709
#   [883] 0.2425826 0.2425971 0.2426047 0.2426225 0.2427077 0.2427240 0.2427574
#   [890] 0.2427655 0.2427685 0.2427909 0.2427921 0.2427957 0.2428358 0.2428427
#   [897] 0.2428485 0.2428667 0.2428841 0.2428899 0.2429221 0.2429511 0.2429753
#   [904] 0.2429809 0.2429827 0.2429900 0.2430149 0.2430428 0.2430434 0.2430458
#   [911] 0.2430479 0.2431072 0.2431278 0.2431357 0.2431510 0.2431714 0.2431729
#   [918] 0.2432019 0.2432223 0.2432306 0.2432543 0.2432727 0.2432973 0.2433040
#   [925] 0.2433072 0.2433463 0.2433700 0.2433714 0.2434189 0.2434475 0.2434539
#   [932] 0.2434621 0.2434687 0.2434707 0.2434828 0.2434830 0.2434894 0.2434900
#   [939] 0.2435331 0.2435372 0.2435418 0.2435457 0.2435460 0.2435594 0.2436023
#   [946] 0.2436037 0.2436542 0.2436967 0.2437072 0.2437128 0.2437153 0.2437481
#   [953] 0.2437628 0.2437733 0.2437735 0.2437992 0.2438005 0.2438335 0.2438406
#   [960] 0.2438670 0.2438727 0.2438749 0.2439482 0.2439526 0.2439601 0.2440280
#   [967] 0.2440287 0.2440302 0.2440360 0.2440427 0.2440690 0.2440796 0.2440844
#   [974] 0.2440900 0.2440934 0.2441030 0.2441032 0.2441056 0.2441102 0.2441112
#   [981] 0.2441137 0.2441380 0.2441461 0.2441871 0.2442143 0.2442185 0.2442293
#   [988] 0.2442362 0.2442382 0.2442505 0.2442511 0.2442511 0.2442568 0.2442603
#   [995] 0.2442801 0.2442856 0.2443027 0.2443141 0.2443771 0.2444033 0.2444225
#  [1002] 0.2444344 0.2444824 0.2444826 0.2445030 0.2445112 0.2445491 0.2445494
#  [1009] 0.2445863 0.2446350 0.2446537 0.2446668 0.2446822 0.2446855 0.2447055
#  [1016] 0.2447090 0.2447271 0.2447376 0.2447557 0.2447599 0.2447754 0.2447925
#  [1023] 0.2447964 0.2448094 0.2448220 0.2448233 0.2448785 0.2448880 0.2449110
#  [1030] 0.2449125 0.2449361 0.2449451 0.2449466 0.2449476 0.2449517 0.2449688
#  [1037] 0.2449989 0.2449991 0.2450180 0.2450227 0.2450317 0.2450671 0.2450793
#  [1044] 0.2450888 0.2450953 0.2451011 0.2451200 0.2451400 0.2451419 0.2451759
#  [1051] 0.2451761 0.2451925 0.2452291 0.2452413 0.2452429 0.2452442 0.2452805
#  [1058] 0.2453010 0.2453020 0.2453153 0.2453177 0.2453357 0.2453509 0.2453717
#  [1065] 0.2453828 0.2453984 0.2454051 0.2454128 0.2454269 0.2454568 0.2454715
#  [1072] 0.2454734 0.2454795 0.2454831 0.2454946 0.2455296 0.2455374 0.2455425
#  [1079] 0.2455432 0.2455548 0.2455652 0.2455660 0.2455661 0.2455713 0.2455979
#  [1086] 0.2455989 0.2456027 0.2456351 0.2456386 0.2456456 0.2456733 0.2456812
#  [1093] 0.2456822 0.2457011 0.2457060 0.2457320 0.2457369 0.2457381 0.2457706
#  [1100] 0.2457878 0.2457940 0.2457959 0.2458399 0.2458537 0.2458546 0.2458754
#  [1107] 0.2459243 0.2459255 0.2459669 0.2459843 0.2460003 0.2460140 0.2460269
#  [1114] 0.2460297 0.2460300 0.2460801 0.2460833 0.2461309 0.2461384 0.2461460
#  [1121] 0.2461842 0.2461873 0.2462123 0.2462285 0.2462346 0.2462374 0.2462389
#  [1128] 0.2462581 0.2462705 0.2462820 0.2462869 0.2462950 0.2463115 0.2463119
#  [1135] 0.2463149 0.2463292 0.2463311 0.2463396 0.2463510 0.2463611 0.2463737
#  [1142] 0.2463747 0.2463907 0.2463961 0.2464007 0.2464092 0.2464255 0.2464272
#  [1149] 0.2464362 0.2464375 0.2464608 0.2464672 0.2464835 0.2465435 0.2465522
#  [1156] 0.2465776 0.2466174 0.2466247 0.2466319 0.2466344 0.2466345 0.2466453
#  [1163] 0.2466852 0.2466883 0.2467584 0.2467638 0.2467668 0.2467766 0.2467769
#  [1170] 0.2467887 0.2468141 0.2468181 0.2468440 0.2468520 0.2468766 0.2468808
#  [1177] 0.2469159 0.2469232 0.2469375 0.2469413 0.2469635 0.2469799 0.2469812
#  [1184] 0.2469973 0.2470041 0.2470079 0.2470112 0.2470177 0.2470200 0.2470299
#  [1191] 0.2470383 0.2470402 0.2470402 0.2470418 0.2471127 0.2471160 0.2471600
#  [1198] 0.2471611 0.2471668 0.2471741 0.2471788 0.2471855 0.2471870 0.2472539
#  [1205] 0.2472546 0.2472644 0.2472711 0.2472734 0.2472788 0.2473208 0.2473296
#  [1212] 0.2473450 0.2473560 0.2473707 0.2473753 0.2474065 0.2474085 0.2474115
#  [1219] 0.2474167 0.2474312 0.2474317 0.2474327 0.2474750 0.2474757 0.2474773
#  [1226] 0.2475054 0.2475091 0.2475113 0.2475204 0.2475243 0.2475388 0.2475504
#  [1233] 0.2475634 0.2475869 0.2475886 0.2475897 0.2476037 0.2476074 0.2476183
#  [1240] 0.2476344 0.2476356 0.2476364 0.2476404 0.2476533 0.2476615 0.2476845
#  [1247] 0.2476890 0.2477001 0.2477106 0.2477207 0.2477215 0.2477315 0.2477492
#  [1254] 0.2477500 0.2477543 0.2477792 0.2477819 0.2478036 0.2478190 0.2478235
#  [1261] 0.2478335 0.2478416 0.2478455 0.2478558 0.2478616 0.2478818 0.2478938
#  [1268] 0.2479016 0.2479043 0.2479068 0.2479120 0.2479348 0.2479618 0.2479807
#  [1275] 0.2479947 0.2479970 0.2479983 0.2480148 0.2480248 0.2480252 0.2480312
#  [1282] 0.2480613 0.2480881 0.2480973 0.2480973 0.2481080 0.2481141 0.2481226
#  [1289] 0.2481254 0.2481284 0.2481548 0.2481674 0.2481708 0.2481731 0.2481811
#  [1296] 0.2481817 0.2481851 0.2482100 0.2482204 0.2482700 0.2482840 0.2483247
#  [1303] 0.2483317 0.2483384 0.2483469 0.2483916 0.2484004 0.2484019 0.2484109
#  [1310] 0.2484129 0.2484135 0.2484438 0.2484556 0.2484709 0.2484746 0.2484803
#  [1317] 0.2484810 0.2485037 0.2485065 0.2485145 0.2485232 0.2485276 0.2485295
#  [1324] 0.2485350 0.2485443 0.2485515 0.2485536 0.2485739 0.2485998 0.2486040
#  [1331] 0.2486232 0.2486345 0.2486608 0.2486729 0.2486833 0.2486884 0.2486917
#  [1338] 0.2486925 0.2486952 0.2487110 0.2487149 0.2487188 0.2487282 0.2487445
#  [1345] 0.2487457 0.2487462 0.2487621 0.2487628 0.2487631 0.2487817 0.2487958
#  [1352] 0.2488525 0.2488757 0.2488797 0.2488812 0.2488840 0.2488842 0.2488891
#  [1359] 0.2489100 0.2489114 0.2489372 0.2489408 0.2489470 0.2489567 0.2489601
#  [1366] 0.2489655 0.2489730 0.2490024 0.2490072 0.2490274 0.2490308 0.2490336
#  [1373] 0.2490630 0.2490632 0.2490683 0.2490748 0.2490894 0.2491041 0.2491056
#  [1380] 0.2491129 0.2491261 0.2491721 0.2491933 0.2491939 0.2491948 0.2492057
#  [1387] 0.2492923 0.2493048 0.2493052 0.2493213 0.2493430 0.2493433 0.2493580
#  [1394] 0.2494015 0.2494200 0.2494283 0.2494648 0.2494734 0.2494930 0.2494964
#  [1401] 0.2494967 0.2494991 0.2495439 0.2495522 0.2495644 0.2495646 0.2495954
#  [1408] 0.2496347 0.2496408 0.2496454 0.2496570 0.2496583 0.2496605 0.2496955
#  [1415] 0.2497018 0.2497086 0.2497188 0.2497249 0.2497619 0.2497759 0.2497892
#  [1422] 0.2497899 0.2497908 0.2497931 0.2497976 0.2498040 0.2498045 0.2498094
#  [1429] 0.2498097 0.2498114 0.2498124 0.2498439 0.2498457 0.2498487 0.2498518
#  [1436] 0.2498645 0.2498811 0.2498973 0.2499226 0.2499440 0.2499440 0.2499623
#  [1443] 0.2499768 0.2499852 0.2500026 0.2500071 0.2500092 0.2500189 0.2500195
#  [1450] 0.2500225 0.2500251 0.2500267 0.2500463 0.2500498 0.2500606 0.2500717
#  [1457] 0.2500717 0.2500787 0.2500801 0.2500946 0.2501088 0.2501114 0.2501252
#  [1464] 0.2501354 0.2501515 0.2501653 0.2501720 0.2501745 0.2501872 0.2501940
#  [1471] 0.2501952 0.2502188 0.2502204 0.2502283 0.2502335 0.2502480 0.2502498
#  [1478] 0.2502911 0.2502982 0.2503028 0.2503333 0.2503340 0.2503725 0.2503976
#  [1485] 0.2504070 0.2504106 0.2504211 0.2504233 0.2504243 0.2504308 0.2504316
#  [1492] 0.2504430 0.2504444 0.2504485 0.2504501 0.2504541 0.2504712 0.2504730
#  [1499] 0.2504751 0.2504779 0.2504833 0.2505006 0.2505040 0.2505450 0.2505710
#  [1506] 0.2505745 0.2505770 0.2505806 0.2505878 0.2506000 0.2506106 0.2506114
#  [1513] 0.2506309 0.2506412 0.2506521 0.2506592 0.2506841 0.2506846 0.2506869
#  [1520] 0.2506915 0.2506964 0.2507081 0.2507109 0.2507130 0.2507260 0.2507283
#  [1527] 0.2507288 0.2507457 0.2507482 0.2507516 0.2507583 0.2507587 0.2507941
#  [1534] 0.2508468 0.2508847 0.2508907 0.2509068 0.2509258 0.2509543 0.2509605
#  [1541] 0.2509670 0.2509787 0.2509884 0.2510028 0.2510063 0.2510098 0.2510213
#  [1548] 0.2510217 0.2510231 0.2510380 0.2510392 0.2510543 0.2510551 0.2510690
#  [1555] 0.2510721 0.2510725 0.2510755 0.2510949 0.2511005 0.2511197 0.2511400
#  [1562] 0.2511464 0.2511466 0.2511700 0.2511759 0.2511960 0.2512412 0.2512485
#  [1569] 0.2512496 0.2512560 0.2512602 0.2512715 0.2512796 0.2512820 0.2512864
#  [1576] 0.2512907 0.2512926 0.2513042 0.2513096 0.2513116 0.2513207 0.2513263
#  [1583] 0.2513415 0.2513513 0.2513566 0.2513583 0.2513652 0.2513732 0.2513796
#  [1590] 0.2513926 0.2514162 0.2514235 0.2514423 0.2514443 0.2514465 0.2514467
#  [1597] 0.2514635 0.2514635 0.2514804 0.2514902 0.2514975 0.2514982 0.2515081
#  [1604] 0.2515115 0.2515138 0.2515182 0.2515284 0.2515324 0.2515354 0.2515621
#  [1611] 0.2515630 0.2515823 0.2515882 0.2515936 0.2516437 0.2516464 0.2516500
#  [1618] 0.2516620 0.2516682 0.2516692 0.2516781 0.2516914 0.2517022 0.2517042
#  [1625] 0.2517071 0.2517220 0.2517279 0.2517326 0.2517331 0.2517520 0.2517618
#  [1632] 0.2517680 0.2517706 0.2517829 0.2517877 0.2517917 0.2517937 0.2518024
#  [1639] 0.2518062 0.2518090 0.2518564 0.2518610 0.2518876 0.2519034 0.2519059
#  [1646] 0.2519264 0.2519326 0.2519359 0.2519396 0.2519504 0.2519572 0.2519590
#  [1653] 0.2519591 0.2519848 0.2519854 0.2520007 0.2520254 0.2520360 0.2520507
#  [1660] 0.2520859 0.2520859 0.2520872 0.2521033 0.2521041 0.2521062 0.2521097
#  [1667] 0.2521215 0.2521225 0.2521389 0.2521398 0.2521438 0.2521484 0.2521545
#  [1674] 0.2521589 0.2521706 0.2521878 0.2521963 0.2521982 0.2522074 0.2522512
#  [1681] 0.2522594 0.2522683 0.2522704 0.2522844 0.2522857 0.2522917 0.2523070
#  [1688] 0.2523117 0.2523205 0.2523249 0.2523272 0.2523422 0.2523489 0.2523499
#  [1695] 0.2523623 0.2523702 0.2523790 0.2523911 0.2523966 0.2524110 0.2524221
#  [1702] 0.2524326 0.2524638 0.2524716 0.2524766 0.2524939 0.2524950 0.2525016
#  [1709] 0.2525086 0.2525148 0.2525208 0.2525254 0.2525275 0.2525337 0.2525383
#  [1716] 0.2525640 0.2525860 0.2525894 0.2525901 0.2526035 0.2526084 0.2526135
#  [1723] 0.2526155 0.2526221 0.2526282 0.2526347 0.2526359 0.2526406 0.2526503
#  [1730] 0.2526751 0.2526775 0.2526811 0.2526879 0.2526921 0.2526965 0.2527051
#  [1737] 0.2527170 0.2527264 0.2527364 0.2527407 0.2527574 0.2527582 0.2527592
#  [1744] 0.2527713 0.2527858 0.2527874 0.2528047 0.2528048 0.2528103 0.2528160
#  [1751] 0.2528194 0.2528256 0.2528320 0.2528592 0.2528627 0.2528755 0.2528777
#  [1758] 0.2528830 0.2528852 0.2528930 0.2528984 0.2528987 0.2529012 0.2529020
#  [1765] 0.2529029 0.2529053 0.2529293 0.2529322 0.2529381 0.2529621 0.2529656
#  [1772] 0.2529819 0.2529840 0.2529856 0.2529992 0.2529993 0.2529998 0.2530019
#  [1779] 0.2530075 0.2530149 0.2530153 0.2530322 0.2530343 0.2530375 0.2530379
#  [1786] 0.2530575 0.2530718 0.2530740 0.2530838 0.2530942 0.2530954 0.2530976
#  [1793] 0.2531048 0.2531221 0.2531321 0.2531440 0.2531444 0.2531475 0.2531479
#  [1800] 0.2531611 0.2531697 0.2531745 0.2531753 0.2531993 0.2532034 0.2532144
#  [1807] 0.2532163 0.2532394 0.2532428 0.2532458 0.2532499 0.2532519 0.2532749
#  [1814] 0.2532751 0.2532843 0.2532893 0.2532925 0.2532989 0.2532989 0.2533012
#  [1821] 0.2533220 0.2533411 0.2533430 0.2533432 0.2533549 0.2533631 0.2533655
#  [1828] 0.2533702 0.2533984 0.2533996 0.2534003 0.2534029 0.2534088 0.2534098
#  [1835] 0.2534137 0.2534501 0.2534586 0.2534761 0.2534834 0.2534913 0.2535017
#  [1842] 0.2535075 0.2535119 0.2535161 0.2535207 0.2535298 0.2535377 0.2535472
#  [1849] 0.2535507 0.2535691 0.2535695 0.2535743 0.2535822 0.2535830 0.2535866
#  [1856] 0.2535955 0.2536115 0.2536120 0.2536314 0.2536434 0.2536490 0.2536530
#  [1863] 0.2536579 0.2536875 0.2536960 0.2537000 0.2537068 0.2537097 0.2537156
#  [1870] 0.2537160 0.2537220 0.2537250 0.2537266 0.2537272 0.2537394 0.2537395
#  [1877] 0.2537440 0.2537523 0.2537655 0.2537668 0.2537731 0.2538093 0.2538383
#  [1884] 0.2538386 0.2538521 0.2538575 0.2538577 0.2538597 0.2538801 0.2538907
#  [1891] 0.2538986 0.2539075 0.2539247 0.2539261 0.2539338 0.2539404 0.2539492
#  [1898] 0.2539550 0.2539625 0.2539703 0.2539707 0.2539834 0.2539874 0.2539890
#  [1905] 0.2539906 0.2539996 0.2540065 0.2540074 0.2540208 0.2540369 0.2540412
#  [1912] 0.2540433 0.2540517 0.2540578 0.2540600 0.2540629 0.2540633 0.2540740
#  [1919] 0.2540818 0.2540884 0.2540907 0.2541052 0.2541072 0.2541129 0.2541134
#  [1926] 0.2541161 0.2541172 0.2541359 0.2541407 0.2541430 0.2541476 0.2541551
#  [1933] 0.2541611 0.2541621 0.2541642 0.2541694 0.2541714 0.2541728 0.2541872
#  [1940] 0.2541966 0.2541976 0.2542075 0.2542132 0.2542181 0.2542325 0.2542401
#  [1947] 0.2542438 0.2542596 0.2542732 0.2542814 0.2542884 0.2542897 0.2542942
#  [1954] 0.2542943 0.2542988 0.2543153 0.2543229 0.2543253 0.2543305 0.2543365
#  [1961] 0.2543382 0.2543502 0.2543616 0.2543800 0.2543818 0.2543932 0.2544062
#  [1968] 0.2544075 0.2544185 0.2544227 0.2544530 0.2544629 0.2544775 0.2544805
#  [1975] 0.2544806 0.2545070 0.2545106 0.2545119 0.2545122 0.2545201 0.2545248
#  [1982] 0.2545611 0.2545699 0.2545744 0.2545855 0.2545953 0.2546652 0.2546698
#  [1989] 0.2546764 0.2546939 0.2546996 0.2547013 0.2547024 0.2547052 0.2547053
#  [1996] 0.2547071 0.2547140 0.2547185 0.2547227 0.2547374 0.2547439 0.2547457
#  [2003] 0.2547563 0.2547583 0.2547788 0.2547897 0.2548141 0.2548179 0.2548365
#  [2010] 0.2548595 0.2548778 0.2548790 0.2548807 0.2548907 0.2548954 0.2549003
#  [2017] 0.2549114 0.2549152 0.2549194 0.2549269 0.2549330 0.2549435 0.2549439
#  [2024] 0.2549442 0.2549446 0.2549469 0.2549547 0.2549846 0.2549883 0.2549922
#  [2031] 0.2549938 0.2549940 0.2550168 0.2550334 0.2550355 0.2550397 0.2550501
#  [2038] 0.2550522 0.2550537 0.2550546 0.2550564 0.2550571 0.2550607 0.2550649
#  [2045] 0.2550686 0.2550744 0.2550911 0.2550982 0.2551279 0.2551662 0.2551697
#  [2052] 0.2551768 0.2551870 0.2551951 0.2552068 0.2552306 0.2552353 0.2552427
#  [2059] 0.2552430 0.2552463 0.2552475 0.2552550 0.2552675 0.2552698 0.2552833
#  [2066] 0.2552887 0.2552954 0.2553005 0.2553102 0.2553280 0.2553379 0.2553432
#  [2073] 0.2553467 0.2553503 0.2553515 0.2553526 0.2553536 0.2553576 0.2553737
#  [2080] 0.2553743 0.2553774 0.2553913 0.2553941 0.2554009 0.2554027 0.2554030
#  [2087] 0.2554240 0.2554284 0.2554286 0.2554439 0.2554471 0.2554471 0.2554720
#  [2094] 0.2554870 0.2554917 0.2555019 0.2555043 0.2555130 0.2555149 0.2555243
#  [2101] 0.2555425 0.2555432 0.2555532 0.2555539 0.2555540 0.2555660 0.2555850
#  [2108] 0.2556120 0.2556120 0.2556363 0.2556366 0.2556506 0.2556688 0.2556774
#  [2115] 0.2556819 0.2556895 0.2556900 0.2556901 0.2556943 0.2556988 0.2557015
#  [2122] 0.2557020 0.2557054 0.2557085 0.2557128 0.2557132 0.2557202 0.2557244
#  [2129] 0.2557267 0.2557354 0.2557361 0.2557367 0.2557420 0.2557456 0.2557539
#  [2136] 0.2557548 0.2557619 0.2557733 0.2557758 0.2557811 0.2557820 0.2557852
#  [2143] 0.2558114 0.2558140 0.2558237 0.2558306 0.2558349 0.2558412 0.2558545
#  [2150] 0.2558560 0.2558646 0.2558757 0.2558841 0.2558904 0.2558941 0.2559007
#  [2157] 0.2559011 0.2559051 0.2559063 0.2559479 0.2559549 0.2559595 0.2559644
#  [2164] 0.2559670 0.2559729 0.2559752 0.2559755 0.2559787 0.2559860 0.2560050
#  [2171] 0.2560094 0.2560115 0.2560140 0.2560150 0.2560311 0.2560350 0.2560492
#  [2178] 0.2560607 0.2560634 0.2560797 0.2560832 0.2560859 0.2560907 0.2560952
#  [2185] 0.2561026 0.2561040 0.2561305 0.2561318 0.2561484 0.2561518 0.2561692
#  [2192] 0.2561750 0.2561788 0.2561795 0.2561867 0.2561871 0.2562033 0.2562058
#  [2199] 0.2562173 0.2562237 0.2562242 0.2562327 0.2562340 0.2562366 0.2562434
#  [2206] 0.2562515 0.2562548 0.2562773 0.2562784 0.2562905 0.2563091 0.2563171
#  [2213] 0.2563243 0.2563269 0.2563339 0.2563392 0.2563505 0.2563529 0.2563543
#  [2220] 0.2563606 0.2563693 0.2563704 0.2563713 0.2563885 0.2563997 0.2564075
#  [2227] 0.2564112 0.2564113 0.2564136 0.2564182 0.2564194 0.2564212 0.2564249
#  [2234] 0.2564300 0.2564302 0.2564410 0.2564446 0.2564571 0.2564609 0.2564644
#  [2241] 0.2564682 0.2564840 0.2564869 0.2564908 0.2565027 0.2565038 0.2565068
#  [2248] 0.2565076 0.2565222 0.2565224 0.2565533 0.2565592 0.2565592 0.2565764
#  [2255] 0.2565812 0.2565889 0.2565924 0.2565967 0.2565973 0.2566332 0.2566357
#  [2262] 0.2566486 0.2566523 0.2566574 0.2566586 0.2566590 0.2566691 0.2566851
#  [2269] 0.2566910 0.2566917 0.2567054 0.2567121 0.2567227 0.2567253 0.2567294
#  [2276] 0.2567317 0.2567336 0.2567369 0.2567467 0.2567467 0.2567554 0.2567621
#  [2283] 0.2567673 0.2567747 0.2567753 0.2567828 0.2567832 0.2567911 0.2567939
#  [2290] 0.2567949 0.2568270 0.2568300 0.2568462 0.2568489 0.2568501 0.2568693
#  [2297] 0.2568889 0.2569045 0.2569082 0.2569490 0.2569658 0.2569732 0.2569769
#  [2304] 0.2569847 0.2569853 0.2569880 0.2569913 0.2569996 0.2570053 0.2570071
#  [2311] 0.2570080 0.2570106 0.2570160 0.2570320 0.2570441 0.2570478 0.2570538
#  [2318] 0.2570839 0.2570887 0.2570995 0.2571038 0.2571116 0.2571129 0.2571174
#  [2325] 0.2571360 0.2571488 0.2571548 0.2571623 0.2571624 0.2571661 0.2571777
#  [2332] 0.2571796 0.2571805 0.2571932 0.2571956 0.2571988 0.2571994 0.2572025
#  [2339] 0.2572033 0.2572046 0.2572105 0.2572200 0.2572229 0.2572517 0.2572541
#  [2346] 0.2572546 0.2572594 0.2572680 0.2572708 0.2572731 0.2572926 0.2572943
#  [2353] 0.2572979 0.2573098 0.2573407 0.2573426 0.2573485 0.2573684 0.2573715
#  [2360] 0.2573725 0.2573895 0.2573947 0.2573948 0.2574019 0.2574252 0.2574253
#  [2367] 0.2574385 0.2574449 0.2574510 0.2574527 0.2574721 0.2574820 0.2574866
#  [2374] 0.2574945 0.2575084 0.2575123 0.2575132 0.2575296 0.2575315 0.2575349
#  [2381] 0.2575420 0.2575742 0.2575812 0.2575816 0.2575816 0.2576010 0.2576108
#  [2388] 0.2576113 0.2576206 0.2576349 0.2576366 0.2576422 0.2576504 0.2576572
#  [2395] 0.2576660 0.2576681 0.2576688 0.2576727 0.2576731 0.2576733 0.2576757
#  [2402] 0.2576830 0.2576844 0.2576890 0.2577016 0.2577031 0.2577310 0.2577321
#  [2409] 0.2577329 0.2577674 0.2577809 0.2577871 0.2577884 0.2577892 0.2577948
#  [2416] 0.2577968 0.2578107 0.2578153 0.2578321 0.2578531 0.2578605 0.2578677
#  [2423] 0.2578782 0.2578783 0.2578798 0.2578920 0.2579001 0.2579009 0.2579017
#  [2430] 0.2579092 0.2579114 0.2579261 0.2579322 0.2579450 0.2579493 0.2579526
#  [2437] 0.2579575 0.2579599 0.2579657 0.2579700 0.2579706 0.2579773 0.2579788
#  [2444] 0.2579789 0.2579831 0.2579840 0.2579866 0.2579873 0.2579919 0.2579955
#  [2451] 0.2579998 0.2580020 0.2580066 0.2580252 0.2580388 0.2580726 0.2580809
#  [2458] 0.2580942 0.2580970 0.2580991 0.2581078 0.2581120 0.2581169 0.2581365
#  [2465] 0.2581407 0.2581459 0.2581479 0.2581515 0.2581553 0.2581559 0.2581826
#  [2472] 0.2581860 0.2581871 0.2581898 0.2581918 0.2581980 0.2582055 0.2582141
#  [2479] 0.2582224 0.2582240 0.2582248 0.2582257 0.2582260 0.2582268 0.2582278
#  [2486] 0.2582321 0.2582372 0.2582490 0.2582622 0.2582758 0.2582778 0.2582818
#  [2493] 0.2582823 0.2582848 0.2582873 0.2582884 0.2582903 0.2582913 0.2583141
#  [2500] 0.2583362 0.2583446 0.2583580 0.2583616 0.2583636 0.2583650 0.2583758
#  [2507] 0.2583821 0.2584095 0.2584132 0.2584302 0.2584347 0.2584361 0.2584387
#  [2514] 0.2584400 0.2584423 0.2584427 0.2584441 0.2584505 0.2584525 0.2584590
#  [2521] 0.2584597 0.2584677 0.2584797 0.2584877 0.2584905 0.2584946 0.2584947
#  [2528] 0.2584982 0.2584983 0.2585049 0.2585492 0.2585523 0.2585618 0.2585626
#  [2535] 0.2585680 0.2585688 0.2585952 0.2586030 0.2586058 0.2586060 0.2586141
#  [2542] 0.2586146 0.2586172 0.2586204 0.2586309 0.2586381 0.2586498 0.2586590
#  [2549] 0.2586643 0.2586744 0.2586964 0.2586992 0.2587095 0.2587113 0.2587329
#  [2556] 0.2587415 0.2587429 0.2587443 0.2587475 0.2587557 0.2587590 0.2587708
#  [2563] 0.2587773 0.2587776 0.2587896 0.2587952 0.2588019 0.2588163 0.2588165
#  [2570] 0.2588271 0.2588337 0.2588396 0.2588402 0.2588447 0.2588518 0.2588775
#  [2577] 0.2588921 0.2588950 0.2588984 0.2589141 0.2589251 0.2589280 0.2589337
#  [2584] 0.2589337 0.2589404 0.2589416 0.2589439 0.2589444 0.2589500 0.2589672
#  [2591] 0.2589723 0.2589760 0.2589795 0.2589828 0.2589885 0.2590022 0.2590061
#  [2598] 0.2590078 0.2590139 0.2590436 0.2590441 0.2590564 0.2590642 0.2590656
#  [2605] 0.2590668 0.2590712 0.2590747 0.2590756 0.2590976 0.2591039 0.2591127
#  [2612] 0.2591128 0.2591139 0.2591203 0.2591216 0.2591279 0.2591295 0.2591335
#  [2619] 0.2591349 0.2591430 0.2591504 0.2591563 0.2591646 0.2591686 0.2591694
#  [2626] 0.2591709 0.2591994 0.2592003 0.2592040 0.2592219 0.2592284 0.2592286
#  [2633] 0.2592358 0.2592597 0.2592715 0.2592761 0.2592813 0.2592850 0.2592852
#  [2640] 0.2592987 0.2593025 0.2593186 0.2593348 0.2593383 0.2593384 0.2593447
#  [2647] 0.2593642 0.2593691 0.2593694 0.2593727 0.2593734 0.2593746 0.2593762
#  [2654] 0.2593904 0.2593942 0.2593983 0.2594029 0.2594068 0.2594180 0.2594229
#  [2661] 0.2594309 0.2594312 0.2594342 0.2594351 0.2594413 0.2594417 0.2594429
#  [2668] 0.2594473 0.2594491 0.2594498 0.2594568 0.2594703 0.2594836 0.2594873
#  [2675] 0.2594889 0.2594901 0.2594923 0.2594945 0.2595072 0.2595073 0.2595103
#  [2682] 0.2595306 0.2595351 0.2595524 0.2595552 0.2595576 0.2595621 0.2595646
#  [2689] 0.2595787 0.2595839 0.2595853 0.2595874 0.2595938 0.2595999 0.2596008
#  [2696] 0.2596047 0.2596177 0.2596190 0.2596229 0.2596249 0.2596280 0.2596301
#  [2703] 0.2596347 0.2596353 0.2596510 0.2596664 0.2596667 0.2596742 0.2596751
#  [2710] 0.2596828 0.2596864 0.2596865 0.2596873 0.2597060 0.2597099 0.2597101
#  [2717] 0.2597142 0.2597219 0.2597225 0.2597230 0.2597256 0.2597263 0.2597349
#  [2724] 0.2597390 0.2597529 0.2597845 0.2597978 0.2597998 0.2598010 0.2598052
#  [2731] 0.2598073 0.2598121 0.2598174 0.2598498 0.2598609 0.2598688 0.2598741
#  [2738] 0.2598773 0.2598797 0.2598864 0.2598877 0.2598931 0.2598984 0.2598999
#  [2745] 0.2599033 0.2599036 0.2599112 0.2599120 0.2599135 0.2599258 0.2599295
#  [2752] 0.2599374 0.2599404 0.2599476 0.2599506 0.2599543 0.2599543 0.2599598
#  [2759] 0.2599673 0.2599699 0.2599700 0.2599729 0.2599791 0.2599799 0.2599909
#  [2766] 0.2600060 0.2600084 0.2600156 0.2600485 0.2600493 0.2600505 0.2600591
#  [2773] 0.2600601 0.2600739 0.2600808 0.2600936 0.2601171 0.2601242 0.2601284
#  [2780] 0.2601377 0.2601436 0.2601511 0.2601685 0.2601699 0.2601721 0.2601727
#  [2787] 0.2601870 0.2601940 0.2601960 0.2602050 0.2602051 0.2602064 0.2602165
#  [2794] 0.2602189 0.2602332 0.2602333 0.2602490 0.2602544 0.2602608 0.2602647
#  [2801] 0.2602655 0.2602765 0.2602814 0.2603016 0.2603065 0.2603099 0.2603142
#  [2808] 0.2603148 0.2603258 0.2603290 0.2603373 0.2603396 0.2603466 0.2603669
#  [2815] 0.2603679 0.2603702 0.2603708 0.2603813 0.2603871 0.2603880 0.2603883
#  [2822] 0.2604052 0.2604103 0.2604204 0.2604330 0.2604362 0.2604394 0.2604468
#  [2829] 0.2604636 0.2604721 0.2604740 0.2604744 0.2604763 0.2604966 0.2605058
#  [2836] 0.2605105 0.2605131 0.2605144 0.2605214 0.2605224 0.2605227 0.2605237
#  [2843] 0.2605380 0.2605386 0.2605405 0.2605417 0.2605593 0.2605686 0.2605704
#  [2850] 0.2605720 0.2605836 0.2605840 0.2605873 0.2605973 0.2605977 0.2606070
#  [2857] 0.2606151 0.2606334 0.2606380 0.2606449 0.2606468 0.2606486 0.2606562
#  [2864] 0.2606597 0.2606916 0.2606986 0.2606986 0.2607020 0.2607024 0.2607096
#  [2871] 0.2607244 0.2607262 0.2607263 0.2607276 0.2607386 0.2607413 0.2607818
#  [2878] 0.2607959 0.2607962 0.2607988 0.2607995 0.2608012 0.2608039 0.2608164
#  [2885] 0.2608186 0.2608430 0.2608454 0.2608498 0.2608552 0.2608599 0.2608628
#  [2892] 0.2608652 0.2608664 0.2608667 0.2608713 0.2608731 0.2608739 0.2608816
#  [2899] 0.2608920 0.2609025 0.2609032 0.2609109 0.2609140 0.2609179 0.2609196
#  [2906] 0.2609233 0.2609409 0.2609440 0.2609460 0.2609523 0.2609736 0.2609818
#  [2913] 0.2609894 0.2609907 0.2609915 0.2609980 0.2610018 0.2610039 0.2610042
#  [2920] 0.2610136 0.2610177 0.2610268 0.2610302 0.2610323 0.2610336 0.2610430
#  [2927] 0.2610459 0.2610463 0.2610522 0.2610535 0.2610575 0.2610679 0.2610915
#  [2934] 0.2610946 0.2610976 0.2610978 0.2611065 0.2611163 0.2611236 0.2611266
#  [2941] 0.2611353 0.2611384 0.2611401 0.2611407 0.2611505 0.2611512 0.2611514
#  [2948] 0.2611634 0.2611671 0.2611685 0.2611716 0.2611718 0.2611813 0.2611823
#  [2955] 0.2611847 0.2611864 0.2611944 0.2612013 0.2612058 0.2612101 0.2612127
#  [2962] 0.2612139 0.2612183 0.2612253 0.2612264 0.2612309 0.2612337 0.2612424
#  [2969] 0.2612448 0.2612502 0.2612591 0.2612679 0.2612725 0.2612726 0.2612746
#  [2976] 0.2612912 0.2612996 0.2613032 0.2613081 0.2613226 0.2613256 0.2613324
#  [2983] 0.2613390 0.2613421 0.2613486 0.2613520 0.2613558 0.2613565 0.2613650
#  [2990] 0.2613755 0.2613760 0.2613767 0.2613905 0.2613934 0.2613938 0.2614017
#  [2997] 0.2614065 0.2614247 0.2614297 0.2614347 0.2614355 0.2614434 0.2614435
#  [3004] 0.2614447 0.2614485 0.2614485 0.2614513 0.2614663 0.2614821 0.2614873
#  [3011] 0.2614906 0.2614967 0.2614987 0.2615001 0.2615016 0.2615069 0.2615253
#  [3018] 0.2615300 0.2615337 0.2615363 0.2615418 0.2615504 0.2615534 0.2615592
#  [3025] 0.2615651 0.2615668 0.2615686 0.2615698 0.2615710 0.2615723 0.2615948
#  [3032] 0.2615958 0.2616073 0.2616137 0.2616147 0.2616187 0.2616200 0.2616239
#  [3039] 0.2616288 0.2616424 0.2616462 0.2616539 0.2616553 0.2616689 0.2616795
#  [3046] 0.2616802 0.2616819 0.2616827 0.2616884 0.2616922 0.2616956 0.2616962
#  [3053] 0.2617009 0.2617095 0.2617162 0.2617242 0.2617252 0.2617356 0.2617374
#  [3060] 0.2617380 0.2617384 0.2617420 0.2617447 0.2617456 0.2617662 0.2617725
#  [3067] 0.2617743 0.2617785 0.2617910 0.2617995 0.2618079 0.2618103 0.2618175
#  [3074] 0.2618206 0.2618323 0.2618416 0.2618538 0.2618558 0.2618675 0.2618675
#  [3081] 0.2618677 0.2618762 0.2618819 0.2618922 0.2619113 0.2619122 0.2619124
#  [3088] 0.2619220 0.2619257 0.2619365 0.2619426 0.2619475 0.2619479 0.2619528
#  [3095] 0.2619569 0.2619585 0.2619635 0.2619642 0.2619695 0.2619858 0.2619882
#  [3102] 0.2619896 0.2619951 0.2619982 0.2620136 0.2620148 0.2620259 0.2620271
#  [3109] 0.2620323 0.2620335 0.2620428 0.2620441 0.2620503 0.2620573 0.2620609
#  [3116] 0.2620683 0.2620687 0.2620812 0.2620827 0.2620906 0.2620972 0.2620982
#  [3123] 0.2621063 0.2621075 0.2621182 0.2621251 0.2621476 0.2621499 0.2621546
#  [3130] 0.2621558 0.2621569 0.2621629 0.2621652 0.2621743 0.2621808 0.2621814
#  [3137] 0.2621831 0.2621850 0.2621888 0.2621911 0.2621956 0.2622010 0.2622140
#  [3144] 0.2622205 0.2622418 0.2622433 0.2622454 0.2622472 0.2622519 0.2622540
#  [3151] 0.2622599 0.2622616 0.2622628 0.2622722 0.2622884 0.2623027 0.2623046
#  [3158] 0.2623095 0.2623126 0.2623164 0.2623164 0.2623174 0.2623193 0.2623239
#  [3165] 0.2623253 0.2623260 0.2623354 0.2623373 0.2623433 0.2623515 0.2623621
#  [3172] 0.2623679 0.2623765 0.2623766 0.2623789 0.2623870 0.2623898 0.2624007
#  [3179] 0.2624008 0.2624044 0.2624052 0.2624101 0.2624131 0.2624143 0.2624151
#  [3186] 0.2624262 0.2624339 0.2624390 0.2624460 0.2624489 0.2624517 0.2624519
#  [3193] 0.2624573 0.2624608 0.2624610 0.2624619 0.2624674 0.2624761 0.2624790
#  [3200] 0.2624794 0.2624868 0.2624892 0.2624927 0.2624977 0.2625077 0.2625138
#  [3207] 0.2625190 0.2625262 0.2625278 0.2625349 0.2625364 0.2625407 0.2625429
#  [3214] 0.2625472 0.2625654 0.2625684 0.2625703 0.2625758 0.2625795 0.2625826
#  [3221] 0.2625945 0.2625959 0.2626007 0.2626054 0.2626066 0.2626088 0.2626140
#  [3228] 0.2626190 0.2626208 0.2626218 0.2626228 0.2626240 0.2626348 0.2626463
#  [3235] 0.2626493 0.2626653 0.2626654 0.2626673 0.2626702 0.2626717 0.2627032
#  [3242] 0.2627057 0.2627160 0.2627201 0.2627274 0.2627274 0.2627370 0.2627376
#  [3249] 0.2627388 0.2627425 0.2627479 0.2627543 0.2627601 0.2627639 0.2627642
#  [3256] 0.2627703 0.2627791 0.2627923 0.2627926 0.2628064 0.2628092 0.2628104
#  [3263] 0.2628124 0.2628140 0.2628150 0.2628187 0.2628235 0.2628264 0.2628345
#  [3270] 0.2628415 0.2628440 0.2628502 0.2628603 0.2628623 0.2628668 0.2628709
#  [3277] 0.2628710 0.2628919 0.2628923 0.2628932 0.2628936 0.2628969 0.2628973
#  [3284] 0.2629131 0.2629193 0.2629223 0.2629285 0.2629317 0.2629500 0.2629509
#  [3291] 0.2629582 0.2629683 0.2629688 0.2629745 0.2629786 0.2629811 0.2629814
#  [3298] 0.2629928 0.2630055 0.2630221 0.2630296 0.2630310 0.2630330 0.2630374
#  [3305] 0.2630473 0.2630486 0.2630498 0.2630521 0.2630649 0.2630657 0.2630719
#  [3312] 0.2630740 0.2630859 0.2630871 0.2630920 0.2630952 0.2631063 0.2631073
#  [3319] 0.2631150 0.2631158 0.2631188 0.2631245 0.2631272 0.2631372 0.2631437
#  [3326] 0.2631456 0.2631540 0.2631551 0.2631551 0.2631560 0.2631566 0.2631583
#  [3333] 0.2631621 0.2631623 0.2631652 0.2631725 0.2631784 0.2631789 0.2631807
#  [3340] 0.2631917 0.2632062 0.2632207 0.2632243 0.2632244 0.2632373 0.2632388
#  [3347] 0.2632479 0.2632601 0.2632619 0.2632654 0.2632734 0.2632917 0.2633001
#  [3354] 0.2633024 0.2633037 0.2633158 0.2633159 0.2633210 0.2633218 0.2633218
#  [3361] 0.2633533 0.2633551 0.2633618 0.2633639 0.2633680 0.2633740 0.2633744
#  [3368] 0.2633751 0.2633784 0.2633811 0.2634008 0.2634096 0.2634125 0.2634137
#  [3375] 0.2634260 0.2634346 0.2634391 0.2634449 0.2634522 0.2634642 0.2634702
#  [3382] 0.2634708 0.2634713 0.2634716 0.2634742 0.2634744 0.2634849 0.2634936
#  [3389] 0.2634938 0.2634990 0.2635039 0.2635049 0.2635086 0.2635124 0.2635195
#  [3396] 0.2635231 0.2635275 0.2635297 0.2635361 0.2635395 0.2635422 0.2635424
#  [3403] 0.2635620 0.2635625 0.2635849 0.2635919 0.2635922 0.2635926 0.2636016
#  [3410] 0.2636062 0.2636114 0.2636241 0.2636332 0.2636438 0.2636475 0.2636480
#  [3417] 0.2636496 0.2636499 0.2636526 0.2636561 0.2636712 0.2636726 0.2637116
#  [3424] 0.2637120 0.2637197 0.2637265 0.2637287 0.2637314 0.2637325 0.2637337
#  [3431] 0.2637379 0.2637393 0.2637402 0.2637509 0.2637581 0.2637653 0.2637758
#  [3438] 0.2637773 0.2637796 0.2637866 0.2637870 0.2637918 0.2637969 0.2638014
#  [3445] 0.2638026 0.2638115 0.2638134 0.2638141 0.2638214 0.2638231 0.2638249
#  [3452] 0.2638333 0.2638347 0.2638351 0.2638443 0.2638475 0.2638595 0.2638649
#  [3459] 0.2638703 0.2638706 0.2638732 0.2638919 0.2638948 0.2639068 0.2639093
#  [3466] 0.2639143 0.2639271 0.2639279 0.2639331 0.2639339 0.2639406 0.2639424
#  [3473] 0.2639434 0.2639472 0.2639547 0.2639558 0.2639574 0.2639624 0.2639670
#  [3480] 0.2639746 0.2639806 0.2639812 0.2639823 0.2639823 0.2639840 0.2639841
#  [3487] 0.2639874 0.2639929 0.2640110 0.2640209 0.2640218 0.2640242 0.2640258
#  [3494] 0.2640267 0.2640351 0.2640354 0.2640382 0.2640388 0.2640413 0.2640455
#  [3501] 0.2640502 0.2640502 0.2640529 0.2640575 0.2640597 0.2640638 0.2640648
#  [3508] 0.2640679 0.2640766 0.2640801 0.2640937 0.2640994 0.2641004 0.2641007
#  [3515] 0.2641012 0.2641068 0.2641071 0.2641072 0.2641165 0.2641208 0.2641275
#  [3522] 0.2641328 0.2641364 0.2641367 0.2641367 0.2641394 0.2641573 0.2641693
#  [3529] 0.2641739 0.2641761 0.2641878 0.2641931 0.2641953 0.2642021 0.2642076
#  [3536] 0.2642130 0.2642166 0.2642220 0.2642224 0.2642233 0.2642339 0.2642351
#  [3543] 0.2642360 0.2642367 0.2642380 0.2642391 0.2642472 0.2642564 0.2642656
#  [3550] 0.2642661 0.2642662 0.2642744 0.2642796 0.2642885 0.2642931 0.2642942
#  [3557] 0.2643003 0.2643103 0.2643122 0.2643305 0.2643326 0.2643436 0.2643527
#  [3564] 0.2643564 0.2643634 0.2643801 0.2643825 0.2643843 0.2643986 0.2644206
#  [3571] 0.2644252 0.2644276 0.2644339 0.2644553 0.2644592 0.2644603 0.2644606
#  [3578] 0.2644625 0.2644649 0.2644685 0.2644687 0.2644705 0.2644821 0.2644856
#  [3585] 0.2644871 0.2644979 0.2644981 0.2645024 0.2645049 0.2645100 0.2645116
#  [3592] 0.2645151 0.2645175 0.2645266 0.2645271 0.2645310 0.2645461 0.2645517
#  [3599] 0.2645567 0.2645615 0.2645712 0.2645748 0.2645853 0.2645875 0.2645913
#  [3606] 0.2645954 0.2645965 0.2645965 0.2646000 0.2646165 0.2646202 0.2646278
#  [3613] 0.2646359 0.2646456 0.2646501 0.2646566 0.2646598 0.2646618 0.2646620
#  [3620] 0.2646714 0.2646770 0.2646824 0.2646843 0.2646851 0.2647038 0.2647095
#  [3627] 0.2647108 0.2647112 0.2647158 0.2647317 0.2647349 0.2647358 0.2647372
#  [3634] 0.2647378 0.2647482 0.2647487 0.2647496 0.2647507 0.2647525 0.2647542
#  [3641] 0.2647545 0.2647557 0.2647561 0.2647584 0.2647719 0.2647801 0.2647818
#  [3648] 0.2647861 0.2647915 0.2648000 0.2648025 0.2648153 0.2648212 0.2648242
#  [3655] 0.2648302 0.2648324 0.2648324 0.2648325 0.2648345 0.2648354 0.2648377
#  [3662] 0.2648378 0.2648500 0.2648559 0.2648592 0.2648605 0.2648713 0.2648728
#  [3669] 0.2648729 0.2648767 0.2648836 0.2648864 0.2648989 0.2649029 0.2649043
#  [3676] 0.2649071 0.2649086 0.2649089 0.2649095 0.2649099 0.2649431 0.2649442
#  [3683] 0.2649442 0.2649479 0.2649568 0.2649571 0.2649589 0.2649602 0.2649616
#  [3690] 0.2649618 0.2649649 0.2649688 0.2649729 0.2649751 0.2649753 0.2649860
#  [3697] 0.2649896 0.2649926 0.2649936 0.2650057 0.2650156 0.2650223 0.2650234
#  [3704] 0.2650493 0.2650577 0.2650636 0.2650648 0.2650651 0.2650668 0.2650757
#  [3711] 0.2650809 0.2650845 0.2650933 0.2651040 0.2651082 0.2651138 0.2651344
#  [3718] 0.2651367 0.2651456 0.2651491 0.2651554 0.2651610 0.2651670 0.2651723
#  [3725] 0.2651767 0.2651805 0.2651817 0.2651819 0.2651833 0.2651848 0.2651858
#  [3732] 0.2652039 0.2652049 0.2652106 0.2652122 0.2652132 0.2652203 0.2652206
#  [3739] 0.2652366 0.2652439 0.2652456 0.2652500 0.2652505 0.2652533 0.2652535
#  [3746] 0.2652582 0.2652596 0.2652649 0.2652682 0.2652719 0.2652725 0.2652745
#  [3753] 0.2652788 0.2652809 0.2652835 0.2652868 0.2652885 0.2652889 0.2652903
#  [3760] 0.2652938 0.2653093 0.2653164 0.2653219 0.2653298 0.2653302 0.2653320
#  [3767] 0.2653340 0.2653369 0.2653370 0.2653378 0.2653393 0.2653409 0.2653461
#  [3774] 0.2653560 0.2653576 0.2653580 0.2653587 0.2653622 0.2653711 0.2653740
#  [3781] 0.2653779 0.2653901 0.2653936 0.2654003 0.2654018 0.2654037 0.2654144
#  [3788] 0.2654249 0.2654279 0.2654286 0.2654311 0.2654529 0.2654667 0.2654706
#  [3795] 0.2654712 0.2654751 0.2654817 0.2654851 0.2654867 0.2655146 0.2655264
#  [3802] 0.2655345 0.2655402 0.2655479 0.2655499 0.2655555 0.2655605 0.2655667
#  [3809] 0.2655674 0.2655709 0.2655803 0.2655807 0.2655843 0.2655873 0.2655901
#  [3816] 0.2655990 0.2655998 0.2656001 0.2656079 0.2656231 0.2656246 0.2656256
#  [3823] 0.2656382 0.2656386 0.2656463 0.2656479 0.2656483 0.2656501 0.2656508
#  [3830] 0.2656510 0.2656514 0.2656524 0.2656527 0.2656623 0.2656667 0.2656673
#  [3837] 0.2656686 0.2656714 0.2656722 0.2656729 0.2656736 0.2656811 0.2656917
#  [3844] 0.2656920 0.2656976 0.2657107 0.2657128 0.2657146 0.2657244 0.2657248
#  [3851] 0.2657259 0.2657284 0.2657330 0.2657373 0.2657396 0.2657567 0.2657589
#  [3858] 0.2657628 0.2657637 0.2657658 0.2657703 0.2657728 0.2657767 0.2657805
#  [3865] 0.2657815 0.2657876 0.2657894 0.2657915 0.2657965 0.2657976 0.2657991
#  [3872] 0.2658056 0.2658117 0.2658213 0.2658267 0.2658297 0.2658330 0.2658374
#  [3879] 0.2658381 0.2658423 0.2658446 0.2658479 0.2658485 0.2658547 0.2658564
#  [3886] 0.2658593 0.2658662 0.2658675 0.2658680 0.2658826 0.2658854 0.2658873
#  [3893] 0.2658957 0.2658972 0.2658978 0.2659008 0.2659068 0.2659068 0.2659101
#  [3900] 0.2659174 0.2659230 0.2659234 0.2659255 0.2659320 0.2659419 0.2659446
#  [3907] 0.2659455 0.2659507 0.2659536 0.2659582 0.2659675 0.2659676 0.2659676
#  [3914] 0.2659678 0.2659804 0.2659836 0.2659855 0.2659873 0.2659918 0.2659931
#  [3921] 0.2659960 0.2659970 0.2660031 0.2660031 0.2660037 0.2660096 0.2660144
#  [3928] 0.2660155 0.2660159 0.2660177 0.2660284 0.2660301 0.2660361 0.2660413
#  [3935] 0.2660429 0.2660439 0.2660564 0.2660642 0.2660651 0.2660678 0.2660689
#  [3942] 0.2660704 0.2660712 0.2660743 0.2660751 0.2660780 0.2660786 0.2660838
#  [3949] 0.2660868 0.2660883 0.2661052 0.2661089 0.2661092 0.2661111 0.2661114
#  [3956] 0.2661137 0.2661199 0.2661216 0.2661325 0.2661481 0.2661490 0.2661534
#  [3963] 0.2661638 0.2661642 0.2661661 0.2661955 0.2662038 0.2662199 0.2662255
#  [3970] 0.2662299 0.2662356 0.2662480 0.2662496 0.2662541 0.2662651 0.2662654
#  [3977] 0.2662696 0.2662730 0.2662764 0.2662844 0.2662972 0.2663040 0.2663128
#  [3984] 0.2663280 0.2663289 0.2663299 0.2663376 0.2663378 0.2663475 0.2663508
#  [3991] 0.2663511 0.2663600 0.2663603 0.2663633 0.2663641 0.2663678 0.2663689
#  [3998] 0.2663709 0.2663729 0.2663775 0.2663800 0.2663850 0.2663851 0.2663940
#  [4005] 0.2663942 0.2663949 0.2664004 0.2664024 0.2664094 0.2664126 0.2664134
#  [4012] 0.2664138 0.2664182 0.2664186 0.2664248 0.2664251 0.2664269 0.2664317
#  [4019] 0.2664356 0.2664418 0.2664423 0.2664460 0.2664491 0.2664497 0.2664532
#  [4026] 0.2664649 0.2664653 0.2664667 0.2664699 0.2664744 0.2664896 0.2664908
#  [4033] 0.2664942 0.2664981 0.2665031 0.2665037 0.2665166 0.2665183 0.2665194
#  [4040] 0.2665215 0.2665236 0.2665288 0.2665315 0.2665321 0.2665348 0.2665426
#  [4047] 0.2665427 0.2665481 0.2665536 0.2665576 0.2665613 0.2665655 0.2665723
#  [4054] 0.2665786 0.2665890 0.2665915 0.2665936 0.2665983 0.2666074 0.2666093
#  [4061] 0.2666143 0.2666150 0.2666256 0.2666321 0.2666378 0.2666492 0.2666521
#  [4068] 0.2666589 0.2666731 0.2666735 0.2666744 0.2666809 0.2666847 0.2666888
#  [4075] 0.2666919 0.2666940 0.2666972 0.2667003 0.2667016 0.2667050 0.2667083
#  [4082] 0.2667108 0.2667139 0.2667274 0.2667352 0.2667399 0.2667400 0.2667424
#  [4089] 0.2667468 0.2667480 0.2667569 0.2667592 0.2667724 0.2667728 0.2667797
#  [4096] 0.2667808 0.2667821 0.2667921 0.2667977 0.2668000 0.2668016 0.2668041
#  [4103] 0.2668133 0.2668155 0.2668164 0.2668164 0.2668223 0.2668252 0.2668341
#  [4110] 0.2668409 0.2668410 0.2668449 0.2668451 0.2668455 0.2668484 0.2668557
#  [4117] 0.2668574 0.2668636 0.2668636 0.2668766 0.2668791 0.2668809 0.2668838
#  [4124] 0.2668871 0.2668910 0.2668970 0.2669016 0.2669060 0.2669088 0.2669179
#  [4131] 0.2669211 0.2669227 0.2669394 0.2669421 0.2669449 0.2669509 0.2669535
#  [4138] 0.2669560 0.2669654 0.2669757 0.2669796 0.2669803 0.2669815 0.2669881
#  [4145] 0.2670023 0.2670059 0.2670147 0.2670184 0.2670192 0.2670203 0.2670237
#  [4152] 0.2670285 0.2670359 0.2670359 0.2670368 0.2670373 0.2670426 0.2670436
#  [4159] 0.2670634 0.2670645 0.2670692 0.2670720 0.2670780 0.2670868 0.2670935
#  [4166] 0.2671141 0.2671175 0.2671183 0.2671195 0.2671203 0.2671210 0.2671382
#  [4173] 0.2671441 0.2671454 0.2671507 0.2671542 0.2671613 0.2671640 0.2671671
#  [4180] 0.2671741 0.2671830 0.2671893 0.2672071 0.2672158 0.2672160 0.2672286
#  [4187] 0.2672313 0.2672446 0.2672458 0.2672458 0.2672557 0.2672564 0.2672685
#  [4194] 0.2672693 0.2672706 0.2672724 0.2672759 0.2672814 0.2672877 0.2672904
#  [4201] 0.2672947 0.2672947 0.2673067 0.2673266 0.2673270 0.2673276 0.2673287
#  [4208] 0.2673319 0.2673327 0.2673337 0.2673353 0.2673365 0.2673522 0.2673562
#  [4215] 0.2673619 0.2673628 0.2673672 0.2673720 0.2673726 0.2673803 0.2673826
#  [4222] 0.2673877 0.2673919 0.2673931 0.2673953 0.2673996 0.2674022 0.2674034
#  [4229] 0.2674034 0.2674059 0.2674083 0.2674169 0.2674260 0.2674314 0.2674328
#  [4236] 0.2674355 0.2674569 0.2674603 0.2674629 0.2674638 0.2674641 0.2674734
#  [4243] 0.2674797 0.2674823 0.2674865 0.2674871 0.2674893 0.2674909 0.2674944
#  [4250] 0.2675013 0.2675025 0.2675069 0.2675143 0.2675174 0.2675204 0.2675211
#  [4257] 0.2675313 0.2675400 0.2675516 0.2675571 0.2675689 0.2675713 0.2675750
#  [4264] 0.2675767 0.2675801 0.2675807 0.2675812 0.2675842 0.2675851 0.2675874
#  [4271] 0.2675876 0.2675892 0.2675905 0.2675971 0.2675976 0.2675997 0.2676149
#  [4278] 0.2676226 0.2676327 0.2676375 0.2676393 0.2676530 0.2676614 0.2676615
#  [4285] 0.2676653 0.2676668 0.2676702 0.2676852 0.2676861 0.2676862 0.2676940
#  [4292] 0.2677023 0.2677164 0.2677341 0.2677384 0.2677395 0.2677467 0.2677580
# ...
# [22429] 138 152 161  77  51 138   8  41 161  45 107 126  33  70 138  25  67  91
# [22447]  55  17  20  75  34 141 161  30   3  70  70  85   6  77 100  62  92  37
# [22465] 164 138  69 105  96  70 198  95  74  37 142  57  30  91  75 131  61  91
# [22483] 153 169  55  75  42 159  77  61  79   6  72  70  47 113  30 119  38 138
# [22501]  97  76 122 158 139 119  90  20  70   1  70 100  75 149  90  98  15 119
# [22519] 160  54  59  55 127  91 114 121  29  17 100  30 186   8  97 164 100  20
# [22537]  67  11 128  70  40  49  71 121  33 132 121  67 100 149  87  15 100 161
# [22555]  17  29 152  18  79  18 160  72 168 181  26  61  99  19  66  20  25  58
# [22573] 191  15  84  91 156  54 142 101 127 140  97   3  50  70  20  57  45  77
# [22591] 157  97  61 139 131  65 142 109  82  42  97 153 110 135  42  40 128   5
# [22609]  96 149 105 155  92  56 119  36  37  90   4   6 138 137  25  33 117  25
# [22627] 139   6  54  70 117 105 155  41 161 117  36  25   1  50   9 120 130  25
# [22645]  91 116 117  30  33 183 196  75 145  99 137  87  70 181 144  99 206 107
# [22663]  63  56 126  18  44 115  26  51  26 117  68  50  95 102 103  13  71 126
# [22681]  99  74 104   3 133  85  83   5 117 144  95 155 137 178  38 206  97 121
# [22699]  65  75 121  97 128  73  73 181 201  67 103 173 137   5  85  20  64  25
# [22717]  57 102  82 137 137  55  33 105  61 100  99 127  34 144 111  88 142  69
# [22735] 141  67 102  65  69 183  97 160  45  54  28   6 121  95  91  20  52  18
# [22753]  25 121 121  70  10  25  89  98  55  20  99 202  10  51  77  29  28 119
# [22771]  99  77 161 168  19 108 117   1 105  37 155  58 149 117  76  25  12  69
# [22789]  51  40 192  33  51  67   6  61  98 184 118  99  44 121  89  93  28 202
# [22807] 138 136  20  85  17  36 194  15  18  42 164   6  33 142  47  25 142  99
# [22825]  91  80  39  77 131  97  99  70  77 114 121  73  91  84  61 120  87  63
# [22843]  74  24  70  17  84  91 102 133 136  25  91 152  91 173  72  37  96 182
# [22861]  50 170 161  72  97 108  17  76 127  75  84 126  35  46 105  55 138  18
# [22879]  12 132 113 118  35 173  35 142  72 129  99   5  70 135  19 178  72 163
# [22897]  97  70 161 155  29 173  20  43 183 140  95 105 106  16 119  25 107  56
# [22915]  38  70 129  72 161  69  19  75 161  33 142 104  30 132  33  33 164 178
# [22933]   2  36  45  47 142  55 132 101  20  91  79  33  71 156 151 178  61  36
# [22951]  65  91  42 114 100 146  33  45  38  99 100 174  20  81 119  48 178  36
# [22969]  70  88  75 112   6 103 173  20  58  30 119  65 161  69  97 197 121 102
# [22987]  16 105  66  95 122  33 173 107  90 155  91  99 121 102 181 122 161 129
# [23005]  47  33  83  50  97 121 167  20 128  51  33 115 127  18  18  72  77  97
# [23023]  31  35  97 102  91 127  91  97  22  21  20  97 135  26  82 176 161 161
# [23041]  83   4 178  97  97  98 121 113  81 127  33 150  82  30 155  64  25  32
# [23059]  33  88  36  70 118  82 138  25 115  97  97   4  33  58  61  97 106  72
# [23077] 100  50 142 142  70  97  42  72  55  89   6   5 142  75  51  56 152  72
# [23095]  97 119 140  45 140 142 173  69  25 121  75 138  13 136  99 127 146 173
# [23113] 127  87 138   2   5  99  41  96  10 173  22 173  27 142 124  87  73  13
# [23131] 142 100 138 127 149 106  93  20 178 143  16 102 124  14 117 157 185  72
# [23149] 149  77 160 172  33  35 167  70   7 117 149  45  97  44  98  91 119  25
# [23167] 177  29 138 148 142  95  20 157 136 211 183 119 161 123   6 173  51  42
# [23185] 178  33 115  35  65  46 161 121  97  13 164  17   9  79 169  79  97  34
# [23203]  66  58  99 142 115  91  91 142 112  47 181  21  76 116  82 117 127  36
# [23221] 155  20 121 100 117  97  72  25  91 143  25  25   5 161 119 192 121  12
# [23239]  91  64 178  16  26 161 125  40 158   5  61  31 161  71 119 108 113  47
# [23257] 102 155  45   2  18  97  41 129   6  57 137 160  85 161  26 146  48  70
# [23275] 197 100 119 124  61  25  30 142  43 111  27  42  75  77 190  81 138  74
# [23293]  91  32  18  25 148  49  42  25 142  10  97  75 175  16  20 127 102  55
# [23311] 141  86 203  72  17 121  44  31 173 121 121  20  21  89   3  34 161  70
# [23329] 121  18 117  17 137  56 127 142  97  60 173  12  77 119 154  77 173  20
# [23347]  30  88   1 117   2  63  97  97 102  25  25  69  25  66 117 141   4  59
# [23365]  77 160 136  31 160 152   7 161  69  93  97  88  97  70 194  45 134 178
# [23383]  25 121 151   9 103 112  20 142 121  95 142  33  72 104  29 127  27 191
# [23401] 156  44  72  54  22   5  97  25  55  71  41  30 155  17 121  76 121 105
# [23419]  90   7  86   5  81 138  43  25 121   7  26  69  91 149  95 100  69  61
# [23437]  45  77  37  51  21  77  27 121 121 197 161 191 142 117  42  75 104 119
# [23455]  99  58  34  25 161 142  24 161  97   9  39 123 191 194 147  65 128  99
# [23473]  77  38  25  18 121 173  70  30 134 127  47  30  97 150  82  40  77   9
# [23491] 160 107  65 100  21 154 105 203 161 100  25 151 120  33 147  91  99 181
# [23509]  72 161 155 105  70  42   8  14  97  93  85  82 102  70  35 102 114  14
# [23527] 102  30 164 133 157 178  86  69  36 197  46 121 165 138  18  56 173  70
# [23545]  10  45 151 105 102 142 137 151 142  41  17 161  43 121  65 202   5  91
# [23563]  97  14  13   1  97  17  91 119  72 142   2  20 125  99 173 108 142  27
# [23581] 161  32  74  92 111  86  94  77  97  43  25  69 142  33  25 183 160 171
# [23599] 152 121  49  79  25   4  23  93  91 121 100  97  91 178 121  55  49  25
# [23617]  77  97 162  41  97  97 127 119  51 138 117   4  99  94 121 159  91 127
# [23635]  33  25   7   5 142  33 112  13  18 130   1 138  25   6 121  20  85  87
# [23653]  70  25  99  47 164 133  70 178   3  32 181 116 181  76  39 125  97  25
# [23671] 196  37  70 124 138  91 105 178 142 110  99 178  30 160  53  76 206 121
# [23689]  54 158 142  91  14 173  69  76  82 121  91 132 161  33  49   5  74  77
# [23707] 127 129 203  78 112  25 159  97 137  20  86 173  97  41  25 145  20  97
# [23725] 153  26   1   3 121 142  91 127  11  97  62  91 173  25  97 142  72  70
# [23743] 128  66  49  99 161 144  97  97 142  91 121  25   6 121 151  97  91  18
# [23761] 114 161 117  70 100  59 140  20  69  25 142  74 142 145  91 173 121  70
# [23779] 178  39  79  25 121 202  95  17 161  70 121 173  36  38  80  42  33  39
# [23797]  56 102  25  64 131  33  97  97  97  97  25  17  42 156 160   9  18 109
# [23815] 161  68  87  25  59 161 173 135 166 117   3 178 119  15  91  60  87  37
# [23833] 142 142  41  72 132  18  91 131  33 161  20 211 178 127  99   6 115  17
# [23851]  49 121 202 173 131  60 126 142  81  83  25  50 121 160  29 121  52  97
# [23869] 121 142 121  51  91  95 121 100 121  91 142  69  99 142 122 101  97  42
# [23887]  17 127 142 121 178  99 105 138  59  60 142  69   6  99  97 121  72  67
# [23905]  25  97  39 178  91  18  97  77  77  25 121  25  74 161  60  25  28  81
# [23923] 161 142 164  97 121  45  95 121  97 119 181  60  47  39  75  97  25  25
# [23941] 170  91 156  77 138   3 121 161  87  97 173   3 121  59  91 172  33  97
# [23959] 142  37  81   5  19  61  95  59  34 119  98 142 161 121 155 149  74 152
# [23977]  97 178  91  99  41 157  97 121 126   6   6 136  31  97  97 178 142  97
# [23995] 117  97   6  17  97  37 161  97  97  97  42 100 169  36   3  30 135  25
# [24013]  97 137  87  42 102  55  69  97 173  18  70 138  99  17 140 160 126  97
# [24031] 173  18  97  65 173 161  69 173  95  18 161 161 105  99   5  37  97 161
# [24049]  42 127  97  25 121 100 105 142  87 135  17  25  33 157 178 140 178 178
# [24067]  99  72  97  25  20  91 121 173 178  97 105  69 178  77 161  97 119  99
# [24085] 178  97 161  25 121 173
#
# $xinit
#   [1] 0.162816664 0.310432303 0.466289169 0.244696636 0.695138175 0.187049841
#   [7] 0.455657917 0.949432347 0.132701553 0.993439117 0.132313861 0.031937173
#  [13] 0.320379180 0.550512092 0.431132594 0.774866396 0.943280204 0.673329776
#  [19] 0.787535598 0.209756803 0.740312307 0.320221891 0.548330365 0.280687433
#  [25] 0.523693270 0.779148391 0.654883171 0.285499157 0.933988020 0.704633574
#  [31] 0.022578513 0.722920760 0.400899940 0.479162655 0.143929534 0.154036092
#  [37] 0.954726713 0.606444091 0.732689651 0.461330462 0.331106529 0.182179246
#  [43] 0.565733249 0.462973503 0.587781248 0.399424087 0.357480546 0.861071958
#  [49] 0.136796328 0.755106457 0.474066098 0.264329373 0.294070983 0.230097430
#  [55] 0.487791059 0.400446362 0.165821313 0.754492014 0.946466734 0.523252906
#  [61] 0.425345618 0.117927795 0.284398499 0.800113686 0.726984364 0.656093179
#  [67] 0.979366662 0.390575391 0.078740063 0.966643005 0.510728112 0.744465123
#  [73] 0.838596815 0.899381079 0.147304927 0.590496287 0.912739206 0.433547476
#  [79] 0.326998960 0.152620816 0.380880834 0.098441018 0.191091213 0.965535951
#  [85] 0.577456291 0.606389965 0.738367910 0.086710677 0.874085613 0.720712119
#  [91] 0.111620368 0.641038161 0.029998499 0.311409792 0.842907583 0.358276230
#  [97] 0.067710331 0.035636941 0.885003200 0.424538518 0.851912329 0.142056803
# [103] 0.246104901 0.785243106 0.033062876 0.988854291 0.798791971 0.632588544
# [109] 0.354143688 0.136086697 0.936463494 0.404683851 0.787445578 0.322456668
# [115] 0.568378896 0.246446753 0.331911608 0.188536773 0.371591620 0.190608642
# [121] 0.881327570 0.485402637 0.065597964 0.570369974 0.368608701 0.587008990
# [127] 0.369477531 0.024146218 0.911237339 0.663751469 0.036359573 0.956136851
# [133] 0.104728892 0.379666998 0.624762790 0.683226670 0.136095617 0.832309949
# [139] 0.203101871 0.537756545 0.234065499 0.554036685 0.467103921 0.655067356
# [145] 0.835746339 0.768676801 0.411351274 0.492322839 0.771904573 0.783306430
# [151] 0.418173796 0.032875761 0.157305688 0.285040678 0.547134258 0.625397304
# [157] 0.019632911 0.679290842 0.905098475 0.902042313 0.592001417 0.963641680
# [163] 0.950071179 0.071625635 0.213656566 0.841993074 0.166760655 0.723131121
# [169] 0.692372204 0.684849994 0.730814398 0.080457340 0.781572653 0.286361150
# [175] 0.699658110 0.559720634 0.683689730 0.226044807 0.009983733 0.668949569
# [181] 0.993264445 0.218987843 0.696380599 0.578462648 0.453463030 0.469324757
# [187] 0.738210157 0.725031512 0.957046167 0.974057748 0.166289578 0.596079045
# [193] 0.126138181 0.497222243 0.445497575 0.359859203 0.716606518 0.162492855
# [199] 0.438336639 0.181421285 0.412225188 0.791160005 0.458705022 0.218926004
# [205] 0.035557158 0.283368549 0.583813477 0.296178130 0.334773386 0.749459762
# [211] 0.141548076 0.136016331 0.005896705 0.156988541 0.438491094 0.259527347
# [217] 0.698101431 0.535976982 0.650089130 0.333668015 0.601319477 0.183920607
# [223] 0.685152640 0.907440291 0.687958404 0.112188820 0.608848338 0.185029405
# [229] 0.388951378 0.420842914 0.463407733 0.808179025 0.842211611 0.535075336
# [235] 0.710026975 0.513585008 0.935018523 0.598835313 0.601808525 0.296663198
# [241] 0.106674613 0.254936009 0.852417569 0.644099455 0.938256753 0.351877773
# [247] 0.628497355 0.353679827 0.454216197 0.889407087 0.553291029 0.821525858
# [253] 0.154937951 0.239131182 0.021946211 0.028830891 0.102287800 0.192180793
# [259] 0.085083733 0.729310298 0.725084793 0.075092712 0.347519941 0.771717795
# [265] 0.114752492 0.432267371 0.376465323 0.134574319 0.535501884 0.053729566
# [271] 0.750491793 0.125456356 0.538106006 0.933642616 0.466301381 0.196875686
# [277] 0.783078603 0.591141538 0.413937919 0.603154754 0.437810818 0.018760947
# [283] 0.409243321 0.249739480 0.485846364 0.956374225 0.671468467 0.322569691
# [289] 0.582253808 0.396076118 0.545628549 0.711380890 0.066267779 0.432179370
# [295] 0.395238364 0.527313057 0.126240605 0.735637990 0.675149093 0.822532741
# [301] 0.685816460 0.912572862 0.664125425 0.039411893 0.326995783 0.417934047
# [307] 0.428655642 0.618811325 0.086863472 0.796815688 0.936384367 0.507645862
# [313] 0.342562345 0.369957687 0.113600550 0.765811843 0.115061512 0.027742371
# [319] 0.509288000 0.180777478 0.580392996 0.078759688 0.408819809 0.904261607
# [325] 0.744859735 0.122177149 0.605619862 0.849664959 0.895982418 0.721110834
# [331] 0.109242014 0.008162226 0.433239527 0.010484366 0.874573913 0.050583435
# [337] 0.214451505 0.080332904 0.754856387 0.921768599 0.110976943 0.778296222
# [343] 0.861351829 0.998068051 0.696862195 0.785955975 0.993650238 0.827774096
# [349] 0.204387644 0.716299523 0.958822342 0.675452452 0.118216891 0.406233923
# [355] 0.880164110 0.361464847 0.437726717 0.601846504 0.341090919 0.222153753
# [361] 0.576188230 0.876718775 0.048540133 0.423894054 0.791626911 0.505943466
# [367] 0.882586780 0.048815709 0.713080903 0.399698626 0.756092104 0.972336685
# [373] 0.305806271 0.463918660 0.503916953 0.518618708 0.268825145 0.190252589
# [379] 0.420314015 0.618234821 0.345189380 0.480749338 0.078299627 0.232195517
# [385] 0.226449899 0.909839496 0.405237304 0.365318583 0.550995084 0.614944551
# [391] 0.420275287 0.425063532 0.083355702 0.914539205 0.052497280 0.224323365
# [397] 0.861087526 0.122187477 0.779629835 0.168172818 0.130274307 0.924606754
# [403] 0.467575455 0.207531394 0.572768689 0.886983416 0.535913761 0.382788435
# [409] 0.307559167 0.800951316 0.171013601 0.985937868 0.734985920 0.321280337
# [415] 0.814013677 0.686493313 0.865815786 0.638762630 0.095640030 0.311839420
# [421] 0.714934002 0.766086604 0.171946631 0.963433414 0.506962143 0.209016928
# [427] 0.415079060 0.066535320 0.801268036 0.833254620 0.850461503 0.411784446
# [433] 0.692284486 0.817239217 0.365227574 0.513599200 0.075632688 0.133093545
# [439] 0.069460318 0.259888939 0.686576491 0.433922379 0.469467941 0.692912644
# [445] 0.510604779 0.248833780 0.353237214 0.096424447 0.016235144 0.075957668
# [451] 0.139107337 0.272396437 0.018989723 0.504467772 0.162375872 0.478482450
# [457] 0.450738413 0.932725746 0.664386812 0.153026125 0.236873306 0.446309306
# [463] 0.917735905 0.941701321 0.147723048 0.172130557 0.454842014 0.900249205
# [469] 0.635152362 0.781596404 0.423993365 0.947650295 0.557203587 0.398054035
# [475] 0.755273469 0.864682933 0.954390206 0.648200589 0.086543482 0.011586181
# [481] 0.527523177 0.533617364 0.273816379 0.356492873 0.019825910 0.660022989
# [487] 0.237019415 0.943077234 0.640114964 0.959703658 0.082790012 0.372620594
# [493] 0.710954886 0.244652248 0.206493117 0.382460305 0.490688861 0.398351741
# [499] 0.443208939 0.140405036 0.058356413 0.325919398 0.984150636 0.335639576
# [505] 0.803557686 0.020647484 0.556591102 0.953561944 0.632080740 0.232100053
# [511] 0.673448982 0.067372509 0.573156057 0.496514358 0.658297360 0.484543675
# [517] 0.831053637 0.692517178 0.593826673 0.184200379 0.612441679 0.067648627
# [523] 0.943004908 0.315847332 0.118201951 0.662439126 0.412419826 0.755744991
# [529] 0.074825869 0.551889605 0.191940358 0.259279781 0.225761760 0.493087417
# [535] 0.557185696 0.389879154 0.993141240 0.597538901 0.567494822 0.637524906
# [541] 0.533433218 0.210741592 0.770554113 0.620008953 0.837718017 0.962257606
# [547] 0.483203009 0.069343867 0.634243261 0.226141145 0.670122929 0.346452322
# [553] 0.967102164 0.213877170 0.810608542 0.630320566 0.763419039 0.315248823
# [559] 0.592835644 0.754936422 0.555824206 0.357551358 0.379738092 0.888286625
# [565] 0.737904087 0.804029693 0.602952647 0.935453079 0.460606879 0.812772366
# [571] 0.365024762 0.738291837 0.225567482 0.721479853 0.593619679 0.177362812
# [577] 0.498026455 0.042375723 0.016082983 0.598042168 0.113420364 0.534215743
# [583] 0.460820246 0.177624905 0.973274055 0.658924239 0.344905376 0.581677457
# [589] 0.187392674 0.731787941 0.005193067 0.200337371 0.945024008 0.618614915
# [595] 0.274644678 0.669251287 0.497257382 0.808293422 0.338232456 0.463989294
# [601] 0.141008510 0.265383940 0.666759321 0.932974510 0.099652237 0.456523821
# [607] 0.736464915 0.096844221 0.099602768 0.245443375 0.788427670 0.631467379
# [613] 0.754314668 0.944312313 0.747571404 0.181940824 0.249114469 0.129478093
# [619] 0.849018534 0.398492290 0.812107279 0.031256018 0.503478626 0.365039808
# [625] 0.193932861 0.355145819 0.324966595 0.742300777 0.016674725 0.142075518
# [631] 0.213248686 0.244312761 0.114040509 0.829178785 0.475934692 0.453021355
# [637] 0.564035762 0.633891457 0.363205389 0.800214875 0.033245396 0.957534328
# [643] 0.769663845 0.194920265 0.840169886 0.656191550 0.233108773 0.521948252
# [649] 0.281818010 0.128420202 0.860918560 0.035765657 0.207862337 0.218625909
# [655] 0.421610514 0.963055693 0.037633567 0.392897499 0.091701498 0.633432237
#
# $istart
# [1] 1

# %%
# %%R
# p.F = plot_ordination(physeq, dist.bray.nmds, justDF = TRUE)
# head(p.F)
# Out:
#                       NMDS1        NMDS2      X.sampleID TubeID ExtractionPlate
# ERA-T2_3-1d_85  -0.02571316  0.084649997  ERA-T2_3-1d_85    425            ERA4
# ERA-T1_3-5c_170  0.02812918  0.029247695 ERA-T1_3-5c_170    213            ERA4
# ERA-T2_1-5a_85   0.07903011  0.003207355  ERA-T2_1-5a_85    382            ERA3
# ERA-T1_1-2b_170  0.01229517  0.042195685 ERA-T1_1-2b_170    125            ERA1
# ERA-T1_1-4b_0    0.08268755 -0.040780456   ERA-T1_1-4b_0    144            ERA1
# ERA-T1_4-3d_0    0.09893197  0.004015153   ERA-T1_4-3d_0    232            ERA3
#                 PooledDNAPlate Sample.Well.ID PrimerPlate Primer.Number
# ERA-T2_3-1d_85               B             E5           2            37
# ERA-T1_3-5c_170              B             D3           2            20
# ERA-T2_1-5a_85               C             D5           3            16
# ERA-T1_1-2b_170              A             A1           1             1
# ERA-T1_1-4b_0                A             C4           1            27
# ERA-T1_4-3d_0                C             D8           3            39
#                 Primer.Well.ID  X primerFwdLoc primerRevLoc fwd_barcode
# ERA-T2_3-1d_85              E5 NA          2-E          2-5    ACGTCTCG
# ERA-T1_3-5c_170             D3 NA          2-D          2-3    TACGAGAC
# ERA-T2_1-5a_85              H2 NA          3-H          3-2    GACACCGT
# ERA-T1_1-2b_170             A1 NA          1-A          1-1    ATCGTACG
# ERA-T1_1-4b_0               C4 NA          1-C          1-4    TAGCGAGT
# ERA-T1_4-3d_0               G5 NA          3-G          3-5    GGATATCT
#                 rev_barcode   PlotID TimePoint Rep Row Pos Fert PlotIndex Plant
# ERA-T2_3-1d_85     CGTACTCA  3-1d_85        T2   3   1   d   85       130 34M95
# ERA-T1_3-5c_170    AGTAGCGT 3-5c_170        T1   3   5   c  170       177   330
# ERA-T2_1-5a_85     ATACTTCG  1-5a_85        T2   1   5   a   85        49  Bare
# ERA-T1_1-2b_170    AACTCTCG 1-2b_170        T1   1   2   b  170        16   330
# ERA-T1_1-4b_0      CAGTGAGT   1-4b_0        T1   1   4   b    0        42 34M95
# ERA-T1_4-3d_0      CGTAGATC   4-3d_0        T1   4   3   d    0       215  Bare
#                 Genotype SeedTreatment R_Year ERA BG_activity.g BX_activity.g
# ERA-T2_3-1d_85     34M95       Treated   2001   3     118.34208      15.36496
# ERA-T1_3-5c_170      330       Treated   1939   1      74.45039      21.77484
# ERA-T2_1-5a_85      Bare                   NA  NA      43.31686      11.52797
# ERA-T1_1-2b_170      330       Treated   1939   1      96.79331      21.01421
# ERA-T1_1-4b_0      34M95       Treated   2001   3      63.29524      17.04118
# ERA-T1_4-3d_0       Bare                   NA  NA      43.63613      13.97329
#                 CB_activity.g LAP_activity.g NAG_activity.g Stage kgdw_ha
# ERA-T2_3-1d_85       18.47109      112.59693      20.604202    R1 10873.5
# ERA-T1_3-5c_170      22.76533       51.22149      20.166138    V6   301.5
# ERA-T2_1-5a_85       13.50582      207.03002       9.706186    R1      NA
# ERA-T1_1-2b_170      21.70019       46.58059      20.246058    V6   269.4
# ERA-T1_1-4b_0        13.62927       35.16869      16.516824    V6   291.6
# ERA-T1_4-3d_0        13.46967       26.70212      11.996429    V6      NA
#                 FracN.leco FracC.leco     kgN_ha        RGR        AGR
# ERA-T2_3-1d_85    0.012280    0.44145 133.526580 0.07679324 306.648387
# ERA-T1_3-5c_170   0.025878    0.41664   7.802217 0.06068723   7.891667
# ERA-T2_1-5a_85          NA         NA         NA         NA         NA
# ERA-T1_1-2b_170   0.032903    0.40984   8.864068 0.05829207   7.000000
# ERA-T1_1-4b_0     0.018950    0.41287   5.525820 0.05997687   7.616667
# ERA-T1_4-3d_0           NA         NA         NA         NA         NA
#                     Nprod      NupR     d15N X15N_AtPercent      FracN
# ERA-T2_3-1d_85  2.2965344 3.5288531 402.5888      0.5130163 0.01223815
# ERA-T1_3-5c_170 1.0114646 0.1598961       NA             NA         NA
# ERA-T2_1-5a_85         NA        NA       NA             NA         NA
# ERA-T1_1-2b_170 0.7897051 0.1824887       NA             NA         NA
# ERA-T1_1-4b_0   1.3783776 0.1114621       NA             NA         NA
# ERA-T1_4-3d_0          NA        NA       NA             NA         NA
#                 FracN_fromSoil FracN_fromFert kgFertN_ha kgSoilN_ha     Planted
# ERA-T2_3-1d_85       0.7789229      0.2210771   29.41906   103.6524 Rhizosphere
# ERA-T1_3-5c_170             NA             NA         NA         NA Rhizosphere
# ERA-T2_1-5a_85              NA             NA         NA         NA        Bare
# ERA-T1_1-2b_170             NA             NA         NA         NA Rhizosphere
# ERA-T1_1-4b_0               NA             NA         NA         NA Rhizosphere
# ERA-T1_4-3d_0               NA             NA         NA         NA        Bare

# %%
# %%R
#
# p = ggplot(p.F,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=Planted)) +
#     theme_pub()
#
# p

# %%
# %%R
# ordMean = p.F %>%
#     group_by(Genotype, R_Year, Fert, TimePoint) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %% [markdown]
# # NMDS of global data faceted by sampling date

# %%
# %%R -w 800 -h 400
# pF = ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = Fert), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2")+
#    facet_wrap(~TimePoint)+
#     ggtitle("T1")
#
# pF

# %% [markdown]
# ### Closer look at T2

# %%
# %%R
# p1 =    ggplot(subset(ordMean, TimePoint == "T2"), aes(x = R_Year, y = mAxis.1)) +
#     geom_point() +
#     ylim(c(-0.12, 0.12))+
#      geom_errorbar(aes(ymin = mAxis.1 - seAxis.1, ymax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     stat_smooth(method = "lm", formula = y ~ poly(x,2))
#
# p2 =    ggplot(subset(ordMean, TimePoint == "T2"), aes(x = R_Year, y = mAxis.2)) +
#     geom_point() +
#      ylim(c(-0.08, 0.08))+
#      geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002)+
#     stat_smooth(method = "lm", formula = y ~ poly(x,2))
#
#
#     stat_smooth(method = "lm", formula = y ~ poly(x,2))
# p3 =    ggplot(subset(ordMean, TimePoint == "T2" & Genotype == "Bare"), aes(x = Genotype, y = mAxis.1)) +
#     geom_point() +
#     ylim(c(-0.12, 0.12))+
#      geom_errorbar(aes(ymin = mAxis.1- seAxis.1, ymax = mAxis.1 + seAxis.1),
#                 color = "black",
#                 width = .002)+
#     stat_smooth(method = "lm", formula = y ~ poly(x,2))
#
# p4 =    ggplot(subset(ordMean, TimePoint == "T2" & Genotype == "Bare"), aes(x = Genotype, y = mAxis.2)) +
#     geom_point() +
#      ylim(c(-0.08, 0.08))+
#      geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002)+
#     stat_smooth(method = "lm", formula = y ~ poly(x,2))
#
# grid.arrange(p1, p3, p2,p4,  ncol = 2, widths = c(2,1))

# %%
# %%R
# ## generating plots
# p1 = ggplot(p.F, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=R_Year), pch = 21, size = 3)
#         #scale_size(range=c(2,8))
#
# #p2 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         #geom_point(aes(fill=Plant, size = BD), pch=21) +
#         #scale_size(range=c(2,8))
#
# grid.arrange(p1, ncol=1)

# %%
# %%R -w 600 -h 350
# p2 = p1 + facet_wrap(~TimePoint)+
# theme_pub()
# p2

# %%
# Create faceted figure with full dataset

# %% [markdown]
# # Adonis sampling date by rhizosphere effect

# %%
# %%R
# phy.core = subset_samples(physeq, Genotype %in% c("Bare","330", "354", "3517", "3475", "34M95", "P1151HR") &
#                          Fert == "85"  & TimePoint != "T0")

# %%
# %%R
# sample_data(phy.core)$Planted
# Out:
#  [1] "Rhizosphere" "Bare"        "Rhizosphere" "Rhizosphere" "Rhizosphere"
#  [6] "Rhizosphere" "Bare"        "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [11] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere" "Bare"
# [16] "Rhizosphere" "Bare"        "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [21] "Rhizosphere" "Rhizosphere" "Bare"        "Rhizosphere" "Bare"
# [26] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [31] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [36] "Bare"        "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [41] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [46] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Bare"        "Rhizosphere"
# [51] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [56] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [61] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Bare"        "Rhizosphere"
# [66] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"
# [71] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Bare"        "Rhizosphere"
# [76] "Rhizosphere" "Bare"        "Bare"        "Rhizosphere" "Rhizosphere"
# [81] "Rhizosphere" "Rhizosphere" "Rhizosphere" "Rhizosphere"

# %%
# %%R
# registerDoParallel(cores=28)
# bray.dist = distance(phy.core,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
# df = as(sample_data(phy.core), "data.frame")
# d = bray.dist
# df$Fert = as.factor(df$Fert)
# Fulladonis = adonis(formula = d ~ Rep + Planted + TimePoint + Planted:TimePoint, df,
#                     permutations = 999)
# Fulladonis
# Out:
# Call:
# adonis(formula = d ~ Rep + Planted + TimePoint + Planted:TimePoint,      data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#                   Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# Rep                3    0.2297 0.07658  1.9626 0.06110  0.001 ***
# Planted            1    0.3265 0.32646  8.3667 0.08683  0.001 ***
# TimePoint          2    0.2099 0.10493  2.6892 0.05582  0.001 ***
# Planted:TimePoint  2    0.0675 0.03373  0.8645 0.01794  0.832
# Residuals         75    2.9264 0.03902         0.77832
# Total             83    3.7599                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Dissimiliarity by time point

# %% [markdown]
# ## T1 adonis

# %%
# %%R
# physeq.plantT1 = subset_samples(physeq,  Planted == "Rhizosphere" & TimePoint == "T1")
# physeq.plantT1
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 72 samples ]
# sample_data() Sample Data:       [ 72 samples by 47 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %%
# %%R
# registerDoParallel(cores=28)
# T1.wunif.dist = distance(physeq.plantT1,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T1.bray.dist = distance(physeq.plantT1,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
# df = as(sample_data(physeq.plantT1), "data.frame")
#
# print("Bray-curtis")
#
# d = T1.bray.dist
# T1adonis = adonis(formula = d ~ Rep + Fert + Genotype, df, permutations = 999)
# T1adonis %>% print
#
# print("w-UniFrac")
# d = T1.wunif.dist
# T1adonis = adonis(formula = d ~ Rep + Fert + Genotype, df, permutations = 999)
# T1adonis
# Out:
# [1] "Bray-curtis"
#
# Call:
# adonis(formula = d ~ Rep + Fert + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Rep        3   0.25265 0.084216 2.19360 0.08753  0.001 ***
# Fert       2   0.07153 0.035766 0.93162 0.02478  0.740
# Genotype   5   0.22049 0.044098 1.14864 0.07639  0.026 *
# Residuals 61   2.34189 0.038392         0.81131
# Total     71   2.88656                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "w-UniFrac"
#
# Call:
# adonis(formula = d ~ Rep + Fert + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# Rep        3  0.037211 0.0124038  3.2048 0.12446  0.001 ***
# Fert       2  0.005278 0.0026391  0.6819 0.01765  0.915
# Genotype   5  0.020408 0.0040816  1.0545 0.06825  0.365
# Residuals 61  0.236096 0.0038704         0.78964
# Total     71  0.298993                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# * Genotype has a significant effect on Bray-curtis distance, but not weighted unifrac
# * Fertilization and genotype do not predict MCC at T1, nor does R_Year

# %%
### Ordinate T1

# %%
# %%R
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T1.bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.1451364
# Run 1 stress 0.1467465
# Run 2 stress 0.149555
# Run 3 stress 0.1478534
# Run 4 stress 0.1478523
# Run 5 stress 0.1476905
# Run 6 stress 0.1453912
# ... Procrustes: rmse 0.0290442  max resid 0.1283431
# Run 7 stress 0.1477762
# Run 8 stress 0.1484775
# Run 9 stress 0.1477834
# Run 10 stress 0.1449198
# ... New best solution
# ... Procrustes: rmse 0.01150246  max resid 0.07912025
# Run 11 stress 0.1469508
# Run 12 stress 0.1463599
# Run 13 stress 0.1464097
# Run 14 stress 0.1448661
# ... New best solution
# ... Procrustes: rmse 0.01494519  max resid 0.08698069
# Run 15 stress 0.1481362
# Run 16 stress 0.1477838
# Run 17 stress 0.1478307
# Run 18 stress 0.1470326
# Run 19 stress 0.1485094
# Run 20 stress 0.1481361
# Run 21 stress 0.1457989
# Run 22 stress 0.1481131
# Run 23 stress 0.1448862
# ... Procrustes: rmse 0.002699791  max resid 0.01820588
# Run 24 stress 0.1449165
# ... Procrustes: rmse 0.00466223  max resid 0.03179257
# Run 25 stress 0.1450687
# ... Procrustes: rmse 0.00748379  max resid 0.04074644
# Run 26 stress 0.1463288
# Run 27 stress 0.1449259
# ... Procrustes: rmse 0.01457525  max resid 0.08615354
# Run 28 stress 0.1460801
# Run 29 stress 0.1464102
# Run 30 stress 0.1448658
# ... New best solution
# ... Procrustes: rmse 0.0008847195  max resid 0.004182471
# ... Similar to previous best
# *** Solution reached

# %%
# %%R
# p.t1 = plot_ordination(physeq.plantT1, dist.bray.nmds, justDF = TRUE)
#
#
# p = ggplot(p.t1,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=as.factor(R_Year), size = kgdw_ha)) +
#     theme_pub()
#
# p

# %%
# %%R
# ordMean = p.t1 %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# pT1 = ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2")+
#    # facet_wrap(~Fert)+
#     ggtitle("T1")
#
# pT1

# %% [markdown]
# ### Mantel of T1

# %%
# %%R
#
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(physeq.plantT1)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# #hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(T1.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M1 %>% print
#
# M2 =  mantel.partial(T1.wunif.dist, Yd, Rd, method="pearson", permutations=999)
# M2 %>% print
# #Model is not significant within T3
# Out:
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T1.bray.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.07992
#       Significance: 0.023
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0479 0.0643 0.0745 0.0912
# Permutation: free
# Number of permutations: 999
#
#
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T1.wunif.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.06282
#       Significance: 0.065
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0543 0.0671 0.0796 0.0926
# Permutation: free
# Number of permutations: 999

# %% [markdown]
# ##  T2 ADONIS

# %%
# %%R
# # subset phyloseq object
# physeq.plantT2 = subset_samples(physeq,  Planted == "Rhizosphere" & TimePoint == "T2" & SeedTreatment == "Treated")
# physeq.plantT2
#
# # create unifrac distance matrix
# registerDoParallel(cores=28)
# T2.wunif.dist = distance(physeq.plantT2,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T2.bray.dist = distance(physeq.plantT2,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
#
# df = as(sample_data(physeq.plantT2), "data.frame")
#
# print("Bray-Curtis")
# d = T2.bray.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis %>% print
#
# print("w-UniFrac")
# d = T2.wunif.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis
# Out:
# [1] "Bray-Curtis"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Rep        3   0.23615 0.078717   2.054 0.12000  0.001 ***
# Genotype  11   0.46708 0.042462   1.108 0.23735  0.039 *
# Residuals 33   1.26467 0.038323         0.64265
# Total     47   1.96790                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "w-UniFrac"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# Rep        3  0.031581 0.0105269  3.1315 0.16598  0.001 ***
# Genotype  11  0.047754 0.0043413  1.2914 0.25098  0.024 *
# Residuals 33  0.110935 0.0033617         0.58304
# Total     47  0.190270                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# * Genotype has a significant effect on community composition at R1, but ADONIS is not significant for R_Year

# %% [markdown]
# ## T2 ordination

# %%
# %%R
# ##Calculating wunifrac distances
#
# #dist.unif = distance(ps, method = "weighted_unifrac")
#
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T2.bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.111785
# Run 1 stress 0.111786
# ... Procrustes: rmse 0.0005269393  max resid 0.002701488
# ... Similar to previous best
# Run 2 stress 0.1117869
# ... Procrustes: rmse 0.0005494032  max resid 0.002695254
# ... Similar to previous best
# Run 3 stress 0.1117856
# ... Procrustes: rmse 0.0003200912  max resid 0.001288098
# ... Similar to previous best
# Run 4 stress 0.111785
# ... New best solution
# ... Procrustes: rmse 0.0003985006  max resid 0.00205871
# ... Similar to previous best
# Run 5 stress 0.1187453
# Run 6 stress 0.1117855
# ... Procrustes: rmse 0.0005935915  max resid 0.002320255
# ... Similar to previous best
# Run 7 stress 0.111785
# ... Procrustes: rmse 0.0004214552  max resid 0.00176901
# ... Similar to previous best
# Run 8 stress 0.111789
# ... Procrustes: rmse 0.001152439  max resid 0.005196215
# ... Similar to previous best
# Run 9 stress 0.1117852
# ... Procrustes: rmse 0.0005795116  max resid 0.002854013
# ... Similar to previous best
# Run 10 stress 0.1117873
# ... Procrustes: rmse 0.0002879254  max resid 0.0008859368
# ... Similar to previous best
# Run 11 stress 0.1117851
# ... Procrustes: rmse 0.0003942962  max resid 0.001532562
# ... Similar to previous best
# Run 12 stress 0.1117888
# ... Procrustes: rmse 0.001115829  max resid 0.005263532
# ... Similar to previous best
# Run 13 stress 0.1241174
# Run 14 stress 0.1117868
# ... Procrustes: rmse 0.0007378945  max resid 0.002776921
# ... Similar to previous best
# Run 15 stress 0.1117856
# ... Procrustes: rmse 0.0005829937  max resid 0.002782524
# ... Similar to previous best
# Run 16 stress 0.1182783
# Run 17 stress 0.1187489
# Run 18 stress 0.1117889
# ... Procrustes: rmse 0.001065432  max resid 0.004242826
# ... Similar to previous best
# Run 19 stress 0.1117882
# ... Procrustes: rmse 0.0007317801  max resid 0.002758322
# ... Similar to previous best
# Run 20 stress 0.1117857
# ... Procrustes: rmse 0.0005969463  max resid 0.002756091
# ... Similar to previous best
# *** Solution reached

# %%
# %%R
# #Plot NMDS
#
# p = plot_ordination(physeq.plantT2, dist.bray.nmds, justDF = TRUE)

# %%
# %%R
#
# p1 = ggplot(p,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=R_Year, shape = SeedTreatment, size = kgdw_ha))
#
# p1

# %%
# %%R
# ordMean = p %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2")

# %%
# %%R
# filter(p, NMDS2 < -0.2 | NMDS1 < -0.2)
# Out:
#         NMDS1       NMDS2     X.sampleID TubeID ExtractionPlate PooledDNAPlate
# 1 -0.04125156 -0.25324060 ERA-T2_1-4c_85    380            ERA1              A
# 2 -0.25419760 -0.01785013 ERA-T2_4-4d_85    474            ERA4              B
#   Sample.Well.ID PrimerPlate Primer.Number Primer.Well.ID  X primerFwdLoc
# 1             E6           1            45             E6 NA          1-E
# 2             C1           2             3             C1 NA          2-C
#   primerRevLoc fwd_barcode rev_barcode  PlotID TimePoint Rep Row Pos Fert
# 1          1-6    TCATCGAG    CTACGCAG 1-4c_85        T2   1   4   c   85
# 2          2-1    AGAGTCAC    AACTCTCG 4-4d_85        T2   4   4   d   85
#   PlotIndex Plant Genotype SeedTreatment R_Year ERA BG_activity.g BX_activity.g
# 1        44   339      339       Treated   1942   1      88.21732      19.60371
# 2       226  3618     3618       Treated   1961   2      76.78400      19.61642
#   CB_activity.g LAP_activity.g NAG_activity.g Stage kgdw_ha FracN.leco
# 1      24.49390       157.6215       29.70118    R1  5313.0  0.0138430
# 2      17.49004       121.8317       23.38762    R1  6523.5  0.0050007
#   FracC.leco   kgN_ha       RGR      AGR    Nprod      NupR d15N X15N_AtPercent
# 1  0.4339200 73.54786 0.1042213 161.1097 2.190542 2.4647842   NA             NA
# 2  0.2176692 32.62207 0.0769772 184.1032 5.643518 0.5574522   NA             NA
#   FracN FracN_fromSoil FracN_fromFert kgFertN_ha kgSoilN_ha     Planted
# 1    NA             NA             NA         NA         NA Rhizosphere
# 2    NA             NA             NA         NA         NA Rhizosphere

# %% [markdown]
# ## T2 without outliers

# %%
# %%R
# # subset phyloseq object
# physeq.plantT2 = subset_samples(physeq,
#             Planted == "Rhizosphere" & TimePoint == "T2" & SeedTreatment == "Treated") #& !X.sampleID %in%
#                               #  c("ERA-T2_1-4c_85", "ERA-T2_4-4d_85"))
#
#
# # create unifrac distance matrix
# registerDoParallel(cores=28)
# T2.wunif.dist = distance(physeq.plantT2,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T2.bray.dist = distance(physeq.plantT2,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
#
# df = as(sample_data(physeq.plantT2), "data.frame")
#
# print("Bray-Curtis")
# d = T2.bray.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis %>% print
#
# print("w-UniFrac")
# d = T2.wunif.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis
# Out:
# [1] "Bray-Curtis"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Rep        3   0.23615 0.078717   2.054 0.12000  0.001 ***
# Genotype  11   0.46708 0.042462   1.108 0.23735  0.039 *
# Residuals 33   1.26467 0.038323         0.64265
# Total     47   1.96790                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "w-UniFrac"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# Rep        3  0.031581 0.0105269  3.1315 0.16598  0.001 ***
# Genotype  11  0.047754 0.0043413  1.2914 0.25098  0.024 *
# Residuals 33  0.110935 0.0033617         0.58304
# Total     47  0.190270                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Ordinate T2 with nmds

# %%
# %%R
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T2.bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.111785
# Run 1 stress 0.111786
# ... Procrustes: rmse 0.0005269393  max resid 0.002701488
# ... Similar to previous best
# Run 2 stress 0.1117869
# ... Procrustes: rmse 0.0005494032  max resid 0.002695254
# ... Similar to previous best
# Run 3 stress 0.1117856
# ... Procrustes: rmse 0.0003200912  max resid 0.001288098
# ... Similar to previous best
# Run 4 stress 0.111785
# ... New best solution
# ... Procrustes: rmse 0.0003985006  max resid 0.00205871
# ... Similar to previous best
# Run 5 stress 0.1187453
# Run 6 stress 0.1117855
# ... Procrustes: rmse 0.0005935915  max resid 0.002320255
# ... Similar to previous best
# Run 7 stress 0.111785
# ... Procrustes: rmse 0.0004214552  max resid 0.00176901
# ... Similar to previous best
# Run 8 stress 0.111789
# ... Procrustes: rmse 0.001152439  max resid 0.005196215
# ... Similar to previous best
# Run 9 stress 0.1117852
# ... Procrustes: rmse 0.0005795116  max resid 0.002854013
# ... Similar to previous best
# Run 10 stress 0.1117873
# ... Procrustes: rmse 0.0002879254  max resid 0.0008859368
# ... Similar to previous best
# Run 11 stress 0.1117851
# ... Procrustes: rmse 0.0003942962  max resid 0.001532562
# ... Similar to previous best
# Run 12 stress 0.1117888
# ... Procrustes: rmse 0.001115829  max resid 0.005263532
# ... Similar to previous best
# Run 13 stress 0.1241174
# Run 14 stress 0.1117868
# ... Procrustes: rmse 0.0007378945  max resid 0.002776921
# ... Similar to previous best
# Run 15 stress 0.1117856
# ... Procrustes: rmse 0.0005829937  max resid 0.002782524
# ... Similar to previous best
# Run 16 stress 0.1182783
# Run 17 stress 0.1187489
# Run 18 stress 0.1117889
# ... Procrustes: rmse 0.001065432  max resid 0.004242826
# ... Similar to previous best
# Run 19 stress 0.1117882
# ... Procrustes: rmse 0.0007317801  max resid 0.002758322
# ... Similar to previous best
# Run 20 stress 0.1117857
# ... Procrustes: rmse 0.0005969463  max resid 0.002756091
# ... Similar to previous best
# *** Solution reached

# %%
# %%R
# p.t2 = plot_ordination(physeq.plantT2, dist.bray.nmds, justDF = TRUE)
#
#
# p = ggplot(p.t2,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=as.factor(R_Year), size = kgdw_ha)) +
#     theme_pub()
#
# p

# %%
# %%R
# ordMean = p.t2 %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# pT2 = ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2")+
#     ggtitle("R1")
# pT2

# %% [markdown]
# * Is there a curvilinear relationship?

# %% [markdown]
# * Careful whether or not using outliers

# %% [markdown]
# ## Curvilinear relationship between year of release and MCC?

# %%
# %%R -w 700 -h 350
# p1 = ggplot(p.t2, aes(x = R_Year, y = NMDS1)) +
#     geom_point(aes(color =Rep))+
#     theme_pub()+
# #     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
# #                 color = "black",
# #                 width = .002) +
# #     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
# #                 height = .002)+
# #    geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "bottom")+
#     xlab("Year of release")+
#     ylab("NMDS1")+
#     ggtitle("R1")
#
# p2 = ggplot(p.t2, aes(x = R_Year, y = NMDS2)) +
#     geom_point(aes(color = Rep))+
#     theme_pub()+
# #     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
# #                 color = "black",
# #                 width = .002) +
# #     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
# #                 height = .002)+
# #    geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "bottom")+
#     xlab("Year of release")+
#     ylab("NMDS2")+
#     ggtitle("R1")
# grid.arrange(p1, p2, ncol =2)

# %% [markdown]
# * hmm, movement along axis 1 is interesting, try in PCoA

# %%
# %%R
# pcoa = ordinate(physeq.plantT2,
#                 method = "PCoA",
#                 distance = T2.bray.dist)
#
# p = plot_ordination(physeq, pcoa, justDF = TRUE)

# %%
# %%R -w 700 -h 350
# p1 = ggplot(p, aes(x = R_Year, y = Axis.1)) +
#     geom_point(aes(color =Rep))+
#     theme_pub()+
# #     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
# #                 color = "black",
# #                 width = .002) +
# #     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
# #                 height = .002)+
# #    geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "bottom")+
#     xlab("Year of release")+
#     ylab("Axis.1")+
#     ggtitle("R1")
#
# p2 = ggplot(p, aes(x = R_Year, y = Axis.2)) +
#     geom_point(aes(color = Rep))+
#     theme_pub()+
# #     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
# #                 color = "black",
# #                 width = .002) +
# #     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
# #                 height = .002)+
# #    geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "bottom")+
#     xlab("Year of release")+
#     ylab("Axis.2")+
#     ggtitle("R1")
# grid.arrange(p1, p2, ncol =2)

# %% [markdown]
# ### plot of merged samples

# %%
# %%R
# tmp = p %>% group_by(R_Year) %>%
#     summarize(mAxis.1 = mean(Axis.1),
#                 seAxis.1 = sd(Axis.1)/sqrt(length(Axis.1)))
#     ggplot(tmp, aes(x = R_Year, y = mAxis.1)) +
#     geom_point() +
#     stat_smooth(method = "lm", formula = y ~ poly(x,2))

# %%
# %%R
# m = lm(mAxis.1~poly(R_Year,2), data = tmp)
# anova(m)
# summary(m)

# %% [markdown]
# * but axis 1 only accounts for 10% of the variation in MCC

# %%
# %%R
# # on raw data
# m = lmer(Axis.1~poly(R_Year,2) + (1|Rep), data = p)
# anova(m)
# summary(m)

# %%
# %%R
# r.squaredGLMM(m)

# %% [markdown]
# ### Mantel test at T2

# %%
# %%R
#
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(physeq.plantT2)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# #hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(T2.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M1 %>% print
#
# M2 =  mantel.partial(T2.wunif.dist, Yd, Rd, method="pearson", permutations=999)
# M2 %>% print
# #Model is not significant within T2

# %% [markdown]
# ## T3

# %%
# %%R
# # subset phyloseq object
# physeq.plantT3 = subset_samples(physeq,  Planted == "Rhizosphere" & TimePoint == "T3")
# physeq.plantT3
#
# # create unifrac distance matrix
# registerDoParallel(cores=28)
# T3.wunif.dist = distance(physeq.plantT3,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T3.bray.dist = distance(physeq.plantT3,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
# df = as(sample_data(physeq.plantT3), "data.frame")
# d = T3.bray.dist
# print("Bray-curtis")
# T3adonis = adonis(formula = d ~ Rep + Fert + Genotype, df, permutations = 999)
# T3adonis %>% print
#
# print("")
# print("weighted UniFrac")
# d = T3.wunif.dist
# T3adonis = adonis(formula = d ~ Rep + Fert + Genotype, df, permutations = 999)
# T3adonis

# %% [markdown]
# * Genotype is significant at T3 when interaction term is not included.  However it describes a lower portion of variance than the untransformed data

# %% [markdown]
# ### Ordinate T3 with nmds

# %%
# %%R
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T3.bray.dist,autotransform=F,k=3,trymax=50)

# %%
# %%R
# p.t3 = plot_ordination(physeq.plantT3, dist.bray.nmds, justDF = TRUE)
#
#
# p2 = ggplot(p.t3,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=Genotype, size = kgdw_ha)) +
#     theme_pub()
#
# p2

# %%
# %%R
# ordMean = p.t3 %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# pT3 = ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2") +
#     ggtitle("R3")
# pT3

# %%
# %%R -w 800 -h 600
# grid.arrange(pT3, p2, ncol = 1)

# %% [markdown]
# ### Mantel test at T3

# %%
# %%R
#
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(physeq.plantT3)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# #hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(T3.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M1 %>% print
#
# M2 =  mantel.partial(T3.wunif.dist, Yd, Rd, method="pearson", permutations=999)
# M2 %>% print
# #Model is not significant within T3

# %% [markdown]
# # Plot  figures with grid.arrange

# %%
# %%R -w 700 -h 250
# grid.arrange(pT1, pT2, pT3, ncol = 3)

# %% [markdown]
# # Global analysis of core plots sampled throughout season

# %%
# %%R
# sd %>%
#     filter(TimePoint == "T1") %>%
#     .$Plant %>%
#     unique

# %%
# %%R
# physeq.core = subset_samples(physeq, Plant %in% c("330", "34M95", "354", "3475", "3517", "P1151HR") &
#                              TimePoint != "T0" & Fert == "85")
# physeq.core

# %%
# %%R
#
# # create unifrac distance matrix
# registerDoParallel(cores=28)
# core.wunif.dist = distance(physeq.core,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# core.bray.dist = distance(physeq.core,
#                       method = "bray",
#                       weighted = FALSE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
# df = as(sample_data(physeq.core), "data.frame")
# d = core.bray.dist
# print("Bray-curtis")
# Coreadonis = adonis(formula = d ~ Rep*TimePoint + Genotype*TimePoint, df, permutations = 999)
# Coreadonis %>% print
#
# print("")
# print("weighted UniFrac")
# d = core.wunif.dist
# Coreadonis = adonis(formula = d ~ Rep*TimePoint + Genotype*TimePoint, df, permutations = 999)
# Coreadonis

# %% [markdown]
# # CAP

# %%
# %%R
# # subset phyloseq object to just rhizosphere plants, time point 2 and only treated seeds
# phy = subset_samples(physeq, Planted == "Rhizosphere" & TimePoint == "T2" & SeedTreatment == "Treated")
# phy

# %%
# %%R
# T2.wunif.dist = phyloseq::distance(phy,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# sample_data(phy) %>% colnames

# %%
# %%R
# sample_data(phy)$Rep = as.factor(sample_data(phy)$Rep)
# # cap.ord = ordinate(
# #     physeq = phy,
# #     method = "CAP",
# #     distance = T2.wunif.dist,
# #     formula = ~ R_Year + Rep + Condition())
#
# ordcap = ordinate(phy, "CAP", "bray", ~poly(R_Year,2) + Condition(Rep))
# plot_ordination(phy, ordcap, "samples", color="R_Year")
#
#
#
#
# # # CAP plot
# # cap.plot <- plot_ordination(phy, cap.ord, axes = c(1,2)) +
# #     geom_point(aes(fill = Genotype), pch= 21,alpha= 1)
#     #geom_point(colour = "grey90",
#     #    size = 1.5) +
#
#     #scale_color_manual(values = c("#1CE6FF","#B79762", "#004D43", "#8FB0FF", "#997D87", "#5A0007"), name = "Genotype",
#  #                      labels = c("B73xB97", "B73xTx303", "ECHES","FAGES","HELAN",     "SORSUD"))
#
#
#
#
# # Now add the environmental variables as arrows
# # arrowmat <- vegan::scores(cap.ord, display = "bp")
#
# # rownames(arrowmat) = c("R_Year", "Rep")
# # #rownames(arrowmat) = c("BX", "CB", "LAP", "NAG")
#
# # # Add labels, make a data.frame
# # arrowdf <- data.frame(labels = rownames(arrowmat), arrowmat)
#
# # Define the arrow aesthetic mapping
# # arrow_map <- aes(xend = CAP1,
# #     yend = CAP2,
# #     x = 0,
# #     y = 0,
# #     shape = NULL,
# #     color = NULL,
# #     label = labels)
#
# # label_map <- aes(x = 1.3 * CAP1,
# #     y = 1.3 * CAP2,
# #     shape = NULL,
# #     color = NULL,
# #     label = labels)
#
# # arrowhead = arrow(length = unit(0.02, "npc"))
#
# # # Make a new graphic
# # p = cap.plot +
# # geom_segment(arrow_map,
# #     size = .5,
# #     data = arrowdf,
# #     color = "gray",
# #     arrow = arrowhead
# #     ) +
# # geom_text(label_map,
# #     data = arrowdf,
# #     show_guide = FALSE)
# # p = p + theme_pub()
# # #p = p + theme(panel.border = element_blank(), legend.position = "right", legend.text = element_text(size = 10))
# # p = p + theme(legend.position = "left", legend.text = element_text())
#
# #save legend for independent formatting
# # g_legend<-function(a.gplot){
# #     tmp <- ggplot_gtable(ggplot_build(a.gplot))
# #     leg <- which(sapply(tmp$grobs, function(x) x$name) == "guide-box")
# #     legend <- tmp$grobs[[leg]]
# #     legend
# # }
# #
#
#
# #legend1 <- g_legend(p)
#
#
# # p =  p + theme(axis.line.x = element_line(color="black", size = 1),
# #     axis.line.y = element_line(color="black", size = 1), legend.position = "left")
# # p = p + theme(legend.position = "bottom")
# # p

# %%
# %%R
# anova(ordcap)

# %% [markdown]
# ## Finally try DESeq2

# %%
# %%R
# # loading
#
# phy.thresh = readRDS('ERA_thresh.rds')
#
# #Subset to T2
# phy.thresh = subset_samples(phy.thresh, TimePoint == "T2" & SeedTreatment == "Treated", TRUE)
# phy.thresh
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4592 taxa and 48 samples ]
# sample_data() Sample Data:       [ 48 samples by 46 sample variables ]
# tax_table()   Taxonomy Table:    [ 4592 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4592 tips and 4591 internal nodes ]

# %%
# %%R
# sample_data(phy.thresh)$Rep = as.factor(sample_data(phy.thresh)$Rep)
# sample_data(phy.thresh)$Row = as.factor(sample_data(phy.thresh)$Row)
# sample_data(phy.thresh)$Fert = as.factor(sample_data(phy.thresh)$Fert)
# sample_data(phy.thresh)$ERA = as.factor(sample_data(phy.thresh)$ERA)
# sample_data(phy.thresh)$R_Year.c = sample_data(phy.thresh)$R_Year - 1935

# %%
# %%R
# dds = phyloseq_to_deseq2(phy.thresh, ~Rep + poly(R_Year.c,2))
# d_dds = DESeq(dds, parallel = TRUE)
# resultsNames(d_dds) %>% print
# Out:
# [1] "Intercept"          "Rep1"               "Rep2"
# [4] "Rep3"               "Rep4"               "poly.R_Year.c..2.1"
# [7] "poly.R_Year.c..2.2"

# %%
# %%R
# Year.x.res = results(d_dds, name="poly.R_Year.c..2.1", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(Year.x.res)
# Out:
# out of 4589 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 0, 0%
# LFC < 0 (down)   : 0, 0%
# outliers [1]     : 0, 0%
# low counts [2]   : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
# %%R
# Year.x2.res = results(d_dds, name="poly.R_Year.c..2.2", alpha = 0.05,
#                 independentFiltering = TRUE, parallel = TRUE)
# summary(Year.x2.res)
# Out:
# out of 4589 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)     : 2, 0.044%
# LFC < 0 (down)   : 11, 0.24%
# outliers [1]     : 0, 0%
# low counts [2]   : 2758, 60%
# (mean count < 2)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
# %%R
# toKeep = Year.x2.res %>% as.data.frame %>% mutate(OTU = rownames(Year.x2.res)) %>% filter(padj < 0.05) %>% .$OTU

# %%
# %%R
# ToPlot = physeq.plantT2 %>%
#         prune_taxa(toKeep, .) %>%
#         psmelt()

# %%
# %%R -w 700 -h 900
# require(scales)
# p = ggplot(ToPlot, aes(x = R_Year, y = Abundance))+
#        geom_point()+
#
#        facet_wrap(~OTU, scales = "free_y", ncol = 3)+
#         scale_y_continuous(trans=log2_trans())
# p

# %%
# %%R
# colnames(ToPlot)
# Out:
#  [1] "OTU"             "Sample"          "Abundance"       "X.sampleID"
#  [5] "TubeID"          "ExtractionPlate" "PooledDNAPlate"  "Sample.Well.ID"
#  [9] "PrimerPlate"     "Primer.Number"   "Primer.Well.ID"  "X"
# [13] "primerFwdLoc"    "primerRevLoc"    "fwd_barcode"     "rev_barcode"
# [17] "PlotID"          "TimePoint"       "Rep"             "Row"
# [21] "Pos"             "Fert"            "PlotIndex"       "Plant"
# [25] "Genotype"        "SeedTreatment"   "R_Year"          "ERA"
# [29] "BG_activity.g"   "BX_activity.g"   "CB_activity.g"   "LAP_activity.g"
# [33] "NAG_activity.g"  "Stage"           "kgdw_ha"         "FracN.leco"
# [37] "FracC.leco"      "kgN_ha"          "RGR"             "AGR"
# [41] "Nprod"           "NupR"            "d15N"            "X15N_AtPercent"
# [45] "FracN"           "FracN_fromSoil"  "FracN_fromFert"  "kgFertN_ha"
# [49] "kgSoilN_ha"      "Planted"         "Rank1"           "Rank2"
# [53] "Rank3"           "Rank4"           "Rank5"           "Rank6"
# [57] "Rank7"

# %%
# %%R
# ToPlot %>%
#     select(OTU, Rank2, Rank3, Rank4, Rank5, Rank6, Rank7) %>%
#     unique %>% print
#
# PolyTaxa = ToPlot %>% .$OTU %>% unique
# Out:
#           OTU             Rank2                 Rank3                  Rank4
# 574   OTU.938  __Proteobacteria __Deltaproteobacteria         __Myxococcales
# 430   OTU.494  __Actinobacteria   __Micromonosporales   __Micromonosporaceae
# 320   OTU.371 __Verrucomicrobia    __OPB35_soil_group __uncultured_bacterium
# 371   OTU.444     __Chloroflexi      __Thermomicrobia         __JG30-KF-CM45
# 148  OTU.1703  __Proteobacteria __Deltaproteobacteria         __Myxococcales
# 511   OTU.881     __Chloroflexi      __Chloroflexales      __Chloroflexaceae
# 20   OTU.1039     __Chloroflexi        __Anaerolineae       __Anaerolineales
# 466   OTU.836     __Chloroflexi        __Anaerolineae       __Anaerolineales
# 96  OTU.12859   __Acidobacteria               __DA023 __uncultured_bacterium
# 616   OTU.966     __Chloroflexi        __Anaerolineae       __Anaerolineales
# 257  OTU.2090 __Verrucomicrobia      __Spartobacteria   __Chthoniobacterales
# 101  OTU.1649   __Bacteroidetes    __Sphingobacteriia   __Sphingobacteriales
# 225  OTU.1772  __Planctomycetes    __Planctomycetacia     __Planctomycetales
#                      Rank5                              Rank6
# 574         __Sorangiineae                       __uncultured
# 430       __Micromonospora                               <NA>
# 320                   <NA>                               <NA>
# 371 __uncultured_bacterium                               <NA>
# 148         __Sorangiineae                       __uncultured
# 511          __Roseiflexus __uncultured_Chloroflexi_bacterium
# 20       __Anaerolineaceae                       __uncultured
# 466      __Anaerolineaceae                       __uncultured
# 96                    <NA>                               <NA>
# 616      __Anaerolineaceae                       __uncultured
# 257     __DA101_soil_group             __uncultured_bacterium
# 101     __Chitinophagaceae                  __Flavisolibacter
# 225    __Planctomycetaceae                       __uncultured
#                      Rank7
# 574                   <NA>
# 430                   <NA>
# 320                   <NA>
# 371                   <NA>
# 148                   <NA>
# 511                   <NA>
# 20  __uncultured_bacterium
# 466 __uncultured_bacterium
# 96                    <NA>
# 616 __uncultured_bacterium
# 257                   <NA>
# 101 __uncultured_bacterium
# 225 __uncultured_bacterium

# %%
# %%R
# mat = ToPlot %>%
#     group_by(OTU, Rank2, Rank5, Rank6, Plant, R_Year) %>%
#     summarize(mAbund = mean(Abundance)) %>%
#     as.data.frame() %>%
#        mutate(Taxa = paste(OTU, ":_", Rank5, "_", Rank6, sep = "")) %>%
#     select(Taxa, R_Year, mAbund) %>%
#     spread(R_Year,mAbund)
#
# rownames(mat) = mat$Taxa
# mat = mat[,-1]
# head(mat)
# mat = data.matrix(mat, rownames.force = TRUE)
# mat
# Out:
#                                                                  1936
# OTU.1039:___Anaerolineaceae___uncultured                  0.001231781
# OTU.12859:_NA_NA                                          0.009322367
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.004514325
# OTU.1703:___Sorangiineae___uncultured                     0.006189560
# OTU.1772:___Planctomycetaceae___uncultured                0.011079897
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.013552187
# OTU.371:_NA_NA                                            0.020544173
# OTU.444:___uncultured_bacterium_NA                        0.010760814
# OTU.494:___Micromonospora_NA                              0.016972468
# OTU.836:___Anaerolineaceae___uncultured                   0.006992521
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.009467945
# OTU.938:___Sorangiineae___uncultured                      0.014752191
# OTU.966:___Anaerolineaceae___uncultured                   0.004447558
#                                                                  1939
# OTU.1039:___Anaerolineaceae___uncultured                  0.000000000
# OTU.12859:_NA_NA                                          0.006475806
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.003180320
# OTU.1703:___Sorangiineae___uncultured                     0.004187836
# OTU.1772:___Planctomycetaceae___uncultured                0.007765688
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.015995187
# OTU.371:_NA_NA                                            0.021122197
# OTU.444:___uncultured_bacterium_NA                        0.009586744
# OTU.494:___Micromonospora_NA                              0.014586298
# OTU.836:___Anaerolineaceae___uncultured                   0.003573768
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.009333126
# OTU.938:___Sorangiineae___uncultured                      0.009115125
# OTU.966:___Anaerolineaceae___uncultured                   0.001202048
#                                                                  1942
# OTU.1039:___Anaerolineaceae___uncultured                  0.004429245
# OTU.12859:_NA_NA                                          0.007773428
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.007220649
# OTU.1703:___Sorangiineae___uncultured                     0.003718537
# OTU.1772:___Planctomycetaceae___uncultured                0.009336632
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.010994906
# OTU.371:_NA_NA                                            0.028191048
# OTU.444:___uncultured_bacterium_NA                        0.017950203
# OTU.494:___Micromonospora_NA                              0.021008608
# OTU.836:___Anaerolineaceae___uncultured                   0.006270990
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.010643277
# OTU.938:___Sorangiineae___uncultured                      0.011236566
# OTU.966:___Anaerolineaceae___uncultured                   0.003366655
#                                                                  1953
# OTU.1039:___Anaerolineaceae___uncultured                  0.005348806
# OTU.12859:_NA_NA                                          0.014574624
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.012400965
# OTU.1703:___Sorangiineae___uncultured                     0.004894213
# OTU.1772:___Planctomycetaceae___uncultured                0.010060688
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.009757627
# OTU.371:_NA_NA                                            0.029744105
# OTU.444:___uncultured_bacterium_NA                        0.016052954
# OTU.494:___Micromonospora_NA                              0.021564505
# OTU.836:___Anaerolineaceae___uncultured                   0.009878066
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.010199977
# OTU.938:___Sorangiineae___uncultured                      0.016347342
# OTU.966:___Anaerolineaceae___uncultured                   0.005360434
#                                                                  1961
# OTU.1039:___Anaerolineaceae___uncultured                  0.004807963
# OTU.12859:_NA_NA                                          0.015817098
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.010232032
# OTU.1703:___Sorangiineae___uncultured                     0.017641983
# OTU.1772:___Planctomycetaceae___uncultured                0.002014623
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.008138382
# OTU.371:_NA_NA                                            0.026097738
# OTU.444:___uncultured_bacterium_NA                        0.018076122
# OTU.494:___Micromonospora_NA                              0.016800562
# OTU.836:___Anaerolineaceae___uncultured                   0.014524156
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.015636791
# OTU.938:___Sorangiineae___uncultured                      0.029124601
# OTU.966:___Anaerolineaceae___uncultured                   0.010422458
#                                                                  1971
# OTU.1039:___Anaerolineaceae___uncultured                  0.012560353
# OTU.12859:_NA_NA                                          0.015641598
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.009901142
# OTU.1703:___Sorangiineae___uncultured                     0.016709812
# OTU.1772:___Planctomycetaceae___uncultured                0.006699266
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.003653664
# OTU.371:_NA_NA                                            0.033672918
# OTU.444:___uncultured_bacterium_NA                        0.022722305
# OTU.494:___Micromonospora_NA                              0.028440798
# OTU.836:___Anaerolineaceae___uncultured                   0.019211707
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.016049304
# OTU.938:___Sorangiineae___uncultured                      0.029774138
# OTU.966:___Anaerolineaceae___uncultured                   0.016394233
#                                                                  1975
# OTU.1039:___Anaerolineaceae___uncultured                  0.013876348
# OTU.12859:_NA_NA                                          0.017581247
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.012537595
# OTU.1703:___Sorangiineae___uncultured                     0.010819445
# OTU.1772:___Planctomycetaceae___uncultured                0.007176259
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.009947341
# OTU.371:_NA_NA                                            0.030891023
# OTU.444:___uncultured_bacterium_NA                        0.019230494
# OTU.494:___Micromonospora_NA                              0.023993747
# OTU.836:___Anaerolineaceae___uncultured                   0.010361651
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.014080308
# OTU.938:___Sorangiineae___uncultured                      0.020975548
# OTU.966:___Anaerolineaceae___uncultured                   0.010132806
#                                                                  1984
# OTU.1039:___Anaerolineaceae___uncultured                  0.010932107
# OTU.12859:_NA_NA                                          0.013160753
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.012787458
# OTU.1703:___Sorangiineae___uncultured                     0.014005700
# OTU.1772:___Planctomycetaceae___uncultured                0.005231929
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.010457245
# OTU.371:_NA_NA                                            0.031104419
# OTU.444:___uncultured_bacterium_NA                        0.020863763
# OTU.494:___Micromonospora_NA                              0.025204112
# OTU.836:___Anaerolineaceae___uncultured                   0.010063871
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.013445250
# OTU.938:___Sorangiineae___uncultured                      0.027384365
# OTU.966:___Anaerolineaceae___uncultured                   0.013822153
#                                                                  1991
# OTU.1039:___Anaerolineaceae___uncultured                  0.008775256
# OTU.12859:_NA_NA                                          0.012160315
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.009040246
# OTU.1703:___Sorangiineae___uncultured                     0.009696802
# OTU.1772:___Planctomycetaceae___uncultured                0.004291887
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.010075259
# OTU.371:_NA_NA                                            0.031965301
# OTU.444:___uncultured_bacterium_NA                        0.021257658
# OTU.494:___Micromonospora_NA                              0.026549557
# OTU.836:___Anaerolineaceae___uncultured                   0.011134661
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.014956584
# OTU.938:___Sorangiineae___uncultured                      0.018688158
# OTU.966:___Anaerolineaceae___uncultured                   0.009000873
#                                                                  2001
# OTU.1039:___Anaerolineaceae___uncultured                  0.001343436
# OTU.12859:_NA_NA                                          0.012691473
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.008106157
# OTU.1703:___Sorangiineae___uncultured                     0.005716717
# OTU.1772:___Planctomycetaceae___uncultured                0.011280716
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.014636633
# OTU.371:_NA_NA                                            0.021042124
# OTU.444:___uncultured_bacterium_NA                        0.014621359
# OTU.494:___Micromonospora_NA                              0.016369078
# OTU.836:___Anaerolineaceae___uncultured                   0.006503684
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.010549117
# OTU.938:___Sorangiineae___uncultured                      0.011267311
# OTU.966:___Anaerolineaceae___uncultured                   0.002923153
#                                                                  2003
# OTU.1039:___Anaerolineaceae___uncultured                  0.003140987
# OTU.12859:_NA_NA                                          0.008565961
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.006556768
# OTU.1703:___Sorangiineae___uncultured                     0.008864494
# OTU.1772:___Planctomycetaceae___uncultured                0.010463881
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.013555318
# OTU.371:_NA_NA                                            0.024393698
# OTU.444:___uncultured_bacterium_NA                        0.017246564
# OTU.494:___Micromonospora_NA                              0.018890624
# OTU.836:___Anaerolineaceae___uncultured                   0.009260974
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.005547366
# OTU.938:___Sorangiineae___uncultured                      0.012120722
# OTU.966:___Anaerolineaceae___uncultured                   0.006767663
#                                                                  2011
# OTU.1039:___Anaerolineaceae___uncultured                  0.003577975
# OTU.12859:_NA_NA                                          0.010617538
# OTU.1649:___Chitinophagaceae___Flavisolibacter            0.006413336
# OTU.1703:___Sorangiineae___uncultured                     0.010778159
# OTU.1772:___Planctomycetaceae___uncultured                0.013649127
# OTU.2090:___DA101_soil_group___uncultured_bacterium       0.015472330
# OTU.371:_NA_NA                                            0.027713140
# OTU.444:___uncultured_bacterium_NA                        0.015093663
# OTU.494:___Micromonospora_NA                              0.016678139
# OTU.836:___Anaerolineaceae___uncultured                   0.004501701
# OTU.881:___Roseiflexus___uncultured_Chloroflexi_bacterium 0.007826252
# OTU.938:___Sorangiineae___uncultured                      0.010506993
# OTU.966:___Anaerolineaceae___uncultured                   0.005912670

# %%
# %%R -w 800
# pheatmap::pheatmap(mat,
#          cluster_col=FALSE)

# %% [markdown]
# ## are these taxa rhizosphere responders or background?

# %%
# %%R
# l2f.rhiz = read.csv(file = "/home/bryan/ERA/data/MiSeq/20170417_run1/DESeq2/BarevsHybrid.csv", header = TRUE)

# %%
# %%R
# mat = l2f.rhiz %>% filter(OTU %in% PolyTaxa & TimePoint == "T2") %>%
#  select(OTU, Plant, log2FoldChange) %>%
#     spread(Plant, log2FoldChange) %>%
#     .[,c("OTU", "322","330"  ,   "339" ,    "354"   ,  "3618"  ,  "3517"  ,  "3541" ,   "3475" ,
#  "3394",    "34M95" ,  "34N42" ,  "P1151HR")]

# %%
# %%R
# rownames(mat) = mat$OTU
# mat = mat[,-1]
# head(mat)
# mat = data.matrix(mat, rownames.force = TRUE)
# mat
# Out:
#                  322        330         339         354       3618       3517
# OTU.1039   0.2908125         NA  2.18205771  1.61656212  2.0510700  3.2540991
# OTU.12859 -0.2397460 -0.5754415  0.38721026  1.11154761  1.5169609  1.4313313
# OTU.1649  -0.5159308 -0.3407492 -0.21854781  1.06830720  0.7357834  0.9866756
# OTU.1703   0.1534538 -0.3352692 -0.67550266 -0.07204963  2.5593706  2.3710454
# OTU.1772  -0.5228727 -1.1074167 -0.71203634 -0.75595338 -2.7317692 -1.4725948
# OTU.2090   0.6692167  0.7237254  0.37662535 -0.50265549 -0.4286481 -1.9297279
# OTU.371   -0.1695206 -0.0257923  0.96797779  1.00239875  0.7180361  1.5250980
# OTU.444   -0.4953284 -0.3602583  1.10514355  0.77263783  1.2268522  1.7480014
# OTU.494    0.2290707  0.3247341  1.10276956  0.96659137  0.5220282  1.9066422
# OTU.836    0.1369107 -0.6309979  0.01551551  1.00756768  1.9947083  2.6895855
# OTU.881    1.0760508  1.4617163  1.87836357  1.31169583  2.9257842  3.0186452
# OTU.938    0.4555728 -0.3795342  0.24484203  0.78325659  2.9236656  2.6631038
# OTU.966    1.0806823  0.4343074  1.37201102  1.71799997  4.2287092  5.2143781
#                 3541         3475        3394       34M95      34N42
# OTU.1039   4.5262003  1.840120869  3.23067758  0.36472421  0.6113878
# OTU.12859  1.5971327  0.774605527  0.63851411  0.76484459 -0.3963459
# OTU.1649   1.2236728  1.114904906  0.86124616  0.01038757 -0.5865662
# OTU.1703   1.0980259  2.118849677  1.15205116 -0.28300938  0.4045115
# OTU.1772  -1.5338358 -1.866096512 -2.47201769 -0.49802264 -0.7172275
# OTU.2090  -0.3206656  0.006130096  0.05707818  0.53433895  0.3405172
# OTU.371    1.1492133  1.106593636  1.28868049 -0.04624507  0.3681930
# OTU.444    1.2291422  1.475134530  1.56113667  0.32353434  0.6919487
# OTU.494    1.3360784  1.423075919  1.80425283  0.25238081  0.5878131
# OTU.836    1.1336228  1.454411784  1.08963711  0.01924751  0.4482369
# OTU.881    2.4738947  2.275974582  2.61988387  1.44321687  0.8158510
# OTU.938    1.4164937  2.235191586  1.29983264 -0.29408074 -0.2285611
# OTU.966    3.7278197  4.409180085  3.27084227  0.54235981  1.7363604
#               P1151HR
# OTU.1039   1.01294192
# OTU.12859  0.35731157
# OTU.1649  -0.29418370
# OTU.1703   0.92487737
# OTU.1772   0.06351133
# OTU.2090   0.82381254
# OTU.371    0.75349655
# OTU.444    0.48445520
# OTU.494    0.42245922
# OTU.836   -0.09275762
# OTU.881    1.01850665
# OTU.938    0.35106171
# OTU.966    1.95895920

# %%
# %%R
# pheatmap::pheatmap(mat,
#          cluster_col=FALSE)

# %%
# %%R
# Fert.sig = l2f.Fert %>% filter(padj < .05)
#     Fert.sig %>% head %>% print
# Rhiz.sig = l2f.rhiz %>% filter(p.adj < .05)
# Out:
#     baseMean log2FoldChange      lfcSE     stat       pvalue        padj
# 1  57.336477      0.3088018 0.09036034 3.417448 6.321110e-04 0.049772638
# 2  31.608509      1.3851356 0.33690111 4.111401 3.932652e-05 0.005594198
# 3  33.698029      1.1325439 0.32376969 3.497992 4.687744e-04 0.041035789
# 4 175.345301      0.7820358 0.19220954 4.068663 4.728373e-05 0.006330458
# 5  95.511586      0.8416117 0.21868204 3.848563 1.188125e-04 0.013520866
# 6   6.678833      1.4443268 0.34166679 4.227296 2.365160e-05 0.004364670
#         OTU Contrast    Rank1            Rank2                 Rank3
# 1  OTU.2489     0_85 Bacteria __Proteobacteria __Deltaproteobacteria
# 2 OTU.14139     0_85 Bacteria __Proteobacteria __Alphaproteobacteria
# 3 OTU.15685     0_85 Bacteria __Proteobacteria __Alphaproteobacteria
# 4    OTU.69     0_85 Bacteria __Proteobacteria __Alphaproteobacteria
# 5    OTU.78     0_85 Bacteria __Proteobacteria __Alphaproteobacteria
# 6  OTU.3468     0_85 Bacteria __Proteobacteria __Alphaproteobacteria
#           Rank4               Rank5       Rank6                  Rank7 Rank8
# 1  __GR-WP33-30                <NA>        <NA>                   <NA>  <NA>
# 2 __Rhizobiales      __Rhizobiaceae __Rhizobium __uncultured_bacterium  <NA>
# 3 __Rhizobiales      __Rhizobiaceae __Rhizobium                   <NA>  <NA>
# 4 __Rhizobiales      __Rhizobiaceae  __Shinella __uncultured_bacterium  <NA>
# 5 __Rhizobiales      __Rhizobiaceae __Rhizobium                   <NA>  <NA>
# 6 __Rhizobiales __Hyphomicrobiaceae   __Devosia __uncultured_bacterium  <NA>

# %%
# %%R
# betas <- coef(d_dds)
# colnames(betas)
# Out:
# [1] "Intercept"          "Rep1"               "Rep2"
# [4] "Rep3"               "Rep4"               "poly.R_Year.c..2.1"
# [7] "poly.R_Year.c..2.2"

# %%
# %%R
# str(betas)
# Out:
#  num [1:4592, 1:7] 2.728 -0.989 3.925 1.453 -0.197 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:4592] "OTU.871" "OTU.9547" "OTU.523" "OTU.1107" ...
#   ..$ : chr [1:7] "Intercept" "Rep1" "Rep2" "Rep3" ...

# %%
# %%R
# betas[topGenes,]
# Out:
#           Intercept        Rep1        Rep2         Rep3          Rep4
# OTU.1039   1.041147  0.05714519  0.02532954  0.257559939 -0.3400340833
# OTU.966    1.330184  0.29385895 -0.26922230  0.011685566 -0.0363214611
# OTU.836    1.874405  0.32653771  0.33899453 -0.341953467 -0.3235777175
# OTU.938    3.701478 -0.25990367 -0.06701055 -0.031728763  0.3586450750
# OTU.1649   1.538524  0.07841166 -0.59854121  0.519433438  0.0006969883
# OTU.1772   1.356840 -0.14485261  0.27019866  0.011954963 -0.1373002463
# OTU.1703   1.971579  0.06299148  0.26585231 -0.336931575  0.0080889035
# OTU.12859  2.393299 -0.16554469  0.15336188 -0.185677355  0.1978615130
# OTU.2090   2.195215 -0.89135610  0.17231439  0.205546381  0.5134965788
# OTU.881    2.346700  0.53335660 -0.31229839 -0.264681857  0.0436249821
# OTU.494    3.835234  0.54253796 -0.10938098 -0.006567204 -0.4265876139
# OTU.371    4.612532  0.13079330 -0.16518455 -0.108040761  0.1424346239
# OTU.444    3.332480  0.14005337 -0.24351899  0.033769527  0.0696979819
# OTU.830    1.681792  0.97225531 -0.25097515 -0.700181733 -0.0210974662
# OTU.891    2.257607  0.23083049 -0.04212556 -0.236463156  0.0477595038
# OTU.9372   3.306122  0.56892785 -0.37997694 -0.340921920  0.1519728765
# OTU.11869  1.642515  0.22818166 -0.18894869  0.068590494 -0.1078225335
# OTU.597    4.020200  0.68634481 -0.60034358 -0.286928749  0.2009297994
# OTU.776    1.179199 -0.53715525  0.50049910 -0.091971927  0.1286287438
# OTU.417    1.905409  0.20866744 -0.86800366 -0.256088466  0.9154257661
#           poly.R_Year.c..2.1 poly.R_Year.c..2.2
# OTU.1039         0.475512003          -3.816198
# OTU.966          0.632009953          -4.032126
# OTU.836          0.108026635          -3.807740
# OTU.938         -0.184172390          -3.609004
# OTU.1649         0.002906258          -3.142581
# OTU.1772         0.371432695           2.967512
# OTU.1703         0.663687638          -3.017583
# OTU.12859        0.286008914          -2.829342
# OTU.2090         0.264086799           2.747002
# OTU.881         -0.198907315          -2.943039
# OTU.494          0.249873911          -2.449714
# OTU.371          0.533293224          -2.108491
# OTU.444          0.835426216          -2.661784
# OTU.830          0.175570037          -2.742281
# OTU.891         -0.018834851          -2.691546
# OTU.9372         0.452854616          -2.594188
# OTU.11869        1.719930025          -2.697228
# OTU.597         -0.929570023          -2.367858
# OTU.776         -0.255300413           2.707502
# OTU.417          0.896001664          -2.641415

# %%
# %%R
# topGenes <- head(order(Year.x2.res$padj),20)
# mat <- betas[topGenes, -c(1,2)]
# thr <- 3
# mat[mat < -thr] <- -thr
# mat[mat > thr] <- thr
# pheatmap::pheatmap(mat, breaks=seq(from=-thr, to=thr, length=101),
#          cluster_col=FALSE)

# %%
DF = results(d_dds)

supp = tax_table(phy.thresh)
            if (!setequal(row.names(supp), row.names(DF))) {
            stop("Ordination and supplementary data indices differ on the following:\n.",
            setdiff(row.names(DF), row.names(supp)))
        }  

        DF = data.frame(DF, supp)
        DF$OTU = rownames(DF)

DF$Test = "R_Year"
        YR = DF

# %%
# %%R
# sigtab = YR %>% filter(padj < 0.05)
# x = tapply(sigtab$log2FoldChange, sigtab$Rank4, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank4 = factor(as.character(sigtab$Rank4), levels=names(x))
# # x = tapply(sigtab$log2FoldChange, sigtab$Rank3, function(x) max(x))
# # x = sort(x, TRUE)
# # sigtab$Rank3 = factor(as.character(sigtab$Rank3), levels=names(x))
#
# p2 = ggplot(sigtab, aes(x=Rank4, y=log2FoldChange, size = baseMean)) +
#     geom_point(aes(color = Rank2))+
#   theme_pub() +
#   theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5)) +
#     ggtitle("OTUs correlated with Year of Release")  +
#    theme(legend.position="right")
# #x = tapply(sigtab$log2FoldChange, sigtab$Rank2, function(x) max(x))
# #x = sort(x, TRUE)
# #x
#     p2

# %%
# %%R
# plotDispEsts(d_dds)

# %%
# %%R
# DF = results(d_dds, contrast = c("ERA", "1", "3"))
#
# supp = tax_table(phy.thresh)
#             if (!setequal(row.names(supp), row.names(DF))) {
#             stop("Ordination and supplementary data indices differ on the following:\n.",
#             setdiff(row.names(DF), row.names(supp)))
#         }
#
#         DF = data.frame(DF, supp)
#         DF$OTU = rownames(DF)
#
# DF$Test = "R_Year_poly1"
#         RYear_poly1 = DF

# %%
# %%R
# sigtab = RYear_poly1 %>% filter(padj < 0.05)
# x = tapply(sigtab$log2FoldChange, sigtab$Rank4, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank4 = factor(as.character(sigtab$Rank4), levels=names(x))
# # x = tapply(sigtab$log2FoldChange, sigtab$Rank3, function(x) max(x))
# # x = sort(x, TRUE)
# # sigtab$Rank3 = factor(as.character(sigtab$Rank3), levels=names(x))
#
# p2 = ggplot(sigtab, aes(x=Rank4, y=log2FoldChange, size = baseMean)) +
#     geom_point(aes(color = Rank2))+
#   theme_pub() +
#   theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5)) +
#     ggtitle("OTUs correlated with Year of Release")  +
#    theme(legend.position="right")
# #x = tapply(sigtab$log2FoldChange, sigtab$Rank2, function(x) max(x))
# #x = sort(x, TRUE)
# #x
#     p2

# %%
# %%R
# head(sigtab)
# Out:
#    baseMean log2FoldChange     lfcSE     stat       pvalue         padj
# 1 15.988529       1.148456 0.2812720 4.083080 4.444272e-05 0.0269471017
# 2  4.498885       1.388474 0.2797634 4.963029 6.940227e-07 0.0006312136
# 3  5.727666       1.093523 0.2758620 3.964023 7.369722e-05 0.0335138089
# 4  3.188988       1.467852 0.2810343 5.223036 1.760134e-07 0.0003201684
#      Rank1            Rank2                 Rank3               Rank4
# 1 Bacteria __Proteobacteria __Deltaproteobacteria      __Myxococcales
# 2 Bacteria __Proteobacteria __Deltaproteobacteria      __Myxococcales
# 3 Bacteria __Proteobacteria __Gammaproteobacteria __Oceanospirillales
# 4 Bacteria    __Chloroflexi        __Anaerolineae    __Anaerolineales
#                  Rank5             Rank6                              Rank7
# 1       __Sorangiineae      __uncultured                               <NA>
# 2       __Sorangiineae      __uncultured                               <NA>
# 3 __Oceanospirillaceae __Pseudospirillum __uncultured_gamma_proteobacterium
# 4    __Anaerolineaceae      __uncultured             __uncultured_bacterium
#   Rank8      OTU         Test
# 1  <NA>  OTU.938 R_Year_poly1
# 2  <NA> OTU.1703 R_Year_poly1
# 3  <NA>  OTU.891 R_Year_poly1
# 4  <NA>  OTU.966 R_Year_poly1

# %%
# %%R
# library("vsn")
# notAllZero <- (rowSums(counts(dds))>0)
# meanSdPlot(log2(counts(dds,normalized=TRUE)[notAllZero,] + 1))
# Out:
# Error in .local(object, ...) :
#   first calculate size factors, add normalizationFactors, or set normalized=FALSE
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in .local(object, ...) :
#   first calculate size factors, add normalizationFactors, or set normalized=FALSE
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# # Pseudomonas

# %%
# %%R
# physeq.core %>%
#     tax_table() %>%
#     head()

# %%
# %%R
# pdms = subset_taxa(physeq.snorm, Rank6=="__Pseudomonas") %>%
#     subset_samples(Ntreat == "Nneg")
# pdms

# %%
# %%R
# title = "plot_bar; Pseudomonas-only"
# plot_bar(pdms, "Genotype", "Abundance", title=title)

# %%
# %%R
# pdms.mean = psmelt(pdms) %>%
#         group_by(OTU,TimePoint, Genotype) %>%
#          summarize(relAbundance = mean(Abundance))

# %%
# %%R -w 700 -h 700
# ggplot(pdms.mean, aes(x = Genotype, y = relAbundance)) +
#     geom_bar(stat = "identity") +
#     facet_grid(OTU~TimePoint, scales = "free_x")+
#     theme(axis.text.x = element_text(angle = 60))
#    # geom_text(aes(y = relAbundance + .001, label=sig))

# %%
# %%R
# tax_table(pdms)
