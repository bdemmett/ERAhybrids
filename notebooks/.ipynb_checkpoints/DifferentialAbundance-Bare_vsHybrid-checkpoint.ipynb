# %% [markdown]
# ## Description:
#
#     Use DeSeq2 to identify differential abundance between hybrids

# %% [markdown]
# # Setting variables

# %%
workDir = '/home/bryan/ERA/data/MiSeq/20170417_run1/DESeq2'
#using physeq file with sparsity of greater than 3 in 3 samples
physeqFile = '/home/bryan/ERA/data/MiSeq/20170417_run1/phyloseq/ERA_thresh.rds'

# %% [markdown]
# # Init

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# # The required package list:
# reqpkg = c("plyr","BiocParallel","doParallel", "DESeq2", "foreach", "ggplot2",
#    "gridExtra","scales", "phyloseq", "dplyr", "tidyr",
#            "reshape2", "vegan", "RColorBrewer")
# # Load all required packages and show version
# for (i in reqpkg) {
#     print(i)
#     print(packageVersion(i))
#     suppressMessages(library(i, quietly = TRUE, verbose = FALSE,
#                              warn.conflicts = FALSE, character.only = TRUE))
# }
# Out:
# [1] "plyr"
# [1] ‘1.8.4’
# [1] "BiocParallel"
# [1] ‘1.8.2’
# [1] "doParallel"
# [1] ‘1.0.10’
# [1] "DESeq2"
# [1] ‘1.14.1’
# [1] "foreach"
# [1] ‘1.4.3’
# [1] "ggplot2"
# [1] ‘2.2.1’
# [1] "gridExtra"
# [1] ‘2.2.1’
# [1] "scales"
# [1] ‘0.4.1’
# [1] "phyloseq"
# [1] ‘1.19.1’
# [1] "dplyr"
# [1] ‘0.5.0’
# [1] "tidyr"
# [1] ‘0.6.1’
# [1] "reshape2"
# [1] ‘1.4.2’
# [1] "vegan"
# [1] ‘2.4.3’
# [1] "RColorBrewer"
# [1] ‘1.1.2’

# %%
# %%R
# register(MulticoreParam(20))

# %% [markdown]
# # Loading phyloseq object

# %%
# %%R -i physeqFile
#
# physeq.Full = readRDS(physeqFile)
# physeq.Full
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4597 taxa and 243 samples ]
# sample_data() Sample Data:       [ 243 samples by 46 sample variables ]
# tax_table()   Taxonomy Table:    [ 4597 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4597 tips and 4596 internal nodes ]

# %%
# %%R
#
#
# #remove BARE soil controls and untreated seeds
# physeq.plant = subset_samples(physeq.Full, Genotype != "BARE" & SeedTreatment == "Treated")
#
#
# # Set rep and R_Year as a factor
# sample_data(physeq.plant)$Rep = factor(sample_data(physeq.plant)$Rep)
# sample_data(physeq.plant)$R_Year = factor(sample_data(physeq.plant)$R_Year)
#
#
#
#
# #re-order levels
# sample_data(physeq.plant)$R_Year %>% levels
# Out:
#  [1] "1936" "1939" "1942" "1953" "1961" "1971" "1975" "1984" "1991" "2001"
# [11] "2003" "2011"

# %% [markdown]
# ## Create DeSeq2 object at T2

# %%
# %%R
# physeq.plant.t2 = subset_samples(physeq.plant, TimePoint == "T2")

# %%
# %%R
#
# diagdds = phyloseq_to_deseq2(physeq.plant.t2, ~ Rep + R_Year)
# # calculate geometric means prior to estimate size factors
# #gm_mean = function(x, na.rm=TRUE){
# #  exp(sum(log(x[x > 0]), na.rm=na.rm) / length(x))
# #}
# #geoMeans = apply(counts(diagdds), 1, gm_mean)
# #diagdds = estimateSizeFactors(diagdds, geoMeans = geoMeans)
# diagdds = DESeq(diagdds, fitType="local")
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: estimating size factors
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R
# resultsNames(diagdds)
# Out:
#  [1] "Intercept"  "Rep1"       "Rep2"       "Rep3"       "Rep4"
#  [6] "R_Year1936" "R_Year1939" "R_Year1942" "R_Year1953" "R_Year1961"
# [11] "R_Year1971" "R_Year1975" "R_Year1984" "R_Year1991" "R_Year2001"
# [16] "R_Year2003" "R_Year2011"

# %%
# %%R
# res1971 = results(diagdds, contrast=c("R_Year","1971","1936"), independentFiltering = TRUE)
# head(res1971)
# Out:
# log2 fold change (MAP): R_Year 1971 vs 1936
# Wald test p-value: R_Year 1971 vs 1936
# DataFrame with 6 rows and 6 columns
#             baseMean log2FoldChange     lfcSE       stat    pvalue      padj
#            <numeric>      <numeric> <numeric>  <numeric> <numeric> <numeric>
# OTU.871    6.7846336     0.56441368 0.5054187  1.1167250 0.2641119 0.6376045
# OTU.9547   0.5068995    -0.41817966 0.4494589 -0.9304069 0.3521604        NA
# OTU.523   15.4351546    -0.38633950 0.3414337 -1.1315214 0.2578357 0.6317151
# OTU.1107   2.9128938    -0.55521674 0.6220994 -0.8924887 0.3721310 0.7340606
# OTU.11742  0.9836105     1.23852658 0.6516175  1.9006956 0.0573419        NA
# OTU.1889   1.9008549     0.06556225 0.6376204  0.1028233 0.9181032        NA

# %%
# %%R
# res = res1971[order(res1971$padj, na.last=NA), ]
# res = cbind(as(res, "data.frame"), as(tax_table(physeq.plant.t2)[rownames(res), ], "matrix"))
# alpha = 0.1
# sigtab = res[(res$padj < alpha), ]
# sigtab
# Out:
#           baseMean log2FoldChange     lfcSE      stat       pvalue        padj
# OTU.673   4.369474       2.874823 0.5984777  4.803559 1.558703e-06 0.002440929
# OTU.630  13.419391       1.842959 0.4728867  3.897252 9.729030e-05 0.019044576
# OTU.2131  4.503675       2.681684 0.6501338  4.124818 3.710277e-05 0.019044576
# OTU.836   4.431064       2.488753 0.6346023  3.921752 8.790735e-05 0.019044576
# OTU.966   3.188988       2.619319 0.6413483  4.084082 4.425133e-05 0.019044576
# OTU.461   7.077355      -1.998540 0.4968085 -4.022757 5.752086e-05 0.019044576
# OTU.825   4.270705       2.279487 0.5830042  3.909898 9.233520e-05 0.019044576
# OTU.640  15.488991       2.138855 0.5366298  3.985717 6.727654e-05 0.019044576
# OTU.226  20.690544       2.027701 0.5270723  3.847102 1.195234e-04 0.020797064
# OTU.375   7.273813      -1.912114 0.5036188 -3.796749 1.466061e-04 0.022958510
# OTU.3134  6.294221       2.241308 0.6218079  3.604502 3.127515e-04 0.044524443
# ...

# %%
# %%R
# theme_set(theme_bw())
# #sigtabgen = subset(sigtab, !is.na(Genus))
# # Phylum order
# x = tapply(sigtab$log2FoldChange, sigtab$Rank2, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank2 = factor(as.character(sigtab$Rank2), levels=names(x))
# # Genus order
# x = tapply(sigtab$log2FoldChange, sigtab$Rank4, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank4 = factor(as.character(sigtab$Rank4), levels=names(x))
# ggplot(sigtab, aes(y=Rank4, x=log2FoldChange, color=Rank2)) +
#   geom_vline(xintercept = 0.0, color = "gray", size = 0.5) +
#   geom_point(aes(size=baseMean)) +
#   theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5))

# %%
# %%R
# plotMA(res1971, main="DESeq2", ylim=c(-2,2))

# %%
# %%R
# resultsNames(diagdds)
# Out:
#  [1] "Intercept"  "Rep1"       "Rep2"       "Rep3"       "Rep4"
#  [6] "R_Year1936" "R_Year1939" "R_Year1942" "R_Year1953" "R_Year1961"
# [11] "R_Year1971" "R_Year1975" "R_Year1984" "R_Year1991" "R_Year2001"
# [16] "R_Year2003" "R_Year2011"

# %%
# %%R
# res1939 = results(diagdds, contrast=c("R_Year","1939","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1939")
#
# res1942 = results(diagdds, contrast=c("R_Year","1942","1939"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1942")
#
# res1953 = results(diagdds, contrast=c("R_Year","1953","1939"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1953")
#
# res1961 = results(diagdds, contrast=c("R_Year","1961","1939"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1961")
#
# res1971 = results(diagdds, contrast=c("R_Year","1971","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1971")
#
# res1975 = results(diagdds, contrast=c("R_Year","1975","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1975")
#
# res1984 = results(diagdds, contrast=c("R_Year","1984","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1984")
#
# res1991 = results(diagdds, contrast=c("R_Year","1991","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "1991")
#
# res2001 = results(diagdds, contrast=c("R_Year","2001","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "2001")
#
# res2003 = results(diagdds, contrast=c("R_Year","2003","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "2003")
#
# res2011 = results(diagdds, contrast=c("R_Year","2011","1936"), independentFiltering = TRUE) %>%
#     as.data.frame() %>%
#     mutate(OTU = row.names(.), Year = "2011")

# %%
# %%R
# df = rbind(res1939, res1942, res1953, res1961, res1971, res1975, res1984, res1991, res2001, res2003, res2011)
# head(df) %>% print
# tail(df) %>% print
# Out:
#     baseMean log2FoldChange     lfcSE       stat     pvalue padj       OTU Year
# 1  6.7846336    -0.90773829 0.5454174 -1.6643003 0.09605243    1   OTU.871 1939
# 2  0.5068995    -0.38586045 0.4498441 -0.8577649 0.39102230    1  OTU.9547 1939
# 3 15.4351546    -0.07376347 0.3387464 -0.2177543 0.82762057    1   OTU.523 1939
# 4  2.9128938     0.36805283 0.6095722  0.6037887 0.54598412    1  OTU.1107 1939
# 5  0.9836105     0.09395510 0.6419480  0.1463594 0.88363770    1 OTU.11742 1939
# 6  1.9008549     0.51120790 0.6340693  0.8062335 0.42010822    1  OTU.1889 1939
#         baseMean log2FoldChange     lfcSE       stat    pvalue padj      OTU
# 50562 0.63600240     0.03648396 0.5362048 0.06804108 0.9457529    1 OTU.5560
# 50563 0.53721665     0.09627072 0.4482985 0.21474690 0.8299647    1 OTU.2371
# 50564 0.05272879     0.00000000 0.2324227 0.00000000 1.0000000    1 OTU.3006
# 50565 0.60107372     0.54708336 0.5821010 0.93984262 0.3472983    1 OTU.2893
# ...

# %%
# %%R
# t.df = tax_table(physeq.plant.t2) %>% as.data.frame()
# t.df = t.df %>% mutate(OTU = row.names(t.df))
#
# df = left_join(df, t.df, by = "OTU")
# head(df)
# Out:
#     baseMean log2FoldChange     lfcSE       stat     pvalue padj       OTU Year
# 1  6.7846336    -0.90773829 0.5454174 -1.6643003 0.09605243    1   OTU.871 1939
# 2  0.5068995    -0.38586045 0.4498441 -0.8577649 0.39102230    1  OTU.9547 1939
# 3 15.4351546    -0.07376347 0.3387464 -0.2177543 0.82762057    1   OTU.523 1939
# 4  2.9128938     0.36805283 0.6095722  0.6037887 0.54598412    1  OTU.1107 1939
# 5  0.9836105     0.09395510 0.6419480  0.1463594 0.88363770    1 OTU.11742 1939
# 6  1.9008549     0.51120790 0.6340693  0.8062335 0.42010822    1  OTU.1889 1939
#      Rank1            Rank2                 Rank3          Rank4
# 1 Bacteria __Proteobacteria __Deltaproteobacteria __Myxococcales
# 2 Bacteria __Proteobacteria __Deltaproteobacteria __Myxococcales
# 3 Bacteria __Proteobacteria __Deltaproteobacteria __Myxococcales
# 4 Bacteria __Proteobacteria __Deltaproteobacteria __Myxococcales
# 5 Bacteria __Proteobacteria __Deltaproteobacteria __Myxococcales
# ...

# %%
# %%R -i workDir
#
#
# write.csv(df, file = "/home/bryan/ERA/data/MiSeq/20170417_run1/DESeq2/1936vsYear_T2.csv", row.names = FALSE, sep = ",")

# %%
# %%R -w 900 -h 1200
#
# colourCount = length(unique(df$Rank2)) + 1
# getPalette = colorRampPalette(brewer.pal(10, "Dark2"))
#
# df.adj = df[!is.na(df$padj),]
# df.sig = df[df$padj < .1,]
# df.ns = df[df$padj >= .1,]
#
# p = ggplot(df)+
#     geom_point(data = df.ns, aes(Rank2, log2FoldChange, color = "Gray", position = "jitter")) +
#     scale_shape_identity() +
#     geom_point(data = df.sig, aes(Rank2, log2FoldChange, color = Rank2, position = "jitter")) +
#
#                #geom_hline(y_intercept = .4) +
#
#     facet_wrap(~Year)+
#     theme(axis.text.x = element_text(angle = 90)) +
#     labs(y = "log[2] Fold Change")
#
# p = p + scale_color_manual(values = getPalette(colourCount))
# #p = p + geom_point(alpha = 1.00, shape = 21, size = 1.5)
# #p = p + theme_bw()
#
#
#
#
# #p = p + geom_hline(y = l2fc.threshold)
#
#
#
# #p = p + theme(axis.text.x = element_blank())
#
# #p = p + labs(x = "Phylum", color = "Phylum")
#
# #p = p + guides(col = guide_legend(ncol = 2))
#
# #p = p + labs(y = expression(paste("", log[2]," Fold Change",sep="")))
#
# #p = p + guides(colour = guide_legend(override.aes = list(size=4)))
#
# p
