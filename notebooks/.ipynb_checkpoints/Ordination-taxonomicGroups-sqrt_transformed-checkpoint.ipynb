# %% [markdown]
# ## Description:
#
#     A quick and dirty ordination of all OTUs

# %% [markdown]
# # Init

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# library(foreach)
# library(doParallel)
# library(gridExtra)
# library(dplyr)
# library(tidyr)
# library(vegan)
# library(DESeq2)
# library(phyloseq)

# %%
# %%R
# # set theme for ggplot
#
# theme_pub = function (base_size = 11, base_family = "Helvetica")
# {
#     theme_grey(base_size = base_size, base_family = base_family) %+replace%
#         theme(
#             axis.line.x = element_line(size = .5),
#             axis.line.y = element_line(size = .5),
#             panel.background = element_rect(fill = "white", colour = NA),
#             panel.border = element_rect(fill = NA, color = "black", size = .5),
#             panel.grid.major = element_blank(),
#             panel.grid.minor = element_blank(),
#             strip.background = element_rect(fill = "grey85",
#                 colour = "grey20"),
#             legend.key = element_rect(fill = "white",
#                 colour = NA), complete = TRUE)
#     }

# %% [markdown]
# # Loading phyloseq object

# %%
# %%R
# setwd('/home/bryan/ERA/data/MiSeq/20170417_run1/phyloseq/')

# %%
# %%R
# # loading
#
# physeq = readRDS('ERA_snorm.rds')
#
# #remove T0, not necessary
# physeq = subset_samples(physeq, !is.na(Genotype), TRUE)
# physeq = transform_sample_counts(physeq, sqrt)
# physeq
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4597 taxa and 236 samples ]
# sample_data() Sample Data:       [ 236 samples by 33 sample variables ]
# tax_table()   Taxonomy Table:    [ 4597 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4597 tips and 4596 internal nodes ]

# %%
# %%R
# physeq %>% otu_table %>% head(n = 10)
# Out:
# OTU Table:          [10 taxa and 236 samples]
#                      taxa are rows
#           ERA-T2_3-1d_85 ERA-T1_3-5c_170 ERA-T2_1-5a_85 ERA-T1_1-2b_170
# OTU.871      0.019977638      0.01367427    0.013626526     0.011274093
# OTU.9547     0.000000000      0.00000000    0.000000000     0.007971988
# OTU.523      0.023637860      0.01634388    0.016434209     0.023242139
# OTU.1107     0.014126323      0.00000000    0.005810370     0.007971988
# OTU.11742    0.006317484      0.00000000    0.005810370     0.007971988
# OTU.1889     0.008934271      0.01265992    0.008217104     0.005637047
# OTU.2855     0.006317484      0.01033678    0.010870207     0.019527302
# OTU.3270     0.000000000      0.00000000    0.000000000     0.000000000
# OTU.5440     0.008934271      0.01033678    0.000000000     0.005637047
# OTU.663      0.026802813      0.01634388    0.015912354     0.014914224
#           ERA-T1_1-4b_0 ERA-T1_4-3d_0 ERA-T1_1-4a_170 ERA-T3_1-3c_170
# OTU.871     0.018068683   0.015608381     0.016655945     0.005346829
# OTU.9547    0.000000000   0.004706104     0.005021956     0.005346829
# OTU.523     0.028788020   0.023055106     0.020087825     0.021387317
# OTU.1107    0.010022702   0.006655436     0.000000000     0.009260980
# OTU.11742   0.000000000   0.004706104     0.008698283     0.011955873
# OTU.1889    0.007087121   0.008151211     0.010043913     0.009260980
# OTU.2855    0.017359829   0.015608381     0.011229436     0.009260980
# OTU.3270    0.000000000   0.000000000     0.000000000     0.000000000
# OTU.5440    0.007087121   0.008151211     0.008698283     0.014146380
# OTU.663     0.020662330   0.012451180     0.011229436     0.024502249
#           ERA-T1_4-4a_170 ERA-T1_2-2b_85 ERA-T3_3-1c_0 ERA-T2_2-2d_85
# [13] "rev_barcode"     "PlotID"          "TimePoint"       "Rep"
# [17] "Row"             "Pos"             "Fert"            "PlotIndex"
# [21] "Plant"           "Genotype"        "SeedTreatment"   "R_Year"
# [25] "ERA"             "kgdw_ha"         "FracN.leco"      "FracC.leco"
# [29] "d15N"            "X15N_AtPercent"  "FracN"           "FracN_fromSoil"
# [33] "FracN_fromFert"

# %%
# %%R
# sd %>%
#     filter(TubeID == "390")
# Out:
#       X.sampleID TubeID ExtractionPlate PooledDNAPlate Sample.Well.ID
# 1 ERA-T2_2-1d_85    390            ERA2              A            G10
#   PrimerPlate Primer.Number Primer.Well.ID  X primerFwdLoc primerRevLoc
# 1           1            79            G10 NA          1-G         1-10
#   fwd_barcode rev_barcode  PlotID TimePoint Rep Row Pos Fert PlotIndex  Plant
# 1    GGATATCT    TAGCAGAC 2-1d_85        T2   2   1   d   85        70 34N42U
#   Genotype SeedTreatment R_Year ERA kgdw_ha FracN.leco FracC.leco d15N
# 1    34N42     Untreated   2003   3    7518    0.01191    0.43927   NA
#   X15N_AtPercent FracN FracN_fromSoil FracN_fromFert
# 1             NA    NA             NA             NA

# %%
# %%R
# sample_data(physeq)$Rep = as.factor(sample_data(physeq)$Rep)
# sample_data(physeq)$Row = as.factor(sample_data(physeq)$Row)
# sample_data(physeq)$Fert = as.factor(sample_data(physeq)$Fert)

# %% [markdown]
# ## Calculate pairwise weighted Unifrac distances between samples

# %%
# %%R
# registerDoParallel(cores=28)
# wunif.dist = phyloseq::distance(physeq,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# registerDoParallel(cores=28)
# bray.dist = distance(physeq,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# physeq %>%
#     sample_data() %>%
#     .$Genotype %>%
#     levels()
# Out:
#  [1] "322"     "330"     "339"     "3394"    "3475"    "34M95"   "34N42"
#  [8] "3517"    "354"     "3541"    "3618"    "Bare"    "P1151HR"

# %%
# %%R
# sd = sample_data(physeq)
# sd = mutate(sd, Planted = ifelse(Genotype == "Bare" | TimePoint == "T0", "BARE", "Rhizosphere"))
# rownames(sd) = sd$X.sampleID
# sd %>% head
# sample_data(physeq) = sd

# %% [markdown]
# ## NMDS of w-Unifrac

# %%
# %%R -w 800 -h 350
#
# nmds = ordinate(physeq,
#                 method = "NMDS",
#                 distance = wunif.dist)
#
# p = plot_ordination(physeq, nmds, justDF = TRUE)
# Out:
# Run 0 stress 0.1382734
# Run 1 stress 0.1543718
# Run 2 stress 0.145649
# Run 3 stress 0.139911
# Run 4 stress 0.1508674
# Run 5 stress 0.1463935
# Run 6 stress 0.1434578
# Run 7 stress 0.1500465
# Run 8 stress 0.1382727
# ... New best solution
# ... Procrustes: rmse 0.0003557736  max resid 0.004430457
# ... Similar to previous best
# Run 9 stress 0.1451374
# Run 10 stress 0.1477251
# Run 11 stress 0.1517108
# Run 12 stress 0.1427822
# Run 13 stress 0.1398561
# Run 14 stress 0.1456505
# Run 15 stress 0.1454594
# Run 16 stress 0.1534976
# Run 17 stress 0.1408252
# Run 18 stress 0.1454868
# Run 19 stress 0.1457851
# Run 20 stress 0.1508798
# *** Solution reached

# %%
# %%R
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=R_Year), pch = 21, size = 3)
#         #scale_size(range=c(2,8))
#
# #p2 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         #geom_point(aes(fill=Plant, size = BD), pch=21) +
#         #scale_size(range=c(2,8))
#
# grid.arrange(p1, ncol=1)

# %%
# %%R -w 600 -h 350
# p2 = p1 + facet_wrap(~TimePoint)+
# theme_pub()
# p2

# %% [markdown]
# # Adonis testing treatment effects

# %%
# %%R
# set.seed(101)
#
# df = as(sample_data(physeq), "data.frame")
# d = wunif.dist
# df$Fert = as.factor(df$Fert)
# Fulladonis = adonis(formula = d ~ Planted + TimePoint + Genotype*TimePoint + SeedTreatment, df,
#                     permutations = 999)
# Fulladonis
# Out:
# Call:
# adonis(formula = d ~ Planted + TimePoint + Genotype * TimePoint +      SeedTreatment, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#                     Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Planted              1   0.24758 0.247580  64.428 0.20173  0.001 ***
# TimePoint            2   0.07027 0.035137   9.144 0.05726  0.001 ***
# Genotype            11   0.05609 0.005100   1.327 0.04571  0.043 *
# SeedTreatment        1   0.00268 0.002682   0.698 0.00219  0.706
# TimePoint:Genotype  12   0.05135 0.004279   1.114 0.04184  0.213
# Residuals          208   0.79930 0.003843         0.65128
# Total              235   1.22728                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Dissimiliarity by time point

# %% [markdown]
# ## T1 adonis

# %%
# %%R
# physeq.plantT1 = subset_samples(physeq,  Planted == "Rhizosphere" & TimePoint == "T1")
# physeq.plantT1
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4597 taxa and 72 samples ]
# sample_data() Sample Data:       [ 72 samples by 34 sample variables ]
# tax_table()   Taxonomy Table:    [ 4597 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4597 tips and 4596 internal nodes ]

# %%
# %%R
# registerDoParallel(cores=28)
# T1.wunif.dist = distance(physeq.plantT1,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T1.bray.dist = distance(physeq.plantT1,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
# df = as(sample_data(physeq.plantT1), "data.frame")
#
# print("Bray-curtis")
#
# d = T1.bray.dist
# T1adonis = adonis(formula = d ~ Rep + Fert + Genotype, df, permutations = 999)
# T1adonis %>% print
#
# print("w-UniFrac")
# d = T1.wunif.dist
# T1adonis = adonis(formula = d ~ Rep + Fert + Genotype, df, permutations = 999)
# T1adonis
# Out:
# [1] "Bray-curtis"
#
# Call:
# adonis(formula = d ~ Rep + Fert + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Rep        3   0.25300 0.084334 2.19609 0.08761  0.001 ***
# Fert       2   0.07161 0.035804 0.93234 0.02480  0.738
# Genotype   5   0.22068 0.044137 1.14934 0.07642  0.025 *
# Residuals 61   2.34250 0.038402         0.81117
# Total     71   2.88779                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "w-UniFrac"
#
# Call:
# adonis(formula = d ~ Rep + Fert + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# Rep        3  0.037321 0.0124404  3.2124 0.12472  0.001 ***
# Fert       2  0.005292 0.0026462  0.6833 0.01769  0.912
# Genotype   5  0.020390 0.0040781  1.0530 0.06814  0.369
# Residuals 61  0.236232 0.0038727         0.78945
# Total     71  0.299236                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# * Genotype has a significant effect on Bray-curtis distance, but not weighted unifrac
# * Fertilization and genotype do not predict MCC at T1, nor does R_Year

# %%
### Ordinate T1

# %%
# %%R
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T1.bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.1452388
# Run 1 stress 0.1467756
# Run 2 stress 0.1497472
# Run 3 stress 0.1480652
# Run 4 stress 0.1481586
# Run 5 stress 0.1487237
# Run 6 stress 0.145022
# ... New best solution
# ... Procrustes: rmse 0.02355574  max resid 0.1235966
# Run 7 stress 0.1487107
# Run 8 stress 0.1450679
# ... Procrustes: rmse 0.008996628  max resid 0.06075028
# Run 9 stress 0.1480343
# Run 10 stress 0.14525
# ... Procrustes: rmse 0.02250374  max resid 0.1177233
# Run 11 stress 0.147111
# Run 12 stress 0.1452438
# ... Procrustes: rmse 0.0255037  max resid 0.1391817
# Run 13 stress 0.1464557
# Run 14 stress 0.1450032
# ... New best solution
# ... Procrustes: rmse 0.002443699  max resid 0.0152993
# Run 15 stress 0.1483253
# Run 16 stress 0.148038
# Run 17 stress 0.1481674
# Run 18 stress 0.1465613
# Run 19 stress 0.1488041
# Run 20 stress 0.1483266
# Run 21 stress 0.1458967
# Run 22 stress 0.1483154
# Run 23 stress 0.1450279
# ... Procrustes: rmse 0.00278714  max resid 0.01837555
# Run 24 stress 0.1450111
# ... Procrustes: rmse 0.001710697  max resid 0.01097699
# Run 25 stress 0.1451841
# ... Procrustes: rmse 0.007051963  max resid 0.04154889
# Run 26 stress 0.1464925
# Run 27 stress 0.1450887
# ... Procrustes: rmse 0.01479185  max resid 0.08773064
# Run 28 stress 0.1453648
# ... Procrustes: rmse 0.008469982  max resid 0.04464494
# Run 29 stress 0.1464493
# Run 30 stress 0.1450025
# ... New best solution
# ... Procrustes: rmse 0.0008508487  max resid 0.005460769
# ... Similar to previous best
# *** Solution reached

# %%
# %%R
# p.t1 = plot_ordination(physeq.plantT1, dist.bray.nmds, justDF = TRUE)
#
#
# p = ggplot(p.t1,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=as.factor(R_Year), size = kgdw_ha)) +
#     theme_pub()
#
# p

# %%
# %%R
# ordMean = p.t1 %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# pT1 = ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2")+
#    # facet_wrap(~Fert)+
#     ggtitle("T1")
#
# pT1
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Warning:
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Ignoring unknown parameters: check_overlap
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ### Mantel of T1

# %%
# %%R
#
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(physeq.plantT1)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# #hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(T1.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M1 %>% print
#
# M2 =  mantel.partial(T1.wunif.dist, Yd, Rd, method="pearson", permutations=999)
# M2 %>% print
# #Model is not significant within T3
# Out:
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T1.bray.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.07994
#       Significance: 0.026
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0562 0.0695 0.0799 0.0969
# Permutation: free
# Number of permutations: 999
#
#
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T1.wunif.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.06258
#       Significance: 0.054
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0521 0.0630 0.0770 0.0895
# Permutation: free
# Number of permutations: 999

# %% [markdown]
# ##  T2 ADONIS

# %%
# %%R
# # subset phyloseq object
# physeq.plantT2 = subset_samples(physeq,  Planted == "Rhizosphere" & TimePoint == "T2" & SeedTreatment == "Treated")
# physeq.plantT2
#
# # create unifrac distance matrix
# registerDoParallel(cores=28)
# T2.wunif.dist = distance(physeq.plantT2,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T2.bray.dist = distance(physeq.plantT2,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
#
# df = as(sample_data(physeq.plantT2), "data.frame")
#
# print("Bray-Curtis")
# d = T2.bray.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis %>% print
#
# print("w-UniFrac")
# d = T2.wunif.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis
# Out:
# [1] "Bray-Curtis"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Rep        3   0.23636 0.078785  2.0552 0.12004  0.001 ***
# Genotype  11   0.46760 0.042509  1.1089 0.23748  0.037 *
# Residuals 33   1.26507 0.038335         0.64249
# Total     47   1.96902                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "w-UniFrac"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# Rep        3  0.031613 0.0105376  3.1293 0.16586  0.001 ***
# Genotype  11  0.047857 0.0043506  1.2920 0.25109  0.024 *
# Residuals 33  0.111124 0.0033674         0.58304
# Total     47  0.190594                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# * Genotype has a significant effect on community composition at R1, but ADONIS is not significant for R_Year

# %% [markdown]
# ## T2 ordination

# %%
# %%R
# ##Calculating wunifrac distances
#
# #dist.unif = distance(ps, method = "weighted_unifrac")
#
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T2.bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.111493
# Run 1 stress 0.1114918
# ... New best solution
# ... Procrustes: rmse 0.0005452352  max resid 0.002681091
# ... Similar to previous best
# Run 2 stress 0.1114941
# ... Procrustes: rmse 0.001002634  max resid 0.005125458
# ... Similar to previous best
# Run 3 stress 0.1114936
# ... Procrustes: rmse 0.000931719  max resid 0.004798493
# ... Similar to previous best
# Run 4 stress 0.1114924
# ... Procrustes: rmse 0.0001551033  max resid 0.0008137833
# ... Similar to previous best
# Run 5 stress 0.1186972
# Run 6 stress 0.1186985
# Run 7 stress 0.1114924
# ... Procrustes: rmse 0.0005822979  max resid 0.002236134
# ... Similar to previous best
# Run 8 stress 0.111492
# ... Procrustes: rmse 0.0006802945  max resid 0.002836345
# ... Similar to previous best
# Run 9 stress 0.1114948
# ... Procrustes: rmse 0.001053228  max resid 0.004643294
# ... Similar to previous best
# Run 10 stress 0.1114915
# ... New best solution
# ... Procrustes: rmse 0.0001539502  max resid 0.0006098353
# ... Similar to previous best
# Run 11 stress 0.1114931
# ... Procrustes: rmse 0.0008106646  max resid 0.00322678
# ... Similar to previous best
# Run 12 stress 0.1114942
# ... Procrustes: rmse 0.0009108841  max resid 0.003989916
# ... Similar to previous best
# Run 13 stress 0.124107
# Run 14 stress 0.1114936
# ... Procrustes: rmse 0.0005744421  max resid 0.00209422
# ... Similar to previous best
# Run 15 stress 0.1114913
# ... New best solution
# ... Procrustes: rmse 0.0002949594  max resid 0.001209654
# ... Similar to previous best
# Run 16 stress 0.1183159
# Run 17 stress 0.1186965
# Run 18 stress 0.1114947
# ... Procrustes: rmse 0.0003343887  max resid 0.001096383
# ... Similar to previous best
# Run 19 stress 0.1300211
# Run 20 stress 0.1114914
# ... Procrustes: rmse 9.889236e-05  max resid 0.0003625255
# ... Similar to previous best
# *** Solution reached

# %%
# %%R
# #Plot NMDS
#
# p = plot_ordination(physeq.plantT2, dist.bray.nmds, justDF = TRUE)

# %%
# %%R
#
# p1 = ggplot(p,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=R_Year, shape = SeedTreatment, size = kgdw_ha))
#
# p1

# %%
# %%R
# ordMean = p %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2")

# %%
# %%R
# filter(p, NMDS2 < -0.2 | NMDS1 < -0.2)
# Out:
#         NMDS1       NMDS2     X.sampleID TubeID ExtractionPlate PooledDNAPlate
# 1 -0.04288656 -0.25280014 ERA-T2_1-4c_85    380            ERA1              A
# 2 -0.25408022 -0.01779967 ERA-T2_4-4d_85    474            ERA4              B
#   Sample.Well.ID PrimerPlate Primer.Number Primer.Well.ID  X primerFwdLoc
# 1             E6           1            45             E6 NA          1-E
# 2             C1           2             3             C1 NA          2-C
#   primerRevLoc fwd_barcode rev_barcode  PlotID TimePoint Rep Row Pos Fert
# 1          1-6    TCATCGAG    CTACGCAG 1-4c_85        T2   1   4   c   85
# 2          2-1    AGAGTCAC    AACTCTCG 4-4d_85        T2   4   4   d   85
#   PlotIndex Plant Genotype SeedTreatment R_Year ERA kgdw_ha FracN.leco
# 1        44   339      339       Treated   1942   1  5313.0  0.0138430
# 2       226  3618     3618       Treated   1961   2  6523.5  0.0050007
#   FracC.leco d15N X15N_AtPercent FracN FracN_fromSoil FracN_fromFert
# 1  0.4339200   NA             NA    NA             NA             NA
# 2  0.2176692   NA             NA    NA             NA             NA
#       Planted
# 1 Rhizosphere
# 2 Rhizosphere

# %% [markdown]
# ## T2 without outliers

# %%
# %%R
# # subset phyloseq object
# physeq.plantT2 = subset_samples(physeq,
#             Planted == "Rhizosphere" & TimePoint == "T2" & SeedTreatment == "Treated" & !X.sampleID %in%
#                                 c("ERA-T2_1-4c_85", "ERA-T2_4-4d_85"))
#
#
# # create unifrac distance matrix
# registerDoParallel(cores=28)
# T2.wunif.dist = distance(physeq.plantT2,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T2.bray.dist = distance(physeq.plantT2,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
#
# df = as(sample_data(physeq.plantT2), "data.frame")
#
# print("Bray-Curtis")
# d = T2.bray.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis %>% print
#
# print("w-UniFrac")
# d = T2.wunif.dist
# T2adonis = adonis(formula = d ~ Rep + Genotype, df, permutations = 999)
# T2adonis
# Out:
# [1] "Bray-Curtis"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Rep        3   0.21874 0.072914  2.0059 0.12207  0.001 ***
# Genotype  11   0.44629 0.040572  1.1161 0.24906  0.021 *
# Residuals 31   1.12686 0.036350         0.62887
# Total     45   1.79189                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] "w-UniFrac"
#
# Call:
# adonis(formula = d ~ Rep + Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# Rep        3  0.027397 0.0091323  3.1053 0.17079  0.001 ***
# Genotype  11  0.041850 0.0038046  1.2937 0.26089  0.017 *
# Residuals 31  0.091168 0.0029409         0.56833
# Total     45  0.160415                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Ordinate T2 with nmds

# %%
# %%R
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T2.bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.1288226
# Run 1 stress 0.1288224
# ... New best solution
# ... Procrustes: rmse 0.0003153343  max resid 0.001423595
# ... Similar to previous best
# Run 2 stress 0.1322654
# Run 3 stress 0.1288246
# ... Procrustes: rmse 0.001443451  max resid 0.006913437
# ... Similar to previous best
# Run 4 stress 0.128826
# ... Procrustes: rmse 0.0007600968  max resid 0.003040482
# ... Similar to previous best
# Run 5 stress 0.1288212
# ... New best solution
# ... Procrustes: rmse 0.000684044  max resid 0.003022204
# ... Similar to previous best
# Run 6 stress 0.1350385
# Run 7 stress 0.1350372
# Run 8 stress 0.1288218
# ... Procrustes: rmse 0.00043542  max resid 0.002125023
# ... Similar to previous best
# Run 9 stress 0.128998
# ... Procrustes: rmse 0.007824184  max resid 0.04384142
# Run 10 stress 0.1289907
# ... Procrustes: rmse 0.007508095  max resid 0.04175813
# Run 11 stress 0.128825
# ... Procrustes: rmse 0.001072562  max resid 0.004935605
# ... Similar to previous best
# Run 12 stress 0.1350412
# Run 13 stress 0.1288257
# ... Procrustes: rmse 0.001149375  max resid 0.005220931
# ... Similar to previous best
# Run 14 stress 0.1288239
# ... Procrustes: rmse 0.0008259027  max resid 0.00358455
# ... Similar to previous best
# Run 15 stress 0.1321901
# Run 16 stress 0.1350363
# Run 17 stress 0.1289975
# ... Procrustes: rmse 0.007922585  max resid 0.04388772
# Run 18 stress 0.1350366
# Run 19 stress 0.1288223
# ... Procrustes: rmse 0.0005978934  max resid 0.002332149
# ... Similar to previous best
# Run 20 stress 0.1288229
# ... Procrustes: rmse 0.000518572  max resid 0.001786931
# ... Similar to previous best
# *** Solution reached

# %%
# %%R
# p.t2 = plot_ordination(physeq.plantT2, dist.bray.nmds, justDF = TRUE)
#
#
# p = ggplot(p.t2,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=as.factor(R_Year), size = kgdw_ha)) +
#     theme_pub()
#
# p

# %%
# %%R
# ordMean = p.t2 %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# pT2 = ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2")+
#     ggtitle("R1")
# pT2

# %% [markdown]
# ### Mantel test at T2

# %%
# %%R
#
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(physeq.plantT2)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# #hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(T2.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M1 %>% print
#
# M2 =  mantel.partial(T2.wunif.dist, Yd, Rd, method="pearson", permutations=999)
# M2 %>% print
# #Model is not significant within T2
# Out:
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T2.bray.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: -0.01644
#       Significance: 0.613
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0719 0.0937 0.1090 0.1334
# Permutation: free
# Number of permutations: 999
#
#
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T2.wunif.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: -0.06093
#       Significance: 0.916
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0609 0.0732 0.0906 0.1052
# Permutation: free
# Number of permutations: 999

# %% [markdown]
# # T3

# %%
# %%R
# # subset phyloseq object
# physeq.plantT3 = subset_samples(physeq,  Planted == "Rhizosphere" & TimePoint == "T3")
# physeq.plantT3
#
# # create unifrac distance matrix
# registerDoParallel(cores=28)
# T3.wunif.dist = distance(physeq.plantT3,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# T3.bray.dist = distance(physeq.plantT3,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# set.seed(101)
#
# df = as(sample_data(physeq.plantT3), "data.frame")
# d = T3.bray.dist
# print("Bray-curtis")
# T3adonis = adonis(formula = d ~ Rep + Fert*Genotype, df, permutations = 999)
# T3adonis %>% print
#
# print("")
# print("weighted UniFrac")
# d = T3.wunif.dist
# T3adonis = adonis(formula = d ~ Rep + Fert*Genotype, df, permutations = 999)
# T3adonis
# Out:
# [1] "Bray-curtis"
#
# Call:
# adonis(formula = d ~ Rep + Fert * Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#               Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Rep            3   0.28324 0.094412 2.39566 0.09245  0.001 ***
# Fert           2   0.14429 0.072144 1.83062 0.04710  0.001 ***
# Genotype       5   0.24688 0.049375 1.25287 0.08058  0.005 **
# Fert:Genotype 10   0.37946 0.037946 0.96287 0.12386  0.752
# Residuals     51   2.00988 0.039409         0.65602
# Total         71   3.06374                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# [1] ""
# [1] "weighted UniFrac"
#
# Call:
# adonis(formula = d ~ Rep + Fert * Genotype, data = df, permutations = 999)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#               Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# Rep            3  0.037868 0.0126228  3.5225 0.12692  0.001 ***
# Fert           2  0.019665 0.0098326  2.7439 0.06591  0.002 **
# Genotype       5  0.022855 0.0045709  1.2756 0.07660  0.076 .
# Fert:Genotype 10  0.035227 0.0035227  0.9831 0.11807  0.544
# Residuals     51  0.182756 0.0035835         0.61251
# Total         71  0.298372                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# * Genotype is not quite significant at T3, but fertilizer is.  However it describes a lower portion of variance than the untransformed data

# %% [markdown]
# ### Ordinate T3 with nmds

# %%
# %%R
# ## Taking distance matrix and making NNMDS rank values with vegan function metaMDS
# ### k = dimensions (usually 2 or 3 used), trymax can give more attempts to reach solution than the default that phyloseq uses
#
# dist.bray.nmds = metaMDS(T3.bray.dist,autotransform=F,k=3,trymax=50)
# Out:
# Run 0 stress 0.1471384
# Run 1 stress 0.156754
# Run 2 stress 0.1471143
# ... New best solution
# ... Procrustes: rmse 0.004527816  max resid 0.0303128
# Run 3 stress 0.1471339
# ... Procrustes: rmse 0.004140858  max resid 0.02779142
# Run 4 stress 0.1530923
# Run 5 stress 0.1595408
# Run 6 stress 0.1517816
# Run 7 stress 0.1547804
# Run 8 stress 0.1471095
# ... New best solution
# ... Procrustes: rmse 0.0006538653  max resid 0.003847836
# ... Similar to previous best
# Run 9 stress 0.1523391
# Run 10 stress 0.1557699
# Run 11 stress 0.1471142
# ... Procrustes: rmse 0.001049341  max resid 0.00687795
# ... Similar to previous best
# Run 12 stress 0.1471119
# ... Procrustes: rmse 0.000418837  max resid 0.002423514
# ... Similar to previous best
# Run 13 stress 0.1471299
# ... Procrustes: rmse 0.003514531  max resid 0.02437691
# Run 14 stress 0.1517643
# Run 15 stress 0.1471102
# ... Procrustes: rmse 0.0006576522  max resid 0.003114887
# ... Similar to previous best
# Run 16 stress 0.1471339
# ... Procrustes: rmse 0.003872729  max resid 0.02675742
# Run 17 stress 0.147111
# ... Procrustes: rmse 0.000266622  max resid 0.001363269
# ... Similar to previous best
# Run 18 stress 0.148598
# Run 19 stress 0.1521343
# Run 20 stress 0.1512029
# *** Solution reached

# %%
# %%R
# p.t3 = plot_ordination(physeq.plantT3, dist.bray.nmds, justDF = TRUE)
#
#
# p2 = ggplot(p.t3,aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color=Genotype, size = kgdw_ha)) +
#     theme_pub()
#
# p2

# %%
# %%R
# ordMean = p.t3 %>%
#     group_by(Genotype, R_Year) %>%
#     summarize(mAxis.1 = mean(NMDS1),
#                 seAxis.1 = sd(NMDS1)/sqrt(length(NMDS1)),
#              mAxis.2 = mean(NMDS2),
#              seAxis.2 = sd(NMDS2)/sqrt(length(NMDS2)))

# %%
# %%R -w 800 -h 400
# pT3 = ggplot(ordMean, aes(x = mAxis.1, y = mAxis.2, label = R_Year)) +
#     geom_point()+
#     theme_pub()+
#     geom_errorbar(aes(ymin = mAxis.2 - seAxis.2, ymax = mAxis.2 + seAxis.2),
#                 color = "black",
#                 width = .002) +
#     geom_errorbarh(aes(xmin = mAxis.1 - seAxis.1, xmax = mAxis.1 + seAxis.1),color = "black",
#                 height = .002)+
#     geom_label(aes(color = R_Year), check_overlap = TRUE) +
#     theme(legend.position = "none")+
#     xlab("NMDS1")+
#     ylab("NMDS2") +
#     ggtitle("R3")
# pT3

# %%
# %%R -w 800 -h 600
# grid.arrange(pT3, p2, ncol = 1)

# %% [markdown]
# ### Mantel test at T3

# %%
# %%R
#
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(physeq.plantT3)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# #hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(T3.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M1 %>% print
#
# M2 =  mantel.partial(T3.wunif.dist, Yd, Rd, method="pearson", permutations=999)
# M2 %>% print
# #Model is not significant within T3
# Out:
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T3.bray.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.01926
#       Significance: 0.329
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0546 0.0692 0.0849 0.0999
# Permutation: free
# Number of permutations: 999
#
#
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = T3.wunif.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.001661
#       Significance: 0.446
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0479 0.0638 0.0737 0.0854
# Permutation: free
# Number of permutations: 999

# %% [markdown]
# ## combine figures with grid.arrange

# %%
# %%R -w 700 -h 250
# grid.arrange(pT1, pT2, pT3, ncol = 3)

# %%
# Do weighted and unweighted bray differ?

# %%
# %%R
# test.weighted.dist = distance(physeq.plantT2,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# test.unweighted.dist = distance(physeq.plantT2,
#                       method = "bray",
#                       weighted = FALSE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# head(test.weighted.dist)
# Out:
# [1] 0.2596775 0.3116596 0.2870721 0.2922338 0.3074103 0.2669461

# %%
# %%R
# head(test.unweighted.dist)
# Out:
# [1] 0.2596775 0.3116596 0.2870721 0.2922338 0.3074103 0.2669461

# %% [markdown]
# # Mantel tests

# %% [markdown]
# ## T1

# %%
# %%R
# phy = subset_samples(physeq, Planted == "Rhizosphere" & TimePoint == "T1")
# phy
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4597 taxa and 72 samples ]
# sample_data() Sample Data:       [ 72 samples by 34 sample variables ]
# tax_table()   Taxonomy Table:    [ 4597 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4597 tips and 4596 internal nodes ]

# %% [markdown]
# * generate distance matrices

# %%
# %%R
#
# registerDoParallel(cores=28)
#
# Time.wunif.dist = phyloseq::distance(phy,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# Time.bray.dist = phyloseq::distance(phy,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(phy)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(Time.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M1
# #Model is not significant within T1
# Out:
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = Time.bray.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.07994
#       Significance: 0.029
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0505 0.0672 0.0817 0.0969
# Permutation: free
# Number of permutations: 999

# %% [markdown]
# * Mantel test at V6 is not quite significant for w-unif, but sign for Bray.
# * Spatial autocorrelation may be an issue and Mantel problems

# %% [markdown]
# ## T2

# %% [markdown]
# * generate distance matrices

# %%
# %%R
#
# # using physeq.plantT2 without two outliers
# registerDoParallel(cores=28)
#
# Time.wunif.dist = phyloseq::distance(physeq.plantT2,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# Time.bray.dist = phyloseq::distance(physeq.plantT2,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %% [markdown]
# ## T3

# %%
# %%R
# # subset phyloseq object to just rhizosphere plants, time point 2 and only treated seeds
# phy = subset_samples(physeq, Planted == "Rhizosphere" & TimePoint == "T3")
# phy
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4597 taxa and 72 samples ]
# sample_data() Sample Data:       [ 72 samples by 34 sample variables ]
# tax_table()   Taxonomy Table:    [ 4597 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4597 tips and 4596 internal nodes ]

# %% [markdown]
# * generate distance matrices

# %%
# %%R
#
# registerDoParallel(cores=28)
#
# Time.wunif.dist = phyloseq::distance(phy,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)
#
# Time.bray.dist = phyloseq::distance(phy,
#                       method = "bray",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# #Test on soil activity/rhizosphere effect
# Sd = sample_data(phy)
#
# # Generate distance matrix of year of release
# Yd = dist(Sd[,"R_Year"], method = "euclidian")
# #hist(Yd)
#
# # generate distance matrix of rep and change all values > 1 to 1
# Rd = dist(Sd[,"Rep"])
# Rd[Rd > 1] <- 1
#
#
# M1 = mantel.partial(Time.wunif.dist, Yd, Rd, method="pearson", permutations=999)
# M1 %>% print
#
# M2 =  mantel.partial(Time.bray.dist, Yd, Rd, method="pearson", permutations=999)
# M2 %>% print
# Out:
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = Time.wunif.dist, ydis = Yd, zdis = Rd,      method = "pearson", permutations = 999)
#
# Mantel statistic r: 0.004635
#       Significance: 0.447
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0473 0.0588 0.0693 0.0861
# Permutation: free
# Number of permutations: 999
#
#
# Partial Mantel statistic based on Pearson's product-moment correlation
#
# Call:
# mantel.partial(xdis = Time.bray.dist, ydis = Yd, zdis = Rd, method = "pearson",      permutations = 999)
#
# Mantel statistic r: 0.02287
#       Significance: 0.269
#
# Upper quantiles of permutations (null model):
#    90%    95%  97.5%    99%
# 0.0519 0.0658 0.0785 0.0902
# Permutation: free
# Number of permutations: 999

# %% [markdown]
# * Mantel test is not significant at T3

# %% [markdown]
# # CAP

# %%
# %%R
# # subset phyloseq object to just rhizosphere plants, time point 2 and only treated seeds
# phy = subset_samples(physeq, Planted == "Rhizosphere" & TimePoint == "T2" & SeedTreatment == "Treated")
# phy
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4597 taxa and 48 samples ]
# sample_data() Sample Data:       [ 48 samples by 34 sample variables ]
# tax_table()   Taxonomy Table:    [ 4597 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4597 tips and 4596 internal nodes ]

# %%
# %%R
# T2.wunif.dist = phyloseq::distance(phy,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# sample_data(phy) %>% colnames

# %%
# %%R
# sample_data(phy)$Rep = as.factor(sample_data(phy)$Rep)
# # cap.ord = ordinate(
# #     physeq = phy,
# #     method = "CAP",
# #     distance = T2.wunif.dist,
# #     formula = ~ R_Year + Rep + Condition())
#
# ordcap = ordinate(phy, "CAP", "bray", ~R_Year + Condition(ExtractionPlate))
# plot_ordination(phy, ordcap, "samples", color="R_Year")
#
#
#
#
# # # CAP plot
# # cap.plot <- plot_ordination(phy, cap.ord, axes = c(1,2)) +
# #     geom_point(aes(fill = Genotype), pch= 21,alpha= 1)
#     #geom_point(colour = "grey90",
#     #    size = 1.5) +
#
#     #scale_color_manual(values = c("#1CE6FF","#B79762", "#004D43", "#8FB0FF", "#997D87", "#5A0007"), name = "Genotype",
#  #                      labels = c("B73xB97", "B73xTx303", "ECHES","FAGES","HELAN",     "SORSUD"))
#
#
#
#
# # Now add the environmental variables as arrows
# # arrowmat <- vegan::scores(cap.ord, display = "bp")
#
# # rownames(arrowmat) = c("R_Year", "Rep")
# # #rownames(arrowmat) = c("BX", "CB", "LAP", "NAG")
#
# # # Add labels, make a data.frame
# # arrowdf <- data.frame(labels = rownames(arrowmat), arrowmat)
#
# # Define the arrow aesthetic mapping
# # arrow_map <- aes(xend = CAP1,
# #     yend = CAP2,
# #     x = 0,
# #     y = 0,
# #     shape = NULL,
# #     color = NULL,
# #     label = labels)
#
# # label_map <- aes(x = 1.3 * CAP1,
# #     y = 1.3 * CAP2,
# #     shape = NULL,
# #     color = NULL,
# #     label = labels)
#
# # arrowhead = arrow(length = unit(0.02, "npc"))
#
# # # Make a new graphic
# # p = cap.plot +
# # geom_segment(arrow_map,
# #     size = .5,
# #     data = arrowdf,
# #     color = "gray",
# #     arrow = arrowhead
# #     ) +
# # geom_text(label_map,
# #     data = arrowdf,
# #     show_guide = FALSE)
# # p = p + theme_pub()
# # #p = p + theme(panel.border = element_blank(), legend.position = "right", legend.text = element_text(size = 10))
# # p = p + theme(legend.position = "left", legend.text = element_text())
#
# #save legend for independent formatting
# # g_legend<-function(a.gplot){
# #     tmp <- ggplot_gtable(ggplot_build(a.gplot))
# #     leg <- which(sapply(tmp$grobs, function(x) x$name) == "guide-box")
# #     legend <- tmp$grobs[[leg]]
# #     legend
# # }
# #
#
#
# #legend1 <- g_legend(p)
#
#
# # p =  p + theme(axis.line.x = element_line(color="black", size = 1),
# #     axis.line.y = element_line(color="black", size = 1), legend.position = "left")
# # p = p + theme(legend.position = "bottom")
# # p

# %%
# %%R
# anova(ordcap)
# Out:
# Permutation test for capscale under reduced model
# Permutation: free
# Number of permutations: 999
#
# Model: capscale(formula = OTU ~ R_Year + Condition(ExtractionPlate), data = data, distance = distance)
#          Df SumOfSqs      F Pr(>F)
# Model     1   0.0413 1.0432  0.336
# Residual 42   1.6626

# %% [markdown]
# ## Finally try DESeq2

# %%
# %%R
# # loading
#
# phy.thresh = readRDS('ERA_thresh.rds')
#
# #Subset to T1
# phy.thresh = subset_samples(phy.thresh, TimePoint == "T1" & SeedTreatment == "Treated", TRUE)
# phy.thresh
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4597 taxa and 72 samples ]
# sample_data() Sample Data:       [ 72 samples by 33 sample variables ]
# tax_table()   Taxonomy Table:    [ 4597 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4597 tips and 4596 internal nodes ]

# %%
# %%R
# sample_data(phy.thresh)$Rep = as.factor(sample_data(phy.thresh)$Rep)
# sample_data(phy.thresh)$Row = as.factor(sample_data(phy.thresh)$Row)
# sample_data(phy.thresh)$Fert = as.factor(sample_data(phy.thresh)$Fert)
# sample_data(phy.thresh)$ERA = as.factor(sample_data(phy.thresh)$ERA)

# %%
# %%R
# dds = phyloseq_to_deseq2(phy.thresh, ~Rep + ERA)
# d_dds = DESeq(dds, parallel = TRUE)
# resultsNames(d_dds) %>% print
# DF = results(d_dds)
#
# supp = tax_table(phy.thresh)
#             if (!setequal(row.names(supp), row.names(DF))) {
#             stop("Ordination and supplementary data indices differ on the following:\n.",
#             setdiff(row.names(DF), row.names(supp)))
#         }
#
#         DF = data.frame(DF, supp)
#         DF$OTU = rownames(DF)
#
# DF$Test = "R_Year"
#         YR = DF
# Out:
# [1] "Intercept" "Rep1"      "Rep2"      "Rep3"      "Rep4"      "ERA1"
# [7] "ERA2"      "ERA3"

# %%
# %%R
# DF
# Out:
#               baseMean log2FoldChange      lfcSE          stat       pvalue
# OTU.871   8.750788e+00   1.273306e-01 0.08582901  1.4835381203 1.379315e-01
# OTU.9547  3.159718e-01  -2.179299e-02 0.06539652 -0.3332439089 7.389502e-01
# OTU.523   1.585089e+01   8.102224e-02 0.07565821  1.0708981555 2.842152e-01
# OTU.1107  2.211258e+00   1.141193e-01 0.10274355  1.1107197309 2.666890e-01
# OTU.11742 1.066166e+00  -5.133989e-02 0.09735455 -0.5273496871 5.979508e-01
# OTU.1889  3.239170e+00   7.044753e-02 0.10293577  0.6843833277 4.937331e-01
# OTU.2855  5.764381e+00   6.760918e-02 0.09689603  0.6977496810 4.853338e-01
# OTU.3270  4.622870e-01  -7.013798e-03 0.06250559 -0.1122107376 9.106563e-01
# OTU.5440  1.269212e+00   3.729772e-02 0.10090909  0.3696170979 7.116678e-01
# OTU.663   1.001347e+01   7.406136e-02 0.08766603  0.8448125711 3.982155e-01
# OTU.2244  6.819397e-01   5.217635e-02 0.08398425  0.6212634910 5.344263e-01
# OTU.7631  8.801287e-01  -5.552788e-02 0.09508173 -0.5840015732 5.592193e-01
# OTU.1184  4.478423e+00   1.135464e-01 0.09984159  1.1372651462 2.554275e-01
# OTU.2510  4.119443e+00   6.941539e-02 0.09834235  0.7058544884 4.802786e-01
# OTU.1116  6.240973e+00   2.571554e-01 0.10184775  2.5248998110 1.157313e-02
# OTU.1241  3.305336e+00   1.600921e-01 0.10331605  1.5495376035 1.212525e-01
# OTU.701   4.939262e+00   1.858121e-01 0.09477219  1.9606180264 4.992360e-02
# OTU.2470  2.042362e+00  -5.166436e-02 0.10361389 -0.4986238363 6.180444e-01
# OTU.4032  5.925932e-01   2.443300e-02 0.08491213  0.2877445107 7.735423e-01
# OTU.1534  1.650038e+00  -1.529667e-02 0.10120513 -0.1511452357 8.798611e-01
# OTU.12    8.354046e+01   2.688730e-03 0.10309146  0.0260810131 9.791927e-01
# OTU.2202  6.687609e-01   6.235060e-02 0.08309315  0.7503698819 4.530320e-01
# OTU.4436  5.843841e-01   6.630539e-02 0.08282142  0.8005826226 4.233733e-01
# OTU.2365  2.484437e+01   1.665344e-02 0.06321852  0.2634265530 7.922218e-01
# OTU.1956  4.954636e+00  -6.828982e-02 0.10158179 -0.6722644170 5.014154e-01
# OTU.922   1.352151e+01  -8.455593e-02 0.08511769 -0.9934001568 3.205150e-01
# ...
# OTU.2232                                  <NA>  OTU.2232 R_Year
# OTU.516                                   <NA>   OTU.516 R_Year
# OTU.161                                   <NA>   OTU.161 R_Year
# OTU.7215                                  <NA>  OTU.7215 R_Year
# OTU.435                                   <NA>   OTU.435 R_Year
# OTU.2724                                  <NA>  OTU.2724 R_Year
# OTU.773                                   <NA>   OTU.773 R_Year
# OTU.13573                                 <NA> OTU.13573 R_Year
# OTU.724                                   <NA>   OTU.724 R_Year
# OTU.377                                   <NA>   OTU.377 R_Year
# OTU.947                                   <NA>   OTU.947 R_Year
# OTU.3494                                  <NA>  OTU.3494 R_Year
# OTU.9277                                  <NA>  OTU.9277 R_Year
# OTU.4253                                  <NA>  OTU.4253 R_Year
# OTU.1962                                  <NA>  OTU.1962 R_Year
# OTU.142                                   <NA>   OTU.142 R_Year
# OTU.1728                                  <NA>  OTU.1728 R_Year
# OTU.754                                   <NA>   OTU.754 R_Year
# OTU.261                                   <NA>   OTU.261 R_Year
# OTU.5661                                  <NA>  OTU.5661 R_Year
# OTU.2313                                  <NA>  OTU.2313 R_Year
# OTU.108                                   <NA>   OTU.108 R_Year
# OTU.15244                                 <NA> OTU.15244 R_Year
# OTU.1984                                  <NA>  OTU.1984 R_Year
# OTU.3059                                  <NA>  OTU.3059 R_Year
# OTU.3385                                  <NA>  OTU.3385 R_Year
# OTU.851                                   <NA>   OTU.851 R_Year
# OTU.1047                                  <NA>  OTU.1047 R_Year
# OTU.8704                                  <NA>  OTU.8704 R_Year
# OTU.9170                                  <NA>  OTU.9170 R_Year
# OTU.1257                                  <NA>  OTU.1257 R_Year
# OTU.817                                   <NA>   OTU.817 R_Year
# OTU.1272                                  <NA>  OTU.1272 R_Year
# OTU.2201                                  <NA>  OTU.2201 R_Year
# OTU.3146                                  <NA>  OTU.3146 R_Year
# OTU.1341                                  <NA>  OTU.1341 R_Year
# OTU.10436                                 <NA> OTU.10436 R_Year
# OTU.165                                   <NA>   OTU.165 R_Year
# OTU.12705                                 <NA> OTU.12705 R_Year
# OTU.718                                   <NA>   OTU.718 R_Year
# OTU.2053                                  <NA>  OTU.2053 R_Year
# OTU.296                                   <NA>   OTU.296 R_Year
# OTU.2514                                  <NA>  OTU.2514 R_Year
# OTU.1332                                  <NA>  OTU.1332 R_Year
# OTU.4123                                  <NA>  OTU.4123 R_Year
# OTU.65                                    <NA>    OTU.65 R_Year
# OTU.1951                                  <NA>  OTU.1951 R_Year
# OTU.2369                                  <NA>  OTU.2369 R_Year
# OTU.2960                                  <NA>  OTU.2960 R_Year
# OTU.8614                                  <NA>  OTU.8614 R_Year
# OTU.10924                                 <NA> OTU.10924 R_Year
# OTU.6                                     <NA>     OTU.6 R_Year
# OTU.497                                   <NA>   OTU.497 R_Year
# OTU.1558                                  <NA>  OTU.1558 R_Year
# OTU.9019                                  <NA>  OTU.9019 R_Year
# OTU.1397                                  <NA>  OTU.1397 R_Year
# OTU.7424                                  <NA>  OTU.7424 R_Year
# OTU.1322                                  <NA>  OTU.1322 R_Year
# OTU.170                                   <NA>   OTU.170 R_Year
# OTU.10561                                 <NA> OTU.10561 R_Year
# OTU.8665                                  <NA>  OTU.8665 R_Year
# OTU.929                                   <NA>   OTU.929 R_Year
# OTU.2620                                  <NA>  OTU.2620 R_Year
# OTU.360                                   <NA>   OTU.360 R_Year
# OTU.949                                   <NA>   OTU.949 R_Year
# OTU.330                                   <NA>   OTU.330 R_Year
# OTU.1715                                  <NA>  OTU.1715 R_Year
# OTU.1541                                  <NA>  OTU.1541 R_Year
# OTU.1249                                  <NA>  OTU.1249 R_Year
# OTU.223                                   <NA>   OTU.223 R_Year
# OTU.13                                    <NA>    OTU.13 R_Year
# OTU.11542                                 <NA> OTU.11542 R_Year
# OTU.68                                    <NA>    OTU.68 R_Year
# OTU.15813                                 <NA> OTU.15813 R_Year
# OTU.7326                                  <NA>  OTU.7326 R_Year
# OTU.13266                                 <NA> OTU.13266 R_Year
# OTU.2385                                  <NA>  OTU.2385 R_Year
# OTU.8447                                  <NA>  OTU.8447 R_Year
# OTU.502                                   <NA>   OTU.502 R_Year
# OTU.7386                                  <NA>  OTU.7386 R_Year
# OTU.81                                    <NA>    OTU.81 R_Year
# OTU.10916                                 <NA> OTU.10916 R_Year
# OTU.8865                                  <NA>  OTU.8865 R_Year
# OTU.1963                                  <NA>  OTU.1963 R_Year
# OTU.2601                                  <NA>  OTU.2601 R_Year
# OTU.867                                   <NA>   OTU.867 R_Year
# OTU.671                                   <NA>   OTU.671 R_Year
# OTU.8058                                  <NA>  OTU.8058 R_Year
# OTU.1731                                  <NA>  OTU.1731 R_Year
# OTU.340                                   <NA>   OTU.340 R_Year
# OTU.6050                                  <NA>  OTU.6050 R_Year
# OTU.13729                                 <NA> OTU.13729 R_Year
# OTU.141                                   <NA>   OTU.141 R_Year
# OTU.3909                                  <NA>  OTU.3909 R_Year
# OTU.7131                                  <NA>  OTU.7131 R_Year
# OTU.576                                   <NA>   OTU.576 R_Year
# OTU.4879                                  <NA>  OTU.4879 R_Year
# OTU.2019                                  <NA>  OTU.2019 R_Year
# OTU.277                                   <NA>   OTU.277 R_Year
# OTU.320                                   <NA>   OTU.320 R_Year
# OTU.1528                                  <NA>  OTU.1528 R_Year
# OTU.2838                                  <NA>  OTU.2838 R_Year
# OTU.1625                                  <NA>  OTU.1625 R_Year
# OTU.1231                                  <NA>  OTU.1231 R_Year
# OTU.328                                   <NA>   OTU.328 R_Year
# OTU.2238                                  <NA>  OTU.2238 R_Year
# OTU.1402                                  <NA>  OTU.1402 R_Year
# OTU.6075                                  <NA>  OTU.6075 R_Year
# OTU.9811                                  <NA>  OTU.9811 R_Year
# OTU.10176                                 <NA> OTU.10176 R_Year
# OTU.13207                                 <NA> OTU.13207 R_Year
# OTU.8873                                  <NA>  OTU.8873 R_Year
# OTU.697                                   <NA>   OTU.697 R_Year
# OTU.3144                                  <NA>  OTU.3144 R_Year
# OTU.6635                                  <NA>  OTU.6635 R_Year
# OTU.29                                    <NA>    OTU.29 R_Year
# OTU.13397                                 <NA> OTU.13397 R_Year
# OTU.2248                                  <NA>  OTU.2248 R_Year
# OTU.10203                                 <NA> OTU.10203 R_Year
# OTU.10060                                 <NA> OTU.10060 R_Year
# OTU.416                                   <NA>   OTU.416 R_Year
# OTU.8922                                  <NA>  OTU.8922 R_Year
# OTU.27                                    <NA>    OTU.27 R_Year
# OTU.7348                                  <NA>  OTU.7348 R_Year
# OTU.13430                                 <NA> OTU.13430 R_Year
# OTU.8533                                  <NA>  OTU.8533 R_Year
# OTU.557                                   <NA>   OTU.557 R_Year
# OTU.5259                                  <NA>  OTU.5259 R_Year
# OTU.10687                                 <NA> OTU.10687 R_Year
# OTU.290                                   <NA>   OTU.290 R_Year
# OTU.4921                                  <NA>  OTU.4921 R_Year
# OTU.12292                                 <NA> OTU.12292 R_Year
# OTU.12835                                 <NA> OTU.12835 R_Year
# OTU.8266                                  <NA>  OTU.8266 R_Year
# OTU.8926                                  <NA>  OTU.8926 R_Year
# OTU.11149                                 <NA> OTU.11149 R_Year
# OTU.9317                                  <NA>  OTU.9317 R_Year
# OTU.2894                                  <NA>  OTU.2894 R_Year
# OTU.36                                    <NA>    OTU.36 R_Year
# OTU.10112                                 <NA> OTU.10112 R_Year
# OTU.9209                                  <NA>  OTU.9209 R_Year
# OTU.9844                                  <NA>  OTU.9844 R_Year
# OTU.7630                                  <NA>  OTU.7630 R_Year
# OTU.5375                                  <NA>  OTU.5375 R_Year
# OTU.3686                                  <NA>  OTU.3686 R_Year
# OTU.26                                    <NA>    OTU.26 R_Year
# OTU.9394                                  <NA>  OTU.9394 R_Year
# OTU.2783                                  <NA>  OTU.2783 R_Year
# OTU.7260                                  <NA>  OTU.7260 R_Year
# OTU.1460                                  <NA>  OTU.1460 R_Year
# OTU.968                                   <NA>   OTU.968 R_Year
# OTU.75                                    <NA>    OTU.75 R_Year
# OTU.5792                                  <NA>  OTU.5792 R_Year
# OTU.1069                                  <NA>  OTU.1069 R_Year
# OTU.1795                                  <NA>  OTU.1795 R_Year
# OTU.273                                   <NA>   OTU.273 R_Year
# OTU.8040                                  <NA>  OTU.8040 R_Year
# OTU.263                                   <NA>   OTU.263 R_Year
# OTU.159                                   <NA>   OTU.159 R_Year
# OTU.9153                                  <NA>  OTU.9153 R_Year
# OTU.86                                    <NA>    OTU.86 R_Year
# OTU.478                                   <NA>   OTU.478 R_Year
# OTU.2890                                  <NA>  OTU.2890 R_Year
# OTU.551                                   <NA>   OTU.551 R_Year
# OTU.1045                                  <NA>  OTU.1045 R_Year
# OTU.4891                                  <NA>  OTU.4891 R_Year
# OTU.1360                                  <NA>  OTU.1360 R_Year
# OTU.2880                                  <NA>  OTU.2880 R_Year
# OTU.87                                    <NA>    OTU.87 R_Year
# OTU.2006                                  <NA>  OTU.2006 R_Year
# OTU.1688                                  <NA>  OTU.1688 R_Year
# OTU.2480                                  <NA>  OTU.2480 R_Year
# OTU.2322                                  <NA>  OTU.2322 R_Year
# OTU.2633                                  <NA>  OTU.2633 R_Year
# OTU.2927                                  <NA>  OTU.2927 R_Year
# OTU.89                                    <NA>    OTU.89 R_Year
# OTU.318                                   <NA>   OTU.318 R_Year
# OTU.837                                   <NA>   OTU.837 R_Year
# OTU.8885                                  <NA>  OTU.8885 R_Year
# OTU.852                                   <NA>   OTU.852 R_Year
# OTU.1470                                  <NA>  OTU.1470 R_Year
# OTU.1877                                  <NA>  OTU.1877 R_Year
# OTU.4757                                  <NA>  OTU.4757 R_Year
# OTU.889                                   <NA>   OTU.889 R_Year
# OTU.706                                   <NA>   OTU.706 R_Year
# OTU.367                                   <NA>   OTU.367 R_Year
# OTU.4570                                  <NA>  OTU.4570 R_Year
# OTU.4552                                  <NA>  OTU.4552 R_Year
# OTU.15353                                 <NA> OTU.15353 R_Year
# OTU.2175                                  <NA>  OTU.2175 R_Year
# OTU.2114                                  <NA>  OTU.2114 R_Year
# OTU.1925                                  <NA>  OTU.1925 R_Year
# OTU.1970                                  <NA>  OTU.1970 R_Year
# OTU.1959                                  <NA>  OTU.1959 R_Year
# OTU.10172                                 <NA> OTU.10172 R_Year
# OTU.3070                                  <NA>  OTU.3070 R_Year
# OTU.971                                   <NA>   OTU.971 R_Year
# OTU.1194                                  <NA>  OTU.1194 R_Year
# OTU.392                                   <NA>   OTU.392 R_Year
# OTU.2674                                  <NA>  OTU.2674 R_Year
# OTU.1483                                  <NA>  OTU.1483 R_Year
# OTU.2957                                  <NA>  OTU.2957 R_Year
# OTU.11361                                 <NA> OTU.11361 R_Year
# OTU.2619                                  <NA>  OTU.2619 R_Year
# OTU.3487                                  <NA>  OTU.3487 R_Year
# OTU.1835                                  <NA>  OTU.1835 R_Year
# OTU.1487                                  <NA>  OTU.1487 R_Year
# OTU.2529                                  <NA>  OTU.2529 R_Year
# OTU.1571                                  <NA>  OTU.1571 R_Year
# OTU.264                                   <NA>   OTU.264 R_Year
# OTU.1385                                  <NA>  OTU.1385 R_Year
# OTU.2448                                  <NA>  OTU.2448 R_Year
# OTU.1761                                  <NA>  OTU.1761 R_Year
# OTU.2882                                  <NA>  OTU.2882 R_Year
# OTU.778                                   <NA>   OTU.778 R_Year
# OTU.7334                                  <NA>  OTU.7334 R_Year
# OTU.2754                                  <NA>  OTU.2754 R_Year
# OTU.2772                                  <NA>  OTU.2772 R_Year
# OTU.1447                                  <NA>  OTU.1447 R_Year
# OTU.1370                                  <NA>  OTU.1370 R_Year
# OTU.2278                                  <NA>  OTU.2278 R_Year
# OTU.3218                                  <NA>  OTU.3218 R_Year
# OTU.2675                                  <NA>  OTU.2675 R_Year
# OTU.6177                                  <NA>  OTU.6177 R_Year
# OTU.442                                   <NA>   OTU.442 R_Year
# OTU.8155                                  <NA>  OTU.8155 R_Year
# OTU.2870                                  <NA>  OTU.2870 R_Year
# OTU.1620                                  <NA>  OTU.1620 R_Year
# OTU.14585                                 <NA> OTU.14585 R_Year
# OTU.684                                   <NA>   OTU.684 R_Year
# OTU.1403                                  <NA>  OTU.1403 R_Year
# OTU.1059                                  <NA>  OTU.1059 R_Year
# OTU.2555                                  <NA>  OTU.2555 R_Year
# OTU.1471                                  <NA>  OTU.1471 R_Year
# OTU.3154                                  <NA>  OTU.3154 R_Year
# OTU.2210                                  <NA>  OTU.2210 R_Year
# OTU.2691                                  <NA>  OTU.2691 R_Year
# OTU.2743                                  <NA>  OTU.2743 R_Year
# OTU.13535                                 <NA> OTU.13535 R_Year
# OTU.4099                                  <NA>  OTU.4099 R_Year
# OTU.3277                                  <NA>  OTU.3277 R_Year
# OTU.4125                                  <NA>  OTU.4125 R_Year
# OTU.3567                                  <NA>  OTU.3567 R_Year
# OTU.2765                                  <NA>  OTU.2765 R_Year
# OTU.5560                                  <NA>  OTU.5560 R_Year
# OTU.2371                                  <NA>  OTU.2371 R_Year
# OTU.3006                                  <NA>  OTU.3006 R_Year
# OTU.2893                                  <NA>  OTU.2893 R_Year
# OTU.2526                                  <NA>  OTU.2526 R_Year
# OTU.3646                                  <NA>  OTU.3646 R_Year

# %%
# %%R
# sigtab = YR %>% filter(padj < 0.1)
# x = tapply(sigtab$log2FoldChange, sigtab$Rank4, function(x) max(x))
# x = sort(x, TRUE)
# sigtab$Rank4 = factor(as.character(sigtab$Rank4), levels=names(x))
# # x = tapply(sigtab$log2FoldChange, sigtab$Rank3, function(x) max(x))
# # x = sort(x, TRUE)
# # sigtab$Rank3 = factor(as.character(sigtab$Rank3), levels=names(x))
#
# p2 = ggplot(sigtab, aes(x=Rank4, y=log2FoldChange, size = baseMean)) +
#     geom_point(aes(color = Rank2))+
#   theme_pub() +
#   theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5)) +
#     ggtitle("OTUs correlated with Year of Release")  +
#    theme(legend.position="right")
# #x = tapply(sigtab$log2FoldChange, sigtab$Rank2, function(x) max(x))
# #x = sort(x, TRUE)
# #x
#     p2

# %% [markdown]
# # Pseudomonas

# %%
# %%R
# physeq.core %>%
#     tax_table() %>%
#     head()

# %%
# %%R
# pdms = subset_taxa(physeq.snorm, Rank6=="__Pseudomonas") %>%
#     subset_samples(Ntreat == "Nneg")
# pdms

# %%
# %%R
# title = "plot_bar; Pseudomonas-only"
# plot_bar(pdms, "Genotype", "Abundance", title=title)

# %%
# %%R
# pdms.mean = psmelt(pdms) %>%
#         group_by(OTU,TimePoint, Genotype) %>%
#          summarize(relAbundance = mean(Abundance))

# %%
# %%R -w 700 -h 700
# ggplot(pdms.mean, aes(x = Genotype, y = relAbundance)) +
#     geom_bar(stat = "identity") +
#     facet_grid(OTU~TimePoint, scales = "free_x")+
#     theme(axis.text.x = element_text(angle = 60))
#    # geom_text(aes(y = relAbundance + .001, label=sig))

# %%
# %%R
# tax_table(pdms)
